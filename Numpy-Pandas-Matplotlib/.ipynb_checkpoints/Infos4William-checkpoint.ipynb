# %%
import pandas as pd

infos = pd.read_csv('infos.csv')

infos.head()
# Out:
#         ID  类别    代号  商户名称    名称  logo                      简介    联系人  \
# 0  MI00001  支付   YSF   NaN   银闪付   NaN       凤凰旗下支付公司，主要提供代付业务     南姐
# 1      NaN  包网  TXWL   NaN  天下网络   NaN           极速包网，AG官方合作伙伴    NaN
# 2      NaN  游戏  TXQP   NaN  天下棋牌   NaN   自主创新研发，纯原声APP，天下棋牌API    NaN
# 3      NaN  包网    SC   NaN    世彩   NaN  业界第一家为平台定制全原生手机APP的系统商  Alvin
# 4      NaN  支付    DS   NaN  鼎盛卡行   NaN          安全用卡，快速售后，质量保证    NaN
#
#              电话            TG     ...       微信  \
# 0  6.392818e+11  6.392818e+11     ...      NaN
# 1  6.683872e+10  6.683872e+10     ...      NaN
# 2  6.683872e+10  6.683872e+10     ...      NaN
# 3  6.582855e+09           NaN     ...      NaN
# 4           NaN           NaN     ...      NaN
#
#                                                   详情 图片上传  \
# 0                        提供稳定安全的第三方代付渠道，资金包赔30万，费率面谈  NaN
# 1  业精于专，功成于勤！ 天下网络（World Network），专业平台系统提供商、支付快充系...  NaN
# 2  独特风格，与众不同。 天下网络全力打造最热门万人同时在线棋牌游戏产品，自主创新研发“天下棋牌...  NaN
# ...

# %%
infos['电话']
# Out:
# 0     6.392818e+11
# 1     6.683872e+10
# 2     6.683872e+10
# 3     6.582855e+09
# 4              NaN
# 5              NaN
# 6              NaN
# 7     6.396634e+11
# 8     6.391732e+11
# 9     6.391657e+11
# 10    6.393075e+11
# 11    6.392086e+11
# 12             NaN
# 13             NaN
# 14             NaN
# 15    6.391589e+11
# 16             NaN
# 17             NaN
# 18             NaN
# 19    6.397728e+11
# Name: 电话, dtype: float64

# %%
infos = infos.fillna(-1)

# %%
infos[['电话','TG','QQ']] = infos[['电话','TG','QQ']].astype('int64',inplace=1)

# %%
infos.head()
# Out:
#         ID  类别    代号  商户名称    名称  logo                      简介    联系人  \
# 0  MI00001  支付   YSF  -1.0   银闪付  -1.0       凤凰旗下支付公司，主要提供代付业务     南姐
# 1       -1  包网  TXWL  -1.0  天下网络  -1.0           极速包网，AG官方合作伙伴     -1
# 2       -1  游戏  TXQP  -1.0  天下棋牌  -1.0   自主创新研发，纯原声APP，天下棋牌API     -1
# 3       -1  包网    SC  -1.0    世彩  -1.0  业界第一家为平台定制全原生手机APP的系统商  Alvin
# 4       -1  支付    DS  -1.0  鼎盛卡行  -1.0          安全用卡，快速售后，质量保证     -1
#
#              电话            TG     ...      微信  \
# 0  639281785888  639281785888     ...      -1
# 1   66838715999   66838715999     ...      -1
# 2   66838715999   66838715999     ...      -1
# 3    6582855294            -1     ...      -1
# 4            -1            -1     ...      -1
#
#                                                   详情 图片上传  \
# 0                        提供稳定安全的第三方代付渠道，资金包赔30万，费率面谈 -1.0
# 1  业精于专，功成于勤！ 天下网络（World Network），专业平台系统提供商、支付快充系... -1.0
# 2  独特风格，与众不同。 天下网络全力打造最热门万人同时在线棋牌游戏产品，自主创新研发“天下棋牌... -1.0
# ...

# %%
infos.to_csv('info22.csv',sep='\t', encoding='utf-8')

# %%
infos.to_html('info22.html')
