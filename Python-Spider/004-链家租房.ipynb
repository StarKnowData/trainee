# %%
# -*- coding: utf-8 -*-  
import requests

from lxml import etree

target = "https://dl.lianjia.com/zufang/gaoxinyuanqu/"
header = {"Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3",
"Accept-Encoding": "gzip, deflate, br",
"Accept-Language": "zh-CN,zh;q=0.9,en;q=0.8,id;q=0.7,ru;q=0.6,fil;q=0.5,ja;q=0.4,vi;q=0.3",
"Cache-Control": "no-cache",
"Connection": "keep-alive",
"Cookie": "lianjia_ssid=ee84ec14-66ed-4f79-ace6-c5eae223dd55; lianjia_uuid=33e433b4-6eb4-4df8-94cc-331096bae1cd; select_city=210200; all-lj=c32edd623b8a5a59c7de54c92107bb6c; _smt_uid=5d0090b0.4595b59a; UM_distinctid=16b4a3532d612a-08abc50973395e-133f6e57-1fa400-16b4a3532d76db; CNZZDATA1253492418=169998304-1560315932-%7C1560315932; CNZZDATA1254525948=1941904529-1560313457-%7C1560313457; CNZZDATA1255633284=1942370536-1560314801-%7C1560314801; CNZZDATA1255604082=983269546-1560314876-%7C1560314876; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2216b4a353482632-00b6157501bba8-133f6e57-2073600-16b4a353483998%22%2C%22%24device_id%22%3A%2216b4a353482632-00b6157501bba8-133f6e57-2073600-16b4a353483998%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E7%9B%B4%E6%8E%A5%E6%B5%81%E9%87%8F%22%2C%22%24latest_referrer%22%3A%22%22%2C%22%24latest_referrer_host%22%3A%22%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC_%E7%9B%B4%E6%8E%A5%E6%89%93%E5%BC%80%22%7D%7D; _ga=GA1.2.854833218.1560318131; _gid=GA1.2.1178911395.1560318131; srcid=...",
"DNT":"1",
"Host": "dl.lianjia.com",
"Pragma": "no-cache",
"Referer": "https://dl.lianjia.com/",
"Upgrade-Insecure-Requests": "1",
"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.80 Safari/537.36"}

# 获取页面源码
r = requests.get(target,headers=header)

# print(r.text)


# 解析页面源码
selector = etree.HTML(r.content.decode('utf-8').encode('utf-8'))

links = selector.xpath("//div[@class='content__list']//div[@class='content__list--item']")

print(len(links))

i = 0

for link in links:
    imgs = link.xpath("//a[@class='content__list--item--aside']//img//@src")
    # print("图片"+img)
    ps = link.xpath("//div[@class='content__list--item--main']//p//text()")
    # print(link.xpath("//div[@class='content__list--item--main']//p//"))
    
    
for img in imgs:
    print(img)
    
for p in ps:
    print(p.strip())
# Out:
# 30
# https://s1.ljcdn.com/matrix_lianjia_pc/dist/pc/src/resource/default/250-182.png?_v=20190612101938bdd
# https://s1.ljcdn.com/matrix_lianjia_pc/dist/pc/src/resource/default/250-182.png?_v=20190612101938bdd
# https://s1.ljcdn.com/matrix_lianjia_pc/dist/pc/src/resource/default/250-182.png?_v=20190612101938bdd
# https://s1.ljcdn.com/matrix_lianjia_pc/dist/pc/src/resource/default/250-182.png?_v=20190612101938bdd
# https://s1.ljcdn.com/matrix_lianjia_pc/dist/pc/src/resource/default/250-182.png?_v=20190612101938bdd
# https://s1.ljcdn.com/matrix_lianjia_pc/dist/pc/src/resource/default/250-182.png?_v=20190612101938bdd
# https://s1.ljcdn.com/matrix_lianjia_pc/dist/pc/src/resource/default/250-182.png?_v=20190612101938bdd
# https://s1.ljcdn.com/matrix_lianjia_pc/dist/pc/src/resource/default/250-182.png?_v=20190612101938bdd
# https://s1.ljcdn.com/matrix_lianjia_pc/dist/pc/src/resource/default/250-182.png?_v=20190612101938bdd
# ...
