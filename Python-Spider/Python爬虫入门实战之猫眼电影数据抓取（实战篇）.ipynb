# %% [markdown]
# ## Python爬虫入门实战之猫眼电影数据抓取（实战篇）

# %% [markdown]
# ## **静态网页实战**
#
# 本节我们将为大家展现一个完整爬虫的大致过程，此次项目内容为提取猫眼电影TOP100榜中的所有电影信息并存储至CSV文件中，其首页地址为[http://maoyan.com/board/4](https://link.zhihu.com/?target=http%3A//maoyan.com/board/4)，在3.2.2中我们已经获取过第一页中的所有电影名了，但是如何获取第二页、第三页的数据呢，即获取第二页第三页对应的URL，那么我们可以在浏览器中不断翻页寻找地址栏中URL的变化规律：
#
# ```language-text
# 第二页： http://maoyan.com/board/4?offset=10
# 第三页： http://maoyan.com/board/4?offset=20
# 第四页： http://maoyan.com/board/4?offset=30
# ......
# ```
#
# 我们看见URL的改变规律就是参数offset值不断偏移，每页偏移的值为10，由此我们可以编写一个获取每页数据函数，接收参数就是页码数：

# %%
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
}

# 偏移参数，默认为0，即为第一页
params = {
    'offset': 0
}
def get_html(page):
    '''
    获取一页html页面
    :param page: 页数
    :return: 该页html页面
    '''
    params['offset'] = page * 10
    url = 'http://maoyan.com/board/4'
    try:
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            html = response.text
            return html
        else:
            return -1
    except:
        return None

# %% [markdown]
# 当我们获取到html页面后，就可以提取相应的电影信息了，比如榜单张每一项电影都会有的属性：电影名称，主演，上映时间，评分等信息。提取信息有多种方式，下面我们利用正则表达式提取电影信息：

# %%
def parse_infor(html):
    '''
    提取html页面中的电影信息
    :param html: html页面
    :return: 电影信息列表
    '''
    # 编写正则字符串规则，提取 电影名，主演，上映时间，评分信息
    pat = re.compile('<div class="movie-item-info">.*?<p.*?><a.*?>(.*?)</a></p>.*?<p.*?>(.*?)</p>.*?<p.*?>(.*?)</p>.*?</div>.*?<div.*?>.*?<p.*?><i.*?>(.*?)</i><i.*?>(.*?)</i></p>.*?</div>.*?</div>.*?</div>', re.S)
    # 得到一个二重列表
    results = re.findall(pat, html)
    one_page_film = []
    if results:
        for result in results:
            film_dict = {}
            # 获取电影名信息
            film_dict['name'] = result[0]
            # 获取主演信息
            start = result[1]
            # 替换字符串中的 '\n' 字符，即换行字符
            start.replace('\n', '')
            # 去掉字符串两边的空格，并使用切片去除字符串开头的'主演：'三个字符
            start = start.strip()[3:]
            film_dict['start'] = start
            # 获取上映时间信息
            releasetime = result[2]
            # 使用切片去除字符串开头的'上映时间：'五个字符
            releasetime = releasetime[5:]
            film_dict['releasetime'] = releasetime
            # 获取评分信息，由于评分是有两个字符拼接的，这里我们提取后也需要进行拼接操作
            left_half =result[3]
            right_half = result[4]
            score = left_half + right_half
            film_dict['score'] = score
            # 打印该电影信息：
            print(film_dict)
            # 将该电影信息字典存入一页电影列表中
            one_page_film.append(film_dict)
        return one_page_film
    else:
        return None

# %% [markdown]
# 不熟悉正则读者要好好复习下前面的知识，虽然正则写起来可能会麻烦些，当时他的提取效率是最高的，接下来我们就可以将提取好的电影信息进行存储操作，这里我们存储为CSV文件：

# %%
def save_infor(one_page_film):
    '''
    存储提取好的电影信息
    :param html: 电影信息列表
    :return: None
    '''
    with open('top_film.csv', 'a', newline='') as f:
        csv_file = csv.writer(f)
        for one in one_page_film:
            csv_file.writerow([one['name'], one['start'], one['releasetime'], one['score']])

# %% [markdown]
# 以上是获取一页html页面并提取电影信息存储至CSV中的过程，接下来我们构造十页的URL便可以完成猫眼电影TOP100榜中的所有电影信息的获取和存储了，以下是完整程序：

# %%
import requests
import re
import csv
import time

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
}
params = {
    'offset': 0
}


def get_html(page):
    '''
    获取一页html页面
    :param page: 页数
    :return: 该页html页面
    '''
    params['offset'] = page * 10
    url = 'http://maoyan.com/board/4'
    try:
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            html = response.text
            return html
        else:
            return -1
    except:
        return None


def parse_infor(html):
    '''
    提取html页面中的电影信息
    :param html: html页面
    :return: 电影信息列表
    '''
    pat = re.compile('<div class="movie-item-info">.*?<p.*?><a.*?>(.*?)</a></p>.*?<p.*?>(.*?)</p>.*?<p.*?>(.*?)</p>.*?</div>.*?<div.*?>.*?<p.*?><i.*?>(.*?)</i><i.*?>(.*?)</i></p>.*?</div>.*?</div>.*?</div>', re.S)
    results = re.findall(pat, html)
    one_page_film = []
    if results:
        for result in results:
            film_dict = {}
            # 获取电影名信息
            film_dict['name'] = result[0]
            # 获取主演信息
            start = result[1]
            # 替换字符串中的 '\n' 字符，即换行字符
            start.replace('\n', '')
            # 去掉字符串两边的空格，并使用切片去除字符串开头的'主演：'三个字符
            start = start.strip()[3:]
            film_dict['start'] = start
            # 获取上映时间信息
            releasetime = result[2]
            # 使用切片去除字符串开头的'上映时间：'五个字符
            releasetime = releasetime[5:]
            film_dict['releasetime'] = releasetime
            # 获取评分信息
            left_half =result[3]
            right_half = result[4]
            score = left_half + right_half
            film_dict['score'] = score
            # 打印该电影信息：
            print(film_dict)
            # 将该电影信息字典存入一页电影列表中
            one_page_film.append(film_dict)
        return one_page_film
    else:
        return None


def save_infor(one_page_film):
    '''
    存储提取好的电影信息
    :param one_page_film: 电影信息列表
    :return: None
    '''
    with open('top_film.csv', 'a', newline='', errors='ignore') as f:
        csv_file = csv.writer(f)
        for one in one_page_film:
            csv_file.writerow([one['name'], one['start'], one['releasetime'], one['score']])

if __name__ == "__main__":
    # 利用循环构建页码
    for page in range(10):
        # 请求页面
        html = get_html(page)
        if html:
            # 提取信息
            one_page_film = parse_infor(html)
            if one_page_film:
                # 存储信息
                save_infor(one_page_film)
        time.sleep(1)
# Out:
# {'name': '霸王别姬', 'start': '张国荣,张丰毅,巩俐', 'releasetime': '1993-01-01', 'score': '9.5'}
# {'name': '肖申克的救赎', 'start': '蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿', 'releasetime': '1994-09-10(加拿大)', 'score': '9.5'}
# {'name': '罗马假日', 'start': '格利高里·派克,奥黛丽·赫本,埃迪·艾伯特', 'releasetime': '1953-09-02(美国)', 'score': '9.1'}
# {'name': '这个杀手不太冷', 'start': '让·雷诺,加里·奥德曼,娜塔莉·波特曼', 'releasetime': '1994-09-14(法国)', 'score': '9.5'}
# {'name': '泰坦尼克号', 'start': '莱昂纳多·迪卡普里奥,凯特·温丝莱特,比利·赞恩', 'releasetime': '1998-04-03', 'score': '9.5'}
# {'name': '唐伯虎点秋香', 'start': '周星驰,巩俐,郑佩佩', 'releasetime': '1993-07-01(中国香港)', 'score': '9.1'}
# {'name': '魂断蓝桥', 'start': '费雯·丽,罗伯特·泰勒,露塞尔·沃特森', 'releasetime': '1940-05-17(美国)', 'score': '9.2'}
# {'name': '乱世佳人', 'start': '费雯·丽,克拉克·盖博,奥利维娅·德哈维兰', 'releasetime': '1939-12-15(美国)', 'score': '9.1'}
# {'name': '天空之城', 'start': '寺田农,鹫尾真知子,龟山助清', 'releasetime': '1992', 'score': '9.1'}
# {'name': '辛德勒的名单', 'start': '连姆·尼森,拉尔夫·费因斯,本·金斯利', 'releasetime': '1993-12-15(美国)', 'score': '9.2'}
# {'name': '喜剧之王', 'start': '周星驰,莫文蔚,张柏芝', 'releasetime': '1999-02-13(中国香港)', 'score': '9.1'}
# {'name': '大闹天宫', 'start': '邱岳峰,毕克,富润生', 'releasetime': '1965-12-31', 'score': '9.0'}
# {'name': '音乐之声', 'start': '朱莉·安德鲁斯,克里斯托弗·普卢默,埃琳诺·帕克', 'releasetime': '1965-03-02(美国)', 'score': '9.0'}
# {'name': '春光乍泄', 'start': '张国荣,梁朝伟,张震', 'releasetime': '1997-05-30(中国香港)', 'score': '9.2'}
# {'name': '剪刀手爱德华', 'start': '约翰尼·德普,薇诺娜·瑞德,黛安·韦斯特', 'releasetime': '1990-12-06(美国)', 'score': '8.8'}
# {'name': '美丽人生', 'start': '罗伯托·贝尼尼,尼可莱塔·布拉斯基,乔治·坎塔里尼', 'releasetime': '1997-12-20(意大利)', 'score': '9.3'}
# {'name': '海上钢琴师', 'start': '蒂姆·罗斯,普路特·泰勒·文斯,比尔·努恩', 'releasetime': '1998-10-28(意大利)', 'score': '9.2'}
# {'name': '黑客帝国', 'start': '基努·里维斯,凯瑞-安·莫斯,劳伦斯·菲什伯恩', 'releasetime': '2000-01-14', 'score': '9.0'}
# {'name': '指环王3：王者无敌', 'start': '伊莱贾·伍德,伊恩·麦克莱恩,丽芙·泰勒', 'releasetime': '2004-03-15', 'score': '9.2'}
# {'name': '哈利·波特与魔法石', 'start': '丹尼尔·雷德克里夫,鲁伯特·格林特,艾玛·沃特森', 'releasetime': '2002-01-26', 'score': '9.1'}
# {'name': '蝙蝠侠：黑暗骑士', 'start': '克里斯蒂安·贝尔,希斯·莱杰,阿伦·伊克哈特', 'releasetime': '2008-07-18(美国)', 'score': '9.3'}
# {'name': '楚门的世界', 'start': '金·凯瑞,劳拉·琳妮,诺亚·艾默里奇', 'releasetime': '1998-06-01(美国)', 'score': '8.9'}
# {'name': '加勒比海盗', 'start': '约翰尼·德普,凯拉·奈特莉,奥兰多·布鲁姆', 'releasetime': '2003-11-21', 'score': '8.9'}
# {'name': '射雕英雄传之东成西就', 'start': '张国荣,梁朝伟,张学友', 'releasetime': '1993-02-05(中国香港)', 'score': '8.9'}
# {'name': '无间道', 'start': '刘德华,梁朝伟,黄秋生', 'releasetime': '2003-09-05', 'score': '9.1'}
# {'name': '教父2', 'start': '阿尔·帕西诺,罗伯特·德尼罗,黛安·基顿', 'releasetime': '1974-12-12(美国)', 'score': '9.0'}
# {'name': '机器人总动员', 'start': '本·贝尔特,艾丽莎·奈特,杰夫·格尔林', 'releasetime': '2008-06-27(美国)', 'score': '9.3'}
# {'name': '指环王1：护戒使者', 'start': '伊莱贾·伍德,伊恩·麦克莱恩,丽芙·泰勒', 'releasetime': '2002-04-04', 'score': '9.0'}
# {'name': '指环王2：双塔奇兵', 'start': '伊莱贾·伍德,伊恩·麦克莱恩,丽芙·泰勒', 'releasetime': '2003-04-25', 'score': '9.1'}
# {'name': '狮子王', 'start': '马修·布罗德里克,尼基塔·卡兰姆,詹姆斯·厄尔·琼斯', 'releasetime': '1995-07-15', 'score': '8.8'}
# {'name': '天堂电影院', 'start': '菲利浦·诺瓦雷,赛尔乔·卡斯特利托,蒂兹亚娜·罗达托', 'releasetime': '1988-11-17(意大利)', 'score': '9.2'}
# {'name': '活着', 'start': '葛优,巩俐,牛犇', 'releasetime': '1994-05-18(法国)', 'score': '9.0'}
# {'name': '拯救大兵瑞恩', 'start': '汤姆·汉克斯,马特·达蒙,汤姆·塞兹摩尔', 'releasetime': '1998-11-13', 'score': '8.9'}
# {'name': '哈尔的移动城堡', 'start': '倍赏千惠子,木村拓哉,美轮明宏', 'releasetime': '2004-11-20(日本)', 'score': '9.0'}
# {'name': '忠犬八公的故事', 'start': 'Forest,理查·基尔,琼·艾伦', 'releasetime': '2010-03-12(英国)', 'score': '9.3'}
# {'name': '疯狂原始人', 'start': '尼古拉斯·凯奇,艾玛·斯通,瑞安·雷诺兹', 'releasetime': '2013-04-20', 'score': '9.5'}
# {'name': '盗梦空间', 'start': '莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特', 'releasetime': '2010-09-01', 'score': '9.2'}
# {'name': '幽灵公主', 'start': '松田洋治,石田百合子,田中裕子', 'releasetime': '1998-05-01', 'score': '8.9'}
# {'name': '东邪西毒', 'start': '张国荣,梁朝伟,刘嘉玲', 'releasetime': '1994-09-17', 'score': '8.8'}
# {'name': '阿凡达', 'start': '萨姆·沃辛顿,佐伊·索尔达娜,米歇尔·罗德里格兹', 'releasetime': '2010-01-04', 'score': '9.0'}
# {'name': '搏击俱乐部', 'start': '爱德华·哈里森·诺顿,布拉德·皮特,海伦娜·伯翰·卡特', 'releasetime': '1999-10-15(美国)', 'score': '8.8'}
# {'name': '风之谷', 'start': '岛本须美,永井一郎,坂本千夏', 'releasetime': '1992', 'score': '8.9'}
# {'name': 'V字仇杀队', 'start': '娜塔莉·波特曼,雨果·维文,斯蒂芬·瑞', 'releasetime': '2006-03-17(美国)', 'score': '8.8'}
# {'name': '十二怒汉', 'start': '亨利·方达,李·科布,马丁·鲍尔萨姆', 'releasetime': '1957-04-13(美国)', 'score': '9.1'}
# {'name': '当幸福来敲门', 'start': '威尔·史密斯,贾登·史密斯,坦迪·牛顿', 'releasetime': '2008-01-17', 'score': '8.9'}
# {'name': '驯龙高手', 'start': '杰伊·巴鲁切尔,杰拉德·巴特勒,亚美莉卡·费雷拉', 'releasetime': '2010-05-14', 'score': '9.0'}
# {'name': '速度与激情5', 'start': '范·迪塞尔,保罗·沃克,道恩·强森', 'releasetime': '2011-05-12', 'score': '9.2'}
# {'name': '放牛班的春天', 'start': '热拉尔·朱尼奥,让-巴蒂斯特·莫尼耶,玛丽·布奈尔', 'releasetime': '2004-10-16', 'score': '8.8'}
# {'name': '勇敢的心', 'start': '梅尔·吉布森,苏菲·玛索,帕特里克·麦高汉', 'releasetime': '1995-05-24(美国)', 'score': '8.8'}
# {'name': '神偷奶爸', 'start': '史蒂夫·卡瑞尔,杰森·席格尔,拉塞尔·布兰德', 'releasetime': '2010-07-09(美国)', 'score': '9.0'}
# {'name': '闻香识女人', 'start': '阿尔·帕西诺,克里斯·奥唐纳,加布里埃尔·安瓦尔', 'releasetime': '1992-12-23(美国)', 'score': '8.8'}
# {'name': '三傻大闹宝莱坞', 'start': '阿米尔·汗,黄渤,卡琳娜·卡普', 'releasetime': '2011-12-08', 'score': '9.1'}
# {'name': '断背山', 'start': '希斯·莱杰,杰克·吉伦哈尔,米歇尔·威廉姆斯', 'releasetime': '2006-01-13(美国)', 'score': '9.0'}
# {'name': '黑客帝国3：矩阵革命', 'start': '基努·里维斯,雨果·维文,凯瑞-安·莫斯', 'releasetime': '2003-11-05', 'score': '8.8'}
# {'name': '少年派的奇幻漂流', 'start': '苏拉·沙玛,伊尔凡·可汗,塔布', 'releasetime': '2012-11-22', 'score': '9.1'}
# {'name': '飞屋环游记', 'start': '爱德华·阿斯纳,乔丹·长井,鲍勃·彼德森', 'releasetime': '2009-08-04', 'score': '8.9'}
# {'name': '末代皇帝', 'start': '尊龙,陈冲,彼得·奥图尔', 'releasetime': '1987-10-23', 'score': '8.8'}
# {'name': '鬼子来了', 'start': '姜文,姜宏波,陈强', 'releasetime': '2000-05-12(法国戛纳)', 'score': '8.9'}
# {'name': '大话西游之月光宝盒', 'start': '周星驰,莫文蔚,吴孟达', 'releasetime': '2014-10-24', 'score': '9.6'}
# {'name': '怦然心动', 'start': '玛德琳·卡罗尔,卡兰·麦克奥利菲,艾丹·奎因', 'releasetime': '2010-08-06(美国)', 'score': '8.9'}
# {'name': '致命魔术', 'start': '休·杰克曼,克里斯蒂安·贝尔,迈克尔·凯恩', 'releasetime': '2006-10-20(美国)', 'score': '8.8'}
# {'name': '美丽心灵', 'start': '罗素·克洛,詹妮弗·康纳利,艾德·哈里斯', 'releasetime': '2001-12-21(美国)', 'score': '8.8'}
# {'name': '无敌破坏王', 'start': '约翰·C·赖利,萨拉·西尔弗曼,简·林奇', 'releasetime': '2012-11-06', 'score': '9.1'}
# {'name': '倩女幽魂', 'start': '张国荣,王祖贤,午马', 'releasetime': '2011-04-30', 'score': '9.2'}
# {'name': '夜访吸血鬼', 'start': '汤姆·克鲁斯,布拉德·皮特,克尔斯滕·邓斯特', 'releasetime': '1994-11-11(美国)', 'score': '8.8'}
# {'name': '蝙蝠侠：黑暗骑士崛起', 'start': '克里斯蒂安·贝尔,迈克尔·凯恩,加里·奥德曼', 'releasetime': '2012-08-27', 'score': '8.9'}
# {'name': '钢琴家', 'start': '艾德里安·布洛迪,艾米莉娅·福克斯,米哈乌·热布罗夫斯基', 'releasetime': '2002-09-25(法国)', 'score': '8.8'}
# {'name': '本杰明·巴顿奇事', 'start': '布拉德·皮特,凯特·布兰切特,塔拉吉·P·汉森', 'releasetime': '2008-12-25(美国)', 'score': '8.8'}
# {'name': '哈利·波特与死亡圣器（下）', 'start': '丹尼尔·雷德克里夫,鲁伯特·格林特,艾玛·沃特森', 'releasetime': '2011-08-04', 'score': '9.0'}
# {'name': '甜蜜蜜', 'start': '黎明,张曼玉,曾志伟', 'releasetime': '2015-02-13', 'score': '9.2'}
# {'name': '初恋这件小事', 'start': '马里奥·毛瑞尔,平采娜·乐维瑟派布恩,阿查拉那·阿瑞亚卫考', 'releasetime': '2012-06-05', 'score': '8.8'}
# {'name': '触不可及', 'start': '弗朗索瓦·克鲁塞,奥玛·希,安娜·勒尼', 'releasetime': '2011-11-02(法国)', 'score': '9.1'}
# {'name': '新龙门客栈', 'start': '张曼玉,梁家辉,甄子丹', 'releasetime': '2012-02-24', 'score': '8.8'}
# {'name': '熔炉', 'start': '孔刘,郑有美,金智英', 'releasetime': '2011-09-22(韩国)', 'score': '8.8'}
# {'name': '大话西游之大圣娶亲', 'start': '周星驰,朱茵,莫文蔚', 'releasetime': '2014-10-24', 'score': '8.8'}
# {'name': '小鞋子', 'start': '默罕默德·阿米尔·纳吉,Kamal Mirkarimi,Behzad Rafi', 'releasetime': '1999-01-22(美国)', 'score': '9.0'}
# {'name': '教父', 'start': '马龙·白兰度,阿尔·帕西诺,詹姆斯·肯恩', 'releasetime': '2015-04-18', 'score': '9.3'}
# {'name': '素媛', 'start': '李来,薛耿求,严志媛', 'releasetime': '2013-10-02(韩国)', 'score': '9.1'}
# {'name': '萤火之森', 'start': '内山昂辉,佐仓绫音,后藤弘树', 'releasetime': '2011-09-17(日本)', 'score': '9.0'}
# {'name': '穿条纹睡衣的男孩', 'start': '阿沙·巴特菲尔德,维拉·法梅加,大卫·休里斯', 'releasetime': '2008-09-12(英国)', 'score': '9.0'}
# {'name': '窃听风暴', 'start': '乌尔里希·穆埃,塞巴斯蒂安·科赫,马蒂娜·格德克', 'releasetime': '2006-03-23(德国)', 'score': '9.0'}
# {'name': '时空恋旅人', 'start': '瑞秋·麦克亚当斯,多姆纳尔·格里森,比尔·奈伊', 'releasetime': '2013-09-04(英国)', 'score': '8.9'}
# {'name': '7号房的礼物', 'start': '柳承龙,郑镇荣,朴信惠', 'releasetime': '2013-01-23(韩国)', 'score': '8.9'}
# {'name': '恐怖直播', 'start': '河正宇,李璟荣,李大为', 'releasetime': '2013-07-31(韩国)', 'score': '8.8'}
# {'name': '海豚湾', 'start': '里克·奥巴瑞,路易·西霍尤斯,哈迪·琼斯', 'releasetime': '2009-07-31(美国)', 'score': '8.9'}
# {'name': '忠犬八公物语', 'start': '仲代达矢,春川真澄,井川比佐志', 'releasetime': '1987-08-01(日本)', 'score': '9.0'}
# {'name': '上帝之城', 'start': '亚历桑德雷·罗德里格斯,艾莉丝·布拉加,莱安德鲁·菲尔米诺', 'releasetime': '2002-08-30(巴西)', 'score': '8.9'}
# {'name': '美国往事', 'start': '罗伯特·德尼罗,詹姆斯·伍兹,伊丽莎白·麦戈文', 'releasetime': '2015-04-23', 'score': '9.1'}
# {'name': '七武士', 'start': '三船敏郎,志村乔,千秋实', 'releasetime': '1954-04-26(日本)', 'score': '9.1'}
# {'name': '完美的世界', 'start': '凯文·科斯特纳,克林特·伊斯特伍德,T·J·劳瑟', 'releasetime': '1993-11-24(美国)', 'score': '8.9'}
# {'name': '一一', 'start': '吴念真,金燕玲,李凯莉', 'releasetime': '2000-09-20(法国)', 'score': '8.9'}
# {'name': '英雄本色', 'start': '狄龙,张国荣,周润发', 'releasetime': '2017-11-17', 'score': '9.2'}
# {'name': '阿飞正传', 'start': '张国荣,张曼玉,刘德华', 'releasetime': '2018-06-25', 'score': '8.8'}
# {'name': '爱·回家', 'start': '俞承豪,金艺芬,童孝熙', 'releasetime': '2002-04-05(韩国)', 'score': '9.0'}
# {'name': '海洋', 'start': '雅克·贝汉,姜文,兰斯洛特·佩林', 'releasetime': '2011-08-12', 'score': '9.0'}
# {'name': '我爱你', 'start': '宋在浩,李顺才,尹秀晶', 'releasetime': '2011-02-17(韩国)', 'score': '9.0'}
# {'name': '黄金三镖客', 'start': '克林特·伊斯特伍德,李·范·克里夫,埃里·瓦拉赫', 'releasetime': '1966-12-23(意大利)', 'score': '8.9'}
# {'name': '迁徙的鸟', 'start': '雅克·贝汉,Philippe Labro', 'releasetime': '2001-12-12(法国)', 'score': '9.1'}
# {'name': '龙猫', 'start': '秦岚,糸井重里,岛本须美', 'releasetime': '2018-12-14', 'score': '9.1'}
# {'name': '千与千寻', 'start': '柊瑠美,周冬雨,入野自由', 'releasetime': '2019-06-21', 'score': '9.3'}

# %% [markdown]
# ## **动态网页实战**
#
# 本节我们将爬取猫眼电影实时票房数据，学会在动态网页中获取我们想要的数据，首先打开[猫眼专业版-实时票房](https://link.zhihu.com/?target=https%3A//piaofang.maoyan.com/dashboard)， 其网址为：[https://piaofang.maoyan.com/dashboard](https://link.zhihu.com/?target=https%3A//piaofang.maoyan.com/dashboard)，然后我们可以看见现在的实时电影票房数据，可以看见 “今日实时” 的数据在不断地动态增加：
#
# ![](https://pic1.zhimg.com/80/v2-82455903df76cbbb44e487e91cfd9a8c_hd.jpg)
#
# 而当我们查看该网页源代码时，却并没有电影相关的票房等信息，那么可以判断该页面可能使用了Ajax(即“Asynchronous Javascript And XML”(异步 JavaScript 和 XML))技术，即动态网页(是指跟静态网页相对的一种网页编程技术。静态网页，随着html代码的生成，页面的内容和显示效果就基本上不会发生变化了——除非你修改页面代码。而动态网页则不然，页面代码虽然没有变，但是显示的内容却是可以随着时间、环境或者数据库操作的结果而发生改变)。我们可以利用浏览器的开发者工具进行分析：
#
# ![](https://pic1.zhimg.com/80/v2-9d22ff40ee256bec9520d1516d131d24_hd.jpg)
#
# 我们可以发现每隔一段时间都会有一个新的请求，其请求类型都为xhr，而Ajax的请求类型就是xhr，这请求可能就是实时更新的票房信息，而我们需要的数据可能就在这些文件里，于是我们选择一个进行分析：
#
# ![](https://pic4.zhimg.com/80/v2-e506b6a61e4cd00f1b45179d58c21007_hd.jpg)
#
# 在Preview中，我们可以看见大量的电影相关的信息，即我们想要获取的实时电影票房数据，而这些内容是JSON格式的，浏览器开发者工具自动做了解析方便我们查看，接下来我们只需要用Python模拟这些Ajax请求，拿下这些数据然后解析即可，而这些Ajax无非依然是HTTP请求，所以只要拿到对应URL然后使用Python模拟该请求即可，我们可以直接复制，如下图：
#
# ![](https://pic2.zhimg.com/80/v2-f72deac5d9c3d0c0fafb2c25fbc64879_hd.jpg)
#
# 获取到该请求的链接，接下来我们就用Python模拟该请求：

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
}


def get_html():
    '''
    获取JSON文件
    :return: JSON格式的数据
    '''
    # 请求second.json的URL
    url = 'https://box.maoyan.com/promovie/api/box/second.json'
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            # 由于是JSON文件，我们可以返回JSON格式的数据便于后续提取
            return response.json()
        else:
            return -1
    except:
        return None

# %% [markdown]
# 获取对应的JSON数据后，我们就可以利用进行提取操作了。

# %%
def parse_infor(json):
    '''
    从JSON数据中提取电影票房数据，包括：电影名，上映信息，综合票房，票房占比，累计票房
    :param json: JSON格式的数据
    :return: 每次循环返回一次字典类型的电影数据
    '''
    if json:
        # 利用json中的get()方法层层获取对应的信息
        items = json.get('data').get('list')
        for item in items:
            piaofang = {}
            piaofang['电影名'] = item.get('movieName')
            piaofang['上映信息'] = item.get('releaseInfo')
            piaofang['综合票房'] = item.get('boxInfo')
            piaofang['票房占比'] = item.get('boxRate')
            piaofang['累计票房'] = item.get('sumBoxInfo')
            # 利用生成器每次循环都返回一个数据
            yield piaofang
    else:
        return None

# %% [markdown]
# 读者可能看见我们没有使用常规的return进行函数返回，而是使用了生成器，这样就能每次循环都返回一次数据，具体读者可以[生成器 | 廖雪峰的官方网站](https://link.zhihu.com/?target=https%3A//www.liaoxuefeng.com/wiki/0014316089557264a6b348958f449949df42a6d3a2e542c000/0014317799226173f45ce40636141b6abc8424e12b5fb27000)进一步了解学习，接下来我们就将提取好的票房信息存储为格式化的HTML文件：

# %%
def save_infor(results):
    '''
    存储格式化的电影票房数据HTML文件
    :param results: 电影票房数据的生成器
    :return: None
    '''
    rows = ''
    for piaofang in results:
        # 利用Python中的format字符串填充html表格中的内容
        row = '<tr><td>{}</td><td>{}</td><td>{}</td><td>{}</td><td>{}</td></tr>'.format(piaofang['电影名'],
                                                                                        piaofang['上映信息'],
                                                                                        piaofang['综合票房'],
                                                                                        piaofang['票房占比'],
                                                                                        piaofang['累计票房'])
        # 利用字符串拼接循环存储每个格式化的电影票房信息
        rows = rows + '\n' + row
    # 利用字符串拼接处格式化的HTML页面
    piaofang_html = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>电影票房</title>

</head>
<body>
    <style>
    .table1_5 table {
        width:100%;
        margin:15px 0
    }
    .table1_5 th {
        background-color:#00BFFF;
        color:#FFFFFF
    }
    .table1_5,.table1_5 th,.table1_5 td
    {
        font-size:0.95em;
        text-align:center;
        padding:4px;
        border:1px solid #dddddd;
        border-collapse:collapse
    }
    .table1_5 tr:nth-child(odd){
        background-color:#aae9fe;
    }
    .table1_5 tr:nth-child(even){
        background-color:#fdfdfd;
    }
    </style>
    <table class='table1_5'>
    <tr>
    <th>电影名</th>
    <th>上映信息</th>
    <th>综合票房</th>
    <th>票房占比</th>
    <th>累计票房</th>
    </tr>
    ''' + rows + '''
    </table>
</body>
</html>
    '''
    # 存储已经格式化的html页面
    with open('piaofang.html', 'w', encoding='utf-8') as f:
        f.write(piaofang_html)

# %% [markdown]
# 我们将以上过程整合，即可得到完整的票房数据获取的代码实例：

# %%
import requests

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
}


def get_html():
    '''
    获取JSON文件
    :return: JSON格式的数据
    '''
    # 请求second.json的URL
    url = 'https://box.maoyan.com/promovie/api/box/second.json'
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            # 由于是JSON文件，我们可以返回JSON格式的数据便于后续提取
            return response.json()
        else:
            return -1
    except:
        return None


def parse_infor(json):
    '''
    从JSON数据中提取电影票房数据，包括：电影名，上映信息，综合票房，票房占比，累计票房
    :param json: JSON格式的数据
    :return: 每次循环返回一次字典类型的电影数据
    '''
    if json:
        # 利用json中的get()方法层层获取对应的信息
        items = json.get('data').get('list')
        for item in items:
            piaofang = {}
            piaofang['电影名'] = item.get('movieName')
            piaofang['上映信息'] = item.get('releaseInfo')
            piaofang['综合票房'] = item.get('boxInfo')
            piaofang['票房占比'] = item.get('boxRate')
            piaofang['累计票房'] = item.get('sumBoxInfo')
            # 利用生成器每次循环都返回一个数据
            yield piaofang
    else:
        return None


def save_infor(results):
    '''
    存储格式化的电影票房数据HTML文件
    :param results: 电影票房数据的生成器
    :return: None
    '''
    rows = ''
    for piaofang in results:
        # 利用Python中的format字符串填充html表格中的内容
        row = '<tr><td>{}</td><td>{}</td><td>{}</td><td>{}</td><td>{}</td></tr>'.format(piaofang['电影名'],
                                                                                        piaofang['上映信息'],
                                                                                        piaofang['综合票房'],
                                                                                        piaofang['票房占比'],
                                                                                        piaofang['累计票房'])
        # 利用字符串拼接循环存储每个格式化的电影票房信息
        rows = rows + '\n' + row
    # 利用字符串拼接处格式化的HTML页面
    piaofang_html = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>电影票房</title>

</head>
<body>
    <style>
    .table1_5 table {
        width:100%;
        margin:15px 0
    }
    .table1_5 th {
        background-color:#00BFFF;
        color:#FFFFFF
    }
    .table1_5,.table1_5 th,.table1_5 td
    {
        font-size:0.95em;
        text-align:center;
        padding:4px;
        border:1px solid #dddddd;
        border-collapse:collapse
    }
    .table1_5 tr:nth-child(odd){
        background-color:#aae9fe;
    }
    .table1_5 tr:nth-child(even){
        background-color:#fdfdfd;
    }
    </style>
    <table class='table1_5'>
    <tr>
    <th>电影名</th>
    <th>上映信息</th>
    <th>综合票房</th>
    <th>票房占比</th>
    <th>累计票房</th>
    </tr>
    ''' + rows + '''
    </table>
</body>
</html>
    '''
    # 存储已经格式化的html页面
    with open('piaofang.html', 'w', encoding='utf-8') as f:
        f.write(piaofang_html)


if __name__ == "__main__":
    # 获取信息
    json = get_html()
    # 提取信息
    results = parse_infor(json)
    # 存储信息
    save_infor(results)

# %% [markdown]
# 可以看见，动态网页的爬虫可能会更加简单些，关键就在于找到对应的XHR格式的请求，而一般这种格式的文件都是JSON格式的，提取相对也会更加简单方便，而读者可能会问为何要把这个信息存储为HTML文件格式的呢，喜欢电影的读者可能会经常打开猫眼电影查看每天的电影票房数据，何不尝试将我们所学的爬虫知识运用起来制作一个定时爬取电影票房数据并推送至个人邮箱的爬虫小程序呢，这样就省得我们每天打开网页查看，让数据主动为我们服务，也算是学习致用了吧，感兴趣的读者可以自己尝试下，下图笔者根据这个爬虫程序扩展每天收到的实时票房信息邮件，每天定时爬取推送给笔者，列表内容如下图所示：
