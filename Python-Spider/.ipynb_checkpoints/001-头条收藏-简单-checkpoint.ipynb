# %%
# https://2.python-requests.org//zh_CN/latest/user/quickstart.html
import requests


target = "https://www.toutiao.com/c/user/favourite/?page_type=2&user_id=3130526840&max_behot_time=0&count=20&as=A1452D71CDDA2B3&cp=5D1D6AB28B634E1&_signature=y9m1TBATls0ln-oHXrxVNsvZtV&max_repin_time=0"


headers = {
"accept":"application/json, text/javascript",
"accept-encoding":"gzip, deflate, br",
"accept-language":"zh-CN,zh;q=0.9,en;q=0.8,id;q=0.7,ru;q=0.6,fil;q=0.5,ja;q=0.4,vi;q=0.3",
"cache-control":"no-cache",
"content-type":"application/x-www-form-urlencoded",
"cookie":'tt_webid=6677038314707420686; WEATHER_CITY=%E5%8C%97%E4%BA%AC; UM_distinctid=169f6859c74558-0e2ae529445bc1-12376d51-1fa400-169f6859c75782; tt_webid=6677038314707420686; csrftoken=fec3a59243d8173158dddde2fd720979; login_flag=79136a12a6234c55616de2b459973ee8; __tea_sdk__ssid=undefined; uuid="w:5cac3c42201348b390e47bafa0ce842f"; ccid=a630215e111e0f21f6798069fcc5b99e; sessionid=f173721b9fd5e342ad439b859dbc06c7; _ga=GA1.2.1687675999.1558491099; s_v_web_id=25e87504dd912e998132882ec4805688; sid_guard=f173721b9fd5e342ad439b859dbc06c7%7C1560144122%7C2591510%7CWed%2C+10-Jul-2019+05%3A13%3A52+GMT; sid_tt=f173721b9fd5e342ad439b859dbc06c7; CNZZDATA1259612802=282182321-1554615356-%7C1562219091; __tasessionId=wtf2lxnz51562221052133',
"dnt":"1",
"pragma":"no-cache",
"referer":"https://www.toutiao.com/c/user/3130526840/",
"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36",
"x-requested-with":"XMLHttpRequest"
}
# 获取页面源码
responseFromNetwork = requests.get(target, headers=headers)


# 解析页面源码
print(responseFromNetwork.text)
# Out:
# {"has_more": true, "message": "success", "data": [{"single_mode": null, "abstract": "\u4e2d\u56fd\u79fb\u52a8\u4e92\u8054\u7f51\u7ecf\u5386\u8fc7\u53bb10\u5e74\u53d1\u5c55\uff0c\u8fd1\u4e4e\u5b8c\u7f8e\u5730\u5c06\u5341\u4ebf\u8ba1\u7528\u6237\u4f7f\u7528\u4e60\u60ef\u57f9\u517b\u8d77\u6765\uff0c\u5c24\u5176\u662f\u6d88\u8d39\u4e92\u8054\u7f51\uff0c\u66f4\u662f\u88ab\u5f00\u57a6\u6210\u4e86\u4e00\u5757\u513f\u5546\u4e1a\u719f\u571f\uff0c\u76f4\u81f3\u8fd1\u5e74\u6108\u53d1\u660e\u663e\u5730\u51fa\u73b0\u7528\u6237\u7ea2\u5229\u89e6\u9876\u3001\u96be\u4ee5\u518d\u73b0\u7206\u53d1\u5f0f\u589e\u957f\u7684\u53ef\u80fd\u3002", "image_list": [], "more_mode": false, "tag": "news_tech", "tag_url": "news_tech", "repin_time": 1562218701, "title": "\u79fb\u52a8\u4e92\u8054\u7f51\u7ed3\u675f \u5c0f\u7a0b\u5e8f\u4e92\u8054\u7f51\u5f00\u542f", "has_video": false, "chinese_tag": "\u79d1\u6280", "source": "\u4ebf\u90a6\u52a8\u529b\u7f51", "group_source": 2, "comments_count": 2, "composition": 8, "me
# ...
