# %%
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
import requests
import os
import time
import re
 
if __name__ == '__main__':
    
    # 定义一个[]列表用来保存
    
    list_url = []
    
    # 循环，78，79
    
    for num in range(78,80):
        if num == 1:
            url = 'http://jandan.net/ooxx'
        else:
            # http://jandan.net/ooxx/page-78#comments
            url = 'http://jandan.net/ooxx/page-%d#comments' % num # 格式化
        headers = {
            "User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
        }
        
        # 使用GET方法去抓取网页上的内容
        req = requests.get(url = url,headers = headers)
        
        req.encoding = 'utf-8'
        # 输出网页上的内容
        html = req.text
        
        
        # print(html)
        
        
        bf = BeautifulSoup(html, 'lxml')
        
        print(bf)
        
        # 找到页面中所有的 view_img_link
        targets_url = bf.find_all('a',attrs={'class':'view_img_link'}) # view_img_link

        print(len(targets_url))
        print(targets_url)
        
        
        for each in targets_url:
            print(each)
            list_url.append('http://'+each.get('href').replace('//',''))
 
    print('得到列表')
    print(list_url)
 
    for target_url in list_url:
 
        filename = ''+str(time.localtime())+'.jpg'
 
 
        headers = {
            "User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
        }
        img_req = requests.get(url = target_url,headers = headers)
        img_req.encoding = 'utf-8'
        img_html = img_req.text
        img_bf = BeautifulSoup(img_html, 'lxml')
 
 
        if 'images' not in os.listdir():
            os.makedirs('images')
        urlretrieve(url = target_url,filename = 'images/'+ filename )
        time.sleep(1)
 
    print('下载完成！')
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="zh">
# <head>
# <!-- BEGIN html head -->
# <title>
# 随手拍 - 分享经典一刻
# </title>
# <meta content="never" name="referrer"/> <meta content="随手拍,身边的趣图,手机摄影,经典一刻" name="keywords"/>
# <meta content="大家手机相册里应该有不少有趣的图片，欢迎发到这里，分享你的经典一刻。" name="description"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="webkit" name="renderer"/>
# <meta content="_top" http-equiv="Window-target"/>
# <meta content="9wC0PEtTmEqSNlOk" name="baidu-site-verification"/>
# <meta content="format=html5; url=//i.jandan.net/ooxx" http-equiv="mobile-agent"/>
# <meta content="index,follow" name="robots"/>
# <link href="//cdn.jandan.net/static/min/33f503276beb2cd40149e2feddc06228gz036zat.10100002.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//cdn.jandan.net/static/img/appicon.png" rel="apple-touch-icon"/>
# ...
