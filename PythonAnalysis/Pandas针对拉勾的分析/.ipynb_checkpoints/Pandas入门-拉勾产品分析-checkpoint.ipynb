# %%
import pandas as pd 
import numpy as np
pd.__version__
# Out:
# '1.0.3'

# %% [markdown]
# 1. 通过技术手段，比喻说爬虫得到数据
# 2. 分析可以进行研究的方向
# 3. 通过数据分组，数据的清洗，数据的整理，得到一个可以被分析的数据集
# 4. 通过数据分析的相关的方法，进行数据的分析工作
# 5. 得到一些数据的结果的呈现，（仅仅需要数据集的表格化展现）
# 6. 通过数据可视化的操作，对第五步的结果进行展现
# 7. 将以上的过程，进行报告化（网页原型）

# %% [markdown]
# # 读入文件

# %%
dataFrameForProduct = pd.read_excel("产品.xls") # 载入文件

# %%
# info函数返回有哪些列、有多少非缺失值、每列的类型
dataFrameForProduct.info() # 整个DF的信息，仔细观察，发现了什么问题没有
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2653 entries, 0 to 2652
# Data columns (total 36 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   网站名称         2653 non-null   object
#  1   对应的搜索关键词     2653 non-null   object
#  2   搜索条件         2653 non-null   object
#  3   职位 ID        2653 non-null   int64
#  4   职位网址         2653 non-null   object
#  5   公司名称         2653 non-null   object
#  6   领域           2653 non-null   object
#  7   发展阶段         2653 non-null   object
#  8   投资机构         572 non-null    object
#  9   公司规模         2653 non-null   object
#  10  公司网址         2653 non-null   object
#  11  职位名称         2653 non-null   object
#  12  标签列表         2653 non-null   object
#  13  职位描述         2653 non-null   object
#  14  薪资范围         2653 non-null   object
#  15  经验要求         2653 non-null   object
#  16  学历要求         2653 non-null   object
#  17  工作性质         2653 non-null   object
# ...

# %%
# describe默认统计数值型数据的各个统计量
dataFrameForProduct.describe() # 描述信息
# Out:
#               职位 ID       最低薪资/k       平均薪资/k       最高薪资/k
# count  2.653000e+03  2653.000000  2653.000000  2653.000000
# mean   6.335620e+06    15.263475    20.619864    25.976253
# std    8.521579e+05     9.904004    13.145331    16.632093
# min    2.654930e+05     1.000000     1.500000     2.000000
# 25%    6.245654e+06     8.000000    11.500000    14.000000
# 50%    6.684678e+06    15.000000    19.000000    25.000000
# 75%    6.809075e+06    20.000000    27.500000    35.000000
# max    6.870833e+06    90.000000   115.000000   150.000000

# %%
# 可以自行选择分位数
dataFrameForProduct.describe(percentiles=[.05, .25, .75, .95])
# Out:
#               职位 ID       最低薪资/k       平均薪资/k       最高薪资/k
# count  2.653000e+03  2653.000000  2653.000000  2653.000000
# mean   6.335620e+06    15.263475    20.619864    25.976253
# std    8.521579e+05     9.904004    13.145331    16.632093
# min    2.654930e+05     1.000000     1.500000     2.000000
# 5%     4.400906e+06     3.000000     4.000000     5.000000
# 25%    6.245654e+06     8.000000    11.500000    14.000000
# 50%    6.684678e+06    15.000000    19.000000    25.000000
# 75%    6.809075e+06    20.000000    27.500000    35.000000
# 95%    6.861474e+06    35.000000    45.000000    60.000000
# max    6.870833e+06    90.000000   115.000000   150.000000

# %%
dataFrameForProduct['公司规模'].describe() # 对于非数值型也可以用describe函数
# Out:
# count        2653
# unique          7
# top       2000人以上
# freq          613
# Name: 公司规模, dtype: object

# %%
dataFrameForProduct['职位 ID'].idxmax() # idxmax函数返回最大值所在索引，在某些情况下特别适用，idxmin功能类似
# Out:
# 1387

# %%
dataFrameForProduct['职位 ID'].nlargest(3) # nlargest函数返回前几个大的元素值，nsmallest功能类似
# Out:
# 1387    6870833
# 2020    6870733
# 240     6870709
# Name: 职位 ID, dtype: int64

# %%
dataFrameForProduct['职位 ID'].head(10) # clip和replace是两类替换函数
# Out:
# 0    6793134
# 1    6362305
# 2    6831533
# 3    4878943
# 4    6210428
# 5    6856576
# 6    5627648
# 7    6863462
# 8    6868962
# 9    6863150
# Name: 职位 ID, dtype: int64

# %%
dataFrameForProduct['职位 ID'].clip(5627650,6863462).head(8) # clip是对超过或者低于某些值的数进行截断
# Out:
# 0    6793134
# 1    6362305
# 2    6831533
# 3    5627650
# 4    6210428
# 5    6856576
# 6    5627650
# 7    6863462
# Name: 职位 ID, dtype: int64

# %%
dataFrameForProduct['发展阶段'].head()
# Out:
# 0      未融资
# 1       A轮
# 2       B轮
# 3    不需要融资
# 4     上市公司
# Name: 发展阶段, dtype: object

# %%
dataFrameForProduct['发展阶段'].replace(['未融资'],['没有拉到投资']).head() # replace是对某些值进行替换
# Out:
# 0    没有拉到投资
# 1        A轮
# 2        B轮
# 3     不需要融资
# 4      上市公司
# Name: 发展阶段, dtype: object

# %%
dataFrameForProduct['职位 ID'] # 获取某一列
# Out:
# 0       6793134
# 1       6362305
# 2       6831533
# 3       4878943
# 4       6210428
#          ...
# 2648    6645804
# 2649    6743841
# 2650    6068624
# 2651    6843241
# 2652    6723168
# Name: 职位 ID, Length: 2653, dtype: int64

# %%
dataFrameForProduct.select_dtypes(include=['number']).head() # 根据类型来选择列
# Out:
#      职位 ID  最低薪资/k  平均薪资/k  最高薪资/k
# 0  6793134      15    22.5      30
# 1  6362305      20    27.5      35
# 2  6831533       8    12.0      16
# 3  4878943      10    15.0      20
# 4  6210428      25    35.0      45

# %%
dataFrameForProduct.select_dtypes(include=['float']).head() # 根据类型来选择列
# Out:
#    平均薪资/k
# 0    22.5
# 1    27.5
# 2    12.0
# 3    15.0
# 4    35.0

# %%
dataFrameForProduct.head()
# Out:
#   网站名称 对应的搜索关键词                                               搜索条件    职位 ID  \
# 0   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6793134
# 1   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6362305
# 2   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6831533
# 3   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  4878943
# 4   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6210428
#
#                                       职位网址           公司名称          领域   发展阶段  \
# 0  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育    未融资
# 1  https://www.lagou.com/jobs/6362305.html            自如网        房产家居     A轮
# 2  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活     B轮
# 3  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务  不需要融资
# 4  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏   上市公司
#
#                       投资机构       公司规模  ...  \
# ...

# %%
dataFrameForProduct.tail()
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 2648   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2649   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2650   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2651   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2652   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#         职位 ID                                     职位网址          公司名称     领域  \
# 2648  6645804  https://www.lagou.com/jobs/6645804.html  北京领创智信科技有限公司  移动互联网
# 2649  6743841  https://www.lagou.com/jobs/6743841.html           博纳德  移动互联网
# 2650  6068624  https://www.lagou.com/jobs/6068624.html          龙湖集团     其他
# 2651  6843241  https://www.lagou.com/jobs/6843241.html           千喜鹤   消费生活
# 2652  6723168  https://www.lagou.com/jobs/6723168.html         慧泊金科技  移动互联网
#
#       发展阶段                                               投资机构       公司规模  ...  \
# ...

# %%
dataFrameForProduct.head(3)
# Out:
#   网站名称 对应的搜索关键词                                               搜索条件    职位 ID  \
# 0   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6793134
# 1   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6362305
# 2   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6831533
#
#                                       职位网址           公司名称          领域 发展阶段  \
# 0  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育  未融资
# 1  https://www.lagou.com/jobs/6362305.html            自如网        房产家居   A轮
# 2  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活   B轮
#
#                       投资机构      公司规模  ...  \
# 0                      NaN    15-50人  ...
# 1                      NaN   2000人以上  ...
# 2  隆领资本、华泽资本、华映资本、松柏资本(A轮)  150-500人  ...
#
#                                  职位诱惑统计词  \
# 0      ['奖励', '奉献者', '贡献者', '欢迎', '有识者']
# 1                   ['年底', '双薪', '绩效奖金']
# 2  ['高速', '发展', '行业', '福利', '齐全', '年终奖']
#
# ...

# %%
dataFrameForProduct['职位 ID'].count() # count返回非缺失值元素个数
# Out:
# 2653

# %%
dataFrameForProduct['职位ID'].count() # count返回非缺失值元素个数

# %%
dataFrameForProduct['职位 ID'].value_counts() # value_counts返回每个元素有多少个
# Out:
# 6826069    2
# 6499275    2
# 5397000    2
# 5483057    2
# 6685447    2
#           ..
# 6484695    1
# 6819199    1
# 6849237    1
# 6413012    1
# 6805897    1
# Name: 职位 ID, Length: 2620, dtype: int64

# %%
dataFrameForProduct['职位 ID'].unique() # unique显示所有的唯一值
# Out:
# array([6793134, 6362305, 6831533, ..., 6068624, 6843241, 6723168])

# %%
dataFrameForProduct['职位 ID'].nunique() # nunique显示有多少个唯一值
# Out:
# 2620

# %% [markdown]
# # apply函数

# %%
# apply是一个自由度很高的函数，在第3章我们还要提到
# 对于Series，它可以迭代每一列的值操作：

# %%
dataFrameForProduct['发展阶段'].apply(lambda x:x+'!').head() #可以使用lambda表达式，也可以使用函数
# Out:
# 0      未融资!
# 1       A轮!
# 2       B轮!
# 3    不需要融资!
# 4     上市公司!
# Name: 发展阶段, dtype: object

# %%
dataFrameForProduct.apply(lambda x:x.apply(lambda x:str(x)+'!')).head() #这是一个稍显复杂的例子，有利于理解apply的功能
# Out:
#   网站名称 对应的搜索关键词                                               搜索条件     职位 ID  \
# 0  拉钩!    产品经理!  https://www.lagou.com/jobs/list_产品经理?labelWord...  6793134!
# 1  拉钩!    产品经理!  https://www.lagou.com/jobs/list_产品经理?labelWord...  6362305!
# 2  拉钩!    产品经理!  https://www.lagou.com/jobs/list_产品经理?labelWord...  6831533!
# 3  拉钩!    产品经理!  https://www.lagou.com/jobs/list_产品经理?labelWord...  4878943!
# 4  拉钩!    产品经理!  https://www.lagou.com/jobs/list_产品经理?labelWord...  6210428!
#
#                                        职位网址            公司名称           领域  \
# 0  https://www.lagou.com/jobs/6793134.html!  未来大学教育咨询/格物大学!          教育!
# 1  https://www.lagou.com/jobs/6362305.html!            自如网!        房产家居!
# 2  https://www.lagou.com/jobs/6831533.html!            车点点!  移动互联网,消费生活!
# 3  https://www.lagou.com/jobs/4878943.html!           大圣科技!   软件开发,数据服务!
# 4  https://www.lagou.com/jobs/6210428.html!           虎牙信息!       社交,游戏!
#
#      发展阶段                      投资机构        公司规模  ...  \
# ...

# %% [markdown]
# # 排序

# %%
# 1. 索引排序
dataFrameForProduct.set_index('职位 ID').head() #set_index函数可以设置索引，将在下一章详细介绍
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6362305  https://www.lagou.com/jobs/6362305.html            自如网        房产家居
# 6831533  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活
# 4878943  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务
# 6210428  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏
#
#           发展阶段                     投资机构       公司规模  \
# ...

# %%
dataFrameForProduct.set_index('职位 ID').sort_index().head() # #可以设置ascending参数，默认为升序，True
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 265493    拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 854127    拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 1119961   拉钩    产品部经理  https://www.lagou.com/jobs/list_产品部经理?labelWor...
# 1206287   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 1248752   拉钩  网页产品设计师  https://www.lagou.com/jobs/list_网页产品设计师?labelW...
#
#                                             职位网址      公司名称          领域  发展阶段  \
# 职位 ID
# 265493    https://www.lagou.com/jobs/265493.html       凯奇谷    移动互联网,游戏  上市公司
# 854127    https://www.lagou.com/jobs/854127.html  花儿绽放网络科技  移动互联网,广告营销  上市公司
# 1119961  https://www.lagou.com/jobs/1119961.html        易路  移动互联网,企业服务    C轮
# 1206287  https://www.lagou.com/jobs/1206287.html  Marketin   企业服务,数据服务    A轮
# 1248752  https://www.lagou.com/jobs/1248752.html      进门财经    移动互联网,金融    A轮
#
# ...

# %%
# 值排序
dataFrameForProduct.sort_values(by='平均薪资/k').head()
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 1631   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 1690   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 864    拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 654    拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 1693   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
#
#         职位 ID                                     职位网址   公司名称        领域  \
# 1631  5415572  https://www.lagou.com/jobs/5415572.html   平安人寿        金融
# 1690  6604956  https://www.lagou.com/jobs/6604956.html    云宝宝     移动互联网
# 864   6510841  https://www.lagou.com/jobs/6510841.html  大易云计算   企业服务,其他
# 654   5644077  https://www.lagou.com/jobs/5644077.html     荔枝        社交
# 1693  6745753  https://www.lagou.com/jobs/6745753.html   星链科技  信息安全,区块链
#
#        发展阶段                                       投资机构       公司规模  ...  \
# ...

# %%
dataFrameForProduct.sort_values(by='平均薪资/k',ascending=False).head()
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 2221   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2417   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2652   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 987    拉钩   数据产品经理  https://www.lagou.com/jobs/list_数据产品经理?labelWo...
# 2275   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#         职位 ID                                     职位网址   公司名称       领域   发展阶段  \
# 2221  6825466  https://www.lagou.com/jobs/6825466.html   仁线科技  电商、消费生活    未融资
# 2417  6690075  https://www.lagou.com/jobs/6690075.html    爱库存       电商     B轮
# 2652  6723168  https://www.lagou.com/jobs/6723168.html  慧泊金科技    移动互联网    天使轮
# 987   6870249  https://www.lagou.com/jobs/6870249.html     百度       工具  不需要融资
# 2275  6453934  https://www.lagou.com/jobs/6453934.html   酷划在线    移动互联网  不需要融资
#
#                                                    投资机构       公司规模  ...  \
# ...

# %%
# 多个值排序，即先对第一层排，在第一层相同的情况下对第二层排序

# df.sort_values(by=['Address','Height']).head()

# %% [markdown]
# # 索引

# %%
import numpy as np
import pandas as pd
df = pd.read_excel('产品.xls',index_col='职位 ID')
df.head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6362305  https://www.lagou.com/jobs/6362305.html            自如网        房产家居
# 6831533  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活
# 4878943  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务
# 6210428  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏
#
#           发展阶段                     投资机构       公司规模  \
# ...

# %% [markdown]
# ## 单级索引
# #### 1. loc方法、iloc方法、[]操作符
# 最常用的索引方法可能就是这三类，其中iloc表示位置索引，loc表示标签索引，[]也具有很大的便利性，各有特点
#
# ##### （a）loc方法

# %%
## ① 单行索引
df.loc[6210428]
# Out:
# 网站名称                                                          拉钩
# 对应的搜索关键词                                                    产品经理
# 搜索条件           https://www.lagou.com/jobs/list_产品经理?labelWord...
# 职位网址                     https://www.lagou.com/jobs/6210428.html
# 公司名称                                                        虎牙信息
# 领域                                                         社交,游戏
# 发展阶段                                                        上市公司
# 投资机构                                                         NaN
# 公司规模                                                   500-2000人
# 公司网址                                         http://hr.huya.com/
# 职位名称                                                        产品经理
# 标签列表                                    ['产品策划', '产品设计', '用户研究']
# 职位描述           职位诱惑: 大平台、大牛多、发展空间、薪资福利好\n职位描述: 工作职责： 1、对社区类产品...
# 薪资范围                                                    25k-45k
# ...

# %%
## ② 多行索引
df.loc[[6210428,6362305]]
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址  公司名称     领域  发展阶段 投资机构  \
# 职位 ID
# 6210428  https://www.lagou.com/jobs/6210428.html  虎牙信息  社交,游戏  上市公司  NaN
# 6362305  https://www.lagou.com/jobs/6362305.html   自如网   房产家居    A轮  NaN
#
#               公司规模                   公司网址  ...  \
# 职位 ID                                      ...
# 6210428  500-2000人    http://hr.huya.com/  ...
# 6362305    2000人以上  http://www.ziroom.com  ...
#
#                                       职位诱惑统计词  \
# 职位 ID
# 6210428  ['平台', '大牛', '发展', '空间', '薪资', '福利']
# 6362305                  ['年底', '双薪', '绩效奖金']
#
#                                                      职位关键词  \
# 职位 ID
# 6210428  ['用户调研', '产品设计', '竞品分析', '功能策划', '逻辑思维', '需求分析...
# ...

# %% [markdown]
# > （注意：所有在loc中使用的切片全部包含右端点！这是因为如果作为Pandas的使用者，那么肯定不太关心最后一个标签再往后一位是什么，但是如果是左闭右开，那么就很麻烦，先要知道再后面一列的名字是什么，非常不方便，因此Pandas中将loc设计为左右全闭）

# %%
df.loc[6793134:6210428].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6362305  https://www.lagou.com/jobs/6362305.html            自如网        房产家居
# 6831533  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活
# 4878943  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务
# 6210428  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏
#
#           发展阶段                     投资机构       公司规模  \
# ...

# %%
df.loc[6210428::-1].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6210428  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏
# 4878943  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务
# 6831533  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活
# 6362305  https://www.lagou.com/jobs/6362305.html            自如网        房产家居
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
#
#           发展阶段                     投资机构       公司规模  \
# ...

# %%
## ③ 单列索引

df.loc[:,'领域'].head()
# Out:
# 职位 ID
# 6793134            教育
# 6362305          房产家居
# 6831533    移动互联网,消费生活
# 4878943     软件开发,数据服务
# 6210428         社交,游戏
# Name: 领域, dtype: object

# %%
## ④ 多列索引

df.loc[:,['领域','发展阶段']].head()
# Out:
#                  领域   发展阶段
# 职位 ID
# 6793134          教育    未融资
# 6362305        房产家居     A轮
# 6831533  移动互联网,消费生活     B轮
# 4878943   软件开发,数据服务  不需要融资
# 6210428       社交,游戏   上市公司

# %%
df.loc[:,'公司名称':'发展阶段'].head()
# Out:
#                   公司名称          领域   发展阶段
# 职位 ID
# 6793134  未来大学教育咨询/格物大学          教育    未融资
# 6362305            自如网        房产家居     A轮
# 6831533            车点点  移动互联网,消费生活     B轮
# 4878943           大圣科技   软件开发,数据服务  不需要融资
# 6210428           虎牙信息       社交,游戏   上市公司

# %%
## ⑤ 联合索引

df.loc[6793134:4878943:2,'公司名称':'发展阶段'].head()
# Out:
#                   公司名称          领域 发展阶段
# 职位 ID
# 6793134  未来大学教育咨询/格物大学          教育  未融资
# 6831533            车点点  移动互联网,消费生活   B轮

# %%
## ⑥ 函数式索引

df.loc[lambda x:x['发展阶段']=='未融资'].head()
#loc中使用的函数，传入参数就是前面的df
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6870561   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6544519   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6829687   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6801113   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6870561  https://www.lagou.com/jobs/6870561.html          年轻的战场       移动互联网
# 6544519  https://www.lagou.com/jobs/6544519.html        北京乐途原动力  移动互联网,广告营销
# 6829687  https://www.lagou.com/jobs/6829687.html           东来科技        房产家居
# 6801113  https://www.lagou.com/jobs/6801113.html           米娱科技    文娱丨内容,社交
#
# ...

# %%
#这里的例子表示，loc中能够传入函数，并且函数的输入值是整张表，输出为标量、切片、合法列表（元素出现在索引中）、合法索引
def f(x):
    return [6770110,6868692]
df.loc[f]
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6770110   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868692   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址    公司名称          领域   发展阶段  \
# 职位 ID
# 6770110  https://www.lagou.com/jobs/6770110.html     壹心理       移动互联网     B轮
# 6868692  https://www.lagou.com/jobs/6868692.html  摩芋信息技术  移动互联网,企业服务  不需要融资
#
#                                                       投资机构      公司规模  \
# 职位 ID
# 6770110  获吴晓波头头是道基金 战略投资(B轮)，获赛富亚洲、北极光 A+轮投资，获百度知道日报“20...  150-500人
# 6868692                                                NaN    15-50人
#
#                               公司网址  ...  \
# 职位 ID                               ...
# 6770110    http://www.xinli001.com  ...
# 6868692  http://guangzhoumoyu.com/  ...
#
#                                        职位诱惑统计词  \
# 职位 ID
# 6770110        ['餐补', '弹性', '上下班', '年终', '零食']
# ...

# %%
## ⑦ 布尔索引（将重点在第2节介绍）

df.loc[df['发展阶段'].isin(['A轮','B轮'])].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868962   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6719978   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6770110   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址          公司名称          领域  \
# 职位 ID
# 6362305  https://www.lagou.com/jobs/6362305.html           自如网        房产家居
# 6831533  https://www.lagou.com/jobs/6831533.html           车点点  移动互联网,消费生活
# 6868962  https://www.lagou.com/jobs/6868962.html  北京极睿科技有限责任公司  移动互联网,数据服务
# 6719978  https://www.lagou.com/jobs/6719978.html           微拍堂       移动互联网
# 6770110  https://www.lagou.com/jobs/6770110.html           壹心理       移动互联网
#
# ...

# %%
# df.loc[[True if i[-1]=='4' or i[-1]=='7' else False for i in df['Address'].values]].head()

小节：本质上说，loc中能传入的只有布尔列表和索引子集构成的列表，只要把握这个原则就很容易理解上面那些操作

# %% [markdown]
# ##### （b）iloc方法（注意与loc不同，切片右端点不包含）

# %%
## ① 单行索引

df.iloc[5] # 第五行！！！
# Out:
# 网站名称                                                          拉钩
# 对应的搜索关键词                                                    产品经理
# 搜索条件           https://www.lagou.com/jobs/list_产品经理?labelWord...
# 职位网址                     https://www.lagou.com/jobs/6856576.html
# 公司名称                                                        竞技世界
# 领域                                                      移动互联网,游戏
# 发展阶段                                                       不需要融资
# 投资机构                                                         NaN
# 公司规模                                                   500-2000人
# 公司网址                                 http://www.jj.cn/index.html
# 职位名称                                                        产品策划
# 标签列表                                       ['直播', '墨刀', 'Axure']
# 职位描述           职位诱惑: 工资奖金 ，六险一金 ，餐补、健身房\n职位描述: 职位描述：1、独立完成产品需...
# 薪资范围                                                    10k-15k
# ...

# %%
# ② 多行索引

df.iloc[3:5]
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址  公司名称         领域   发展阶段 投资机构  \
# 职位 ID
# 4878943  https://www.lagou.com/jobs/4878943.html  大圣科技  软件开发,数据服务  不需要融资  NaN
# 6210428  https://www.lagou.com/jobs/6210428.html  虎牙信息      社交,游戏   上市公司  NaN
#
#               公司规模                 公司网址  ...  \
# 职位 ID                                    ...
# 4878943   150-500人     http://www.ds.cn  ...
# 6210428  500-2000人  http://hr.huya.com/  ...
#
#                                             职位诱惑统计词  \
# 职位 ID
# 4878943  ['福利', '优厚', '美味', '三餐', '成长', '团队', '氛围']
# 6210428        ['平台', '大牛', '发展', '空间', '薪资', '福利']
#
#                                                      职位关键词              需求匹配  \
# 职位 ID
# ...

# %%
# ③ 单列索引

df.iloc[:,3].head()
# Out:
# 职位 ID
# 6793134    https://www.lagou.com/jobs/6793134.html
# 6362305    https://www.lagou.com/jobs/6362305.html
# 6831533    https://www.lagou.com/jobs/6831533.html
# 4878943    https://www.lagou.com/jobs/4878943.html
# 6210428    https://www.lagou.com/jobs/6210428.html
# Name: 职位网址, dtype: object

# %%
# ④ 多列索引
df.iloc[:,7::-2].head()
# Out:
#                             投资机构          领域  \
# 职位 ID
# 6793134                      NaN          教育
# 6362305                      NaN        房产家居
# 6831533  隆领资本、华泽资本、华映资本、松柏资本(A轮)  移动互联网,消费生活
# 4878943                      NaN   软件开发,数据服务
# 6210428                      NaN       社交,游戏
#
#                                             职位网址 对应的搜索关键词
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html     产品经理
# 6362305  https://www.lagou.com/jobs/6362305.html     产品经理
# 6831533  https://www.lagou.com/jobs/6831533.html     产品经理
# 4878943  https://www.lagou.com/jobs/4878943.html     产品经理
# 6210428  https://www.lagou.com/jobs/6210428.html     产品经理

# %%
## ⑤ 混合索引

df.iloc[3::4,7::-2].head()
# Out:
#                        投资机构         领域  \
# 职位 ID
# 4878943                 NaN  软件开发,数据服务
# 6863462                 NaN   移动互联网,电商
# 6866682                 NaN   移动互联网,游戏
# 6865348                 NaN         社交
# 6799228  启明创投(A轮)，五岳资本(天使轮)   移动互联网,社交
#
#                                             职位网址 对应的搜索关键词
# 职位 ID
# 4878943  https://www.lagou.com/jobs/4878943.html     产品经理
# 6863462  https://www.lagou.com/jobs/6863462.html     产品经理
# 6866682  https://www.lagou.com/jobs/6866682.html     产品经理
# 6865348  https://www.lagou.com/jobs/6865348.html     产品经理
# 6799228  https://www.lagou.com/jobs/6799228.html     产品经理

# %%
## ⑥ 函数式索引

df.iloc[lambda x:[3]].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址  公司名称         领域   发展阶段 投资机构  \
# 职位 ID
# 4878943  https://www.lagou.com/jobs/4878943.html  大圣科技  软件开发,数据服务  不需要融资  NaN
#
#              公司规模              公司网址  ...  \
# 职位 ID                                ...
# 4878943  150-500人  http://www.ds.cn  ...
#
#                                             职位诱惑统计词             职位关键词  \
# 职位 ID
# 4878943  ['福利', '优厚', '美味', '三餐', '成长', '团队', '氛围']  ['产品设计', '工作经验']
#
#              需求匹配 最低薪资/k 平均薪资/k 最高薪资/k  专业要求 证书要求 softskill要求       技能要求
# 职位 ID
# 4878943  ['产品设计']     10   15.0     20  产品设计  NaN         NaN  产品设计，工作经验
#
# [1 rows x 35 columns]

# %% [markdown]
# > 小节：iloc中接收的参数只能为整数或整数列表或布尔列表，不能使用布尔Series，如果要用就必须如下把values拿出来

# %%
#df.iloc[df['School']=='S_1'].head() #报错
df.iloc[(df['发展阶段']=='未融资').values].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6870561   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6544519   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6829687   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6801113   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6870561  https://www.lagou.com/jobs/6870561.html          年轻的战场       移动互联网
# 6544519  https://www.lagou.com/jobs/6544519.html        北京乐途原动力  移动互联网,广告营销
# 6829687  https://www.lagou.com/jobs/6829687.html           东来科技        房产家居
# 6801113  https://www.lagou.com/jobs/6801113.html           米娱科技    文娱丨内容,社交
#
# ...

# %% [markdown]
# ##### （c） []操作符
# （c.1）Series的[]操作

# %%
## ① 单元素索引
s = pd.Series(df['发展阶段'],index=df.index)

# %%
s[6801113] #使用的是索引标签
# Out:
# '未融资'

# %%
## ② 多行索引
s[0:4]
# Out:
# 职位 ID
# 6793134      未融资
# 6362305       A轮
# 6831533       B轮
# 4878943    不需要融资
# Name: 发展阶段, dtype: object

# %%
## ③ 函数式索引
s[lambda x: x.index[16::-6]]
#注意使用lambda函数时，直接切片(如：s[lambda x: 16::-6])就报错，此时使用的不是绝对位置切片，而是元素切片，非常易错
# Out:
# 职位 ID
# 6770110      B轮
# 6719978      A轮
# 6210428    上市公司
# Name: 发展阶段, dtype: object

# %%
## ④ 布尔索引
s[s>80] # 【注意】如果不想陷入困境，请不要在行索引为浮点时使用[]操作符，因为在Series中[]的浮点切片并不是进行位置比较，而是值比较，非常特殊
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-358-fc1ec36d29f5> in <module>
#       1 ## ④ 布尔索引
# ----> 2 s[s>80] # 【注意】如果不想陷入困境，请不要在行索引为浮点时使用[]操作符，因为在Series中[]的浮点切片并不是进行位置比较，而是值比较，非常特殊
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ...

# %% [markdown]
# ###### （c.2）DataFrame的[]操作
#
# ① 单行索引

# %%
df[1:2]
#这里非常容易写成df['label']，会报错
#同Series使用了绝对位置切片
#如果想要获得某一个元素，可用如下get_loc方法：
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址 公司名称    领域 发展阶段 投资机构  \
# 职位 ID
# 6362305  https://www.lagou.com/jobs/6362305.html  自如网  房产家居   A轮  NaN
#
#             公司规模                   公司网址  ...               职位诱惑统计词  \
# 职位 ID                                    ...
# 6362305  2000人以上  http://www.ziroom.com  ...  ['年底', '双薪', '绩效奖金']
#
#                                                      职位关键词  \
# 职位 ID
# 6362305  ['竞品分析', '产品设计', '项目管理', '逻辑思维', '工作经验', '需求调研...
#
#                                      需求匹配 最低薪资/k 平均薪资/k 最高薪资/k  专业要求 证书要求  \
# 职位 ID
# 6362305  ['产品设计', '逻辑思维', '项目管理', '沟通能力']     20   27.5     35  产品设计  NaN
#
#             softskill要求                                技能要求
# 职位 ID
# 6362305  逻辑思维，项目管理，沟通能力  竞品分析，产品设计，项目管理，逻辑思维，工作经验，需求调研，沟通能力
#
# [1 rows x 35 columns]

# %%
row = df.index.get_loc(6770110)
df[row:row+1]
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6770110   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址 公司名称     领域 发展阶段  \
# 职位 ID
# 6770110  https://www.lagou.com/jobs/6770110.html  壹心理  移动互联网   B轮
#
#                                                       投资机构      公司规模  \
# 职位 ID
# 6770110  获吴晓波头头是道基金 战略投资(B轮)，获赛富亚洲、北极光 A+轮投资，获百度知道日报“20...  150-500人
#
#                             公司网址  ...                          职位诱惑统计词  \
# 职位 ID                             ...
# 6770110  http://www.xinli001.com  ...  ['餐补', '弹性', '上下班', '年终', '零食']
#
#                                职位关键词              需求匹配 最低薪资/k 平均薪资/k 最高薪资/k  \
# 职位 ID
# 6770110  ['产品设计', '沟通能力', '本科及以上学历']  ['产品设计', '沟通能力']     10   12.5     15
#
#          专业要求 证书要求 softskill要求               技能要求
# 职位 ID
# 6770110  产品设计  NaN        沟通能力  产品设计，沟通能力，本科及以上学历
#
# [1 rows x 35 columns]

# %%
## ② 多行索引

#用切片，如果是选取指定的某几行，推荐使用loc，否则很可能报错
df[3:5]
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址  公司名称         领域   发展阶段 投资机构  \
# 职位 ID
# 4878943  https://www.lagou.com/jobs/4878943.html  大圣科技  软件开发,数据服务  不需要融资  NaN
# 6210428  https://www.lagou.com/jobs/6210428.html  虎牙信息      社交,游戏   上市公司  NaN
#
#               公司规模                 公司网址  ...  \
# 职位 ID                                    ...
# 4878943   150-500人     http://www.ds.cn  ...
# 6210428  500-2000人  http://hr.huya.com/  ...
#
#                                             职位诱惑统计词  \
# 职位 ID
# 4878943  ['福利', '优厚', '美味', '三餐', '成长', '团队', '氛围']
# 6210428        ['平台', '大牛', '发展', '空间', '薪资', '福利']
#
#                                                      职位关键词              需求匹配  \
# 职位 ID
# ...

# %%
## ③ 单列索引

df['发展阶段'].head()
# Out:
# 职位 ID
# 6793134      未融资
# 6362305       A轮
# 6831533       B轮
# 4878943    不需要融资
# 6210428     上市公司
# Name: 发展阶段, dtype: object

# %%
## ④ 多列索引

df[['发展阶段','平均薪资/k']].head()
# Out:
#           发展阶段  平均薪资/k
# 职位 ID
# 6793134    未融资    22.5
# 6362305     A轮    27.5
# 6831533     B轮    12.0
# 4878943  不需要融资    15.0
# 6210428   上市公司    35.0

# %%
## ⑤函数式索引

df[lambda x:['发展阶段','平均薪资/k']].head()
# Out:
#           发展阶段  平均薪资/k
# 职位 ID
# 6793134    未融资    22.5
# 6362305     A轮    27.5
# 6831533     B轮    12.0
# 4878943  不需要融资    15.0
# 6210428   上市公司    35.0

# %%
# ⑥ 布尔索引

df[df['发展阶段']=='A轮'].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868962   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6719978   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6799228   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 3930560   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址          公司名称          领域  \
# 职位 ID
# 6362305  https://www.lagou.com/jobs/6362305.html           自如网        房产家居
# 6868962  https://www.lagou.com/jobs/6868962.html  北京极睿科技有限责任公司  移动互联网,数据服务
# 6719978  https://www.lagou.com/jobs/6719978.html           微拍堂       移动互联网
# 6799228  https://www.lagou.com/jobs/6799228.html          秀蛋科技    移动互联网,社交
# 3930560  https://www.lagou.com/jobs/3930560.html            领主    移动互联网,社交
#
#         发展阶段                       投资机构      公司规模  \
# ...

# %% [markdown]
# > 小节：一般来说，[]操作符常用于列选择或布尔选择，尽量避免行的选择

# %% [markdown]
# ### 2. 布尔索引

# %%
## （a）布尔符号：'&','|','~'：分别代表和and，或or，取反not

df[(df['发展阶段']=='A轮')&(df['平均薪资/k']>=22.5)].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868962   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6719978   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 3930560   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6606290   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址          公司名称          领域  \
# 职位 ID
# 6362305  https://www.lagou.com/jobs/6362305.html           自如网        房产家居
# 6868962  https://www.lagou.com/jobs/6868962.html  北京极睿科技有限责任公司  移动互联网,数据服务
# 6719978  https://www.lagou.com/jobs/6719978.html           微拍堂       移动互联网
# 3930560  https://www.lagou.com/jobs/3930560.html            领主    移动互联网,社交
# 6606290  https://www.lagou.com/jobs/6606290.html          探知数据     金融,数据服务
#
#         发展阶段                       投资机构      公司规模  \
# ...

# %%
df[(df['发展阶段']=='A轮')|(df['平均薪资/k']>=22.5)].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868962   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6719978   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6362305  https://www.lagou.com/jobs/6362305.html            自如网        房产家居
# 6210428  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏
# 6868962  https://www.lagou.com/jobs/6868962.html   北京极睿科技有限责任公司  移动互联网,数据服务
# 6719978  https://www.lagou.com/jobs/6719978.html            微拍堂       移动互联网
#
# ...

# %%
df[~(df['发展阶段']=='A轮')|(df['平均薪资/k']>=22.5)].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6362305  https://www.lagou.com/jobs/6362305.html            自如网        房产家居
# 6831533  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活
# 4878943  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务
# 6210428  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏
#
#           发展阶段                     投资机构       公司规模  \
# ...

# %%
## （b） isin方法
df[df['发展阶段'].isin(['A轮','B轮'])].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868962   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6719978   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6770110   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址          公司名称          领域  \
# 职位 ID
# 6362305  https://www.lagou.com/jobs/6362305.html           自如网        房产家居
# 6831533  https://www.lagou.com/jobs/6831533.html           车点点  移动互联网,消费生活
# 6868962  https://www.lagou.com/jobs/6868962.html  北京极睿科技有限责任公司  移动互联网,数据服务
# 6719978  https://www.lagou.com/jobs/6719978.html           微拍堂       移动互联网
# 6770110  https://www.lagou.com/jobs/6770110.html           壹心理       移动互联网
#
# ...

# %% [markdown]
# ### 3. 快速标量索引

# %%
## 当只需要取一个元素时，at和iat方法能够提供更快的实现

display(df.at[6770110,'发展阶段'])
display(df.loc[6770110,'发展阶段'])
display(df.iat[0,0])
display(df.iloc[0,0])

#可尝试去掉注释对比时间
# %timeit df.at[6770110,'发展阶段']
# %timeit df.loc[6770110,'发展阶段']
#%timeit df.iat[0,0]
#%timeit df.iloc[0,0]
# Out:
# 'B轮'
# 'B轮'
# '拉钩'
# '拉钩'
# 30.6 µs ± 1.77 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 494 µs ± 61.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### 4. 区间索引

# %%
## 此处介绍并不是说只能在单级索引中使用区间索引，只是作为一种特殊类型的索引方式，在此处先行介绍

##（a）利用interval_range方法

# %%
pd.interval_range(start=0,end=5)
#closed参数可选'left''right''both''neither'，默认左开右闭

# %%
pd.interval_range(start=0,periods=8,freq=5)
#periods参数控制区间个数，freq控制步长

# %%
## （b）利用cut将数值列转为区间为元素的分类变量，例如统计数学成绩的区间情况

# %%
math_interval = pd.cut(df['平均薪资/k'],bins=[0,40,60,80,100])

# %%
math_interval
# Out:
# 职位 ID
# 6793134      (0, 40]
# 6362305      (0, 40]
# 6831533      (0, 40]
# 4878943      (0, 40]
# 6210428      (0, 40]
#              ...
# 6645804     (40, 60]
# 6743841      (0, 40]
# 6068624      (0, 40]
# 6843241      (0, 40]
# 6723168    (80, 100]
# Name: 平均薪资/k, Length: 2653, dtype: category
# Categories (4, interval[int64]): [(0, 40] < (40, 60] < (60, 80] < (80, 100]]

# %%
## （c）区间索引的选取
df.join(math_interval,rsuffix='_interval')
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 265493    拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 854127    拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 1119961   拉钩    产品部经理  https://www.lagou.com/jobs/list_产品部经理?labelWor...
# 1206287   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 1248752   拉钩  网页产品设计师  https://www.lagou.com/jobs/list_网页产品设计师?labelW...
# ...      ...      ...                                                ...
# 6870561   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6870639   拉钩   数据产品经理  https://www.lagou.com/jobs/list_数据产品经理?labelWo...
# 6870709   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6870733   拉钩    产品部经理  https://www.lagou.com/jobs/list_产品部经理?labelWor...
# 6870833   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
#
#                                             职位网址       公司名称          领域  \
# 职位 ID
# ...

# %%
df_i = df.join(math_interval,rsuffix='_interval')[['平均薪资/k','平均薪资/k_interval']].reset_index().set_index('平均薪资/k_interval')
df_i.head()
# Out:
#                    职位 ID  平均薪资/k
# 平均薪资/k_interval
# (0, 40]           265493    12.5
# (0, 40]           854127     8.5
# (0, 40]          1119961    30.0
# (0, 40]          1206287     5.0
# (0, 40]          1248752     6.5

# %%
df_i.loc[65].head() # #包含该值就会被选中
# Out:
#                    职位 ID  平均薪资/k
# 平均薪资/k_interval
# (60, 80]         4687751    65.0
# (60, 80]         5459009    65.0
# (60, 80]         5505690    65.0
# (60, 80]         5693927    65.0
# (60, 80]         5803917    65.0

# %%
df_i.loc[[65,90]].head()
# Out:
#                    职位 ID  平均薪资/k
# 平均薪资/k_interval
# (60, 80]         4687751    65.0
# (60, 80]         5459009    65.0
# (60, 80]         5505690    65.0
# (60, 80]         5693927    65.0
# (60, 80]         5803917    65.0

# %%
df_i.index.astype('interval')
# Out:
# IntervalIndex([(0.0, 40.0], (0.0, 40.0], (0.0, 40.0], (0.0, 40.0], (0.0, 40.0] ... (0.0, 40.0], (0.0, 40.0], (0.0, 40.0], (0.0, 40.0], (0.0, 40.0]],
#               closed='right',
#               dtype='interval[float64]')

# %%
df_i.index.astype('interval').overlaps(pd.Interval(70, 85)) # New in version 0.24.0.
# Out:
# array([False, False, False, ..., False, False, False])

# %%
# 如果想要选取某个区间，先要把分类变量转为区间变量，再使用overlap方法：

#df_i.loc[pd.Interval(70,75)].head() 报错
df_i[df_i.index.astype('interval').overlaps(pd.Interval(70, 85))].head()
#只要索引与(70,85]这个区间有交集就会被选中，注意pd.Interval默认构造区间都是左开右闭，可选closed参数right,left,both,neither
# Out:
#                    职位 ID  平均薪资/k
# 平均薪资/k_interval
# (60, 80]         4687751    65.0
# (60, 80]         5459009    65.0
# (60, 80]         5505690    65.0
# (60, 80]         5693927    65.0
# (60, 80]         5803917    65.0

# %%
## 二、多级索引

# %%
## 1. 创建多级索引

##（a）通过from_tuple或from_arrays

## ① 直接创建元组

# %%
tuples = [('A','a'),('A','b'),('B','a'),('B','b')]
mul_index = pd.MultiIndex.from_tuples(tuples, names=('Upper', 'Lower'))
mul_index
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            names=['Upper', 'Lower'])

# %%
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)
# Out:
#                Score
# Upper Lower
# A     a      perfect
#       b         good
# B     a         fair
#       b          bad

# %%
## ② 利用zip创建元组
L1 = list('AABB')
L2 = list('abab')
tuples = list(zip(L1,L2))
mul_index = pd.MultiIndex.from_tuples(tuples, names=('Upper', 'Lower'))
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)

# %%
## ③ 通过Array创建

arrays = [['A','a'],['A','b'],['B','a'],['B','b']]
mul_index = pd.MultiIndex.from_tuples(arrays, names=('Upper', 'Lower'))
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)

# %%
mul_index
#由此看出内部自动转成元组

# %%
## （b）通过from_product¶

L1 = ['A','B']
L2 = ['a','b']
pd.MultiIndex.from_product([L1,L2],names=('Upper', 'Lower'))
#两两相乘

# %%
## （c）指定df中的列创建（set_index方法）

df_using_mul = df.set_index(['领域','发展阶段'])
df_using_mul.head()

# %%
## 2. 多层索引切片

df_using_mul.head()

# %%
## （a）一般切片

#df_using_mul.loc['C_2','street_5']
#当索引不排序时，单个索引会报出性能警告
#df_using_mul.index.is_lexsorted()
#该函数检查是否排序
df_using_mul.sort_index().loc['教育','未融资']
#df_using_mul.sort_index().index.is_lexsorted()

# %%
#df_using_mul.loc[('C_2','street_5'):] 报错
#当不排序时，不能使用多层切片
df_using_mul.sort_index().loc[('教育','未融资'):('游戏','A轮')]
#注意此处由于使用了loc，因此仍然包含右端点

# %%
df_using_mul.sort_index().loc[('教育','A轮'):'C轮'].head()
#非元组也是合法的，表示选中该层所有元素

# %% [markdown]
# # 分组
#
#
# ## 一、SAC过程
#
# ### 1. 内涵
#
# SAC指的是分组操作中的split-apply-combine过程
# 其中split指基于某一些规则，将数据拆成若干组，apply是指对每一组独立地使用函数，combine指将每一组的结果组合成某一类数据结构
#
# ### 2. apply过程
#
# 在该过程中，我们实际往往会遇到四类问题：
#
# * 整合（Aggregation）——即分组计算统计量（如求均值、求每组元素个数）
# * 变换（Transformation）——即分组对每个单元的数据进行操作（如元素标准化）
# * 过滤（Filtration）——即按照某些规则筛选出一些组（如选出组内某一指标小于50的组）¶
# * 综合问题——即前面提及的三种问题的混合
#
# ## 二、groupby函数
#
# ### 1. 分组函数的基本内容

# %%
import numpy as np
import pandas as pd
df = pd.read_excel('产品.xls',index_col='职位 ID')
## df.head()

# %% [markdown]
# #### （a）根据某一列分组

# %%
grouped_single = df.groupby('发展阶段')

# %% [markdown]
# 经过groupby后会生成一个groupby对象，该对象本身不会返回任何东西，只有当相应的方法被调用才会起作用
# 例如取出某一个组：

# %%
grouped_single.get_group('A轮').head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868962   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6719978   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6799228   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 3930560   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址          公司名称          领域  \
# 职位 ID
# 6362305  https://www.lagou.com/jobs/6362305.html           自如网        房产家居
# 6868962  https://www.lagou.com/jobs/6868962.html  北京极睿科技有限责任公司  移动互联网,数据服务
# 6719978  https://www.lagou.com/jobs/6719978.html           微拍堂       移动互联网
# 6799228  https://www.lagou.com/jobs/6799228.html          秀蛋科技    移动互联网,社交
# 3930560  https://www.lagou.com/jobs/3930560.html            领主    移动互联网,社交
#
#         发展阶段                       投资机构      公司规模  \
# ...

# %% [markdown]
# #### （b）根据某几列分组

# %%
grouped_mul = df.groupby(['发展阶段','领域'])
grouped_mul.get_group(('A轮','游戏'))
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6485768   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6720395   拉钩   网页产品经理  https://www.lagou.com/jobs/list_网页产品经理?labelWo...
# 6127506   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 6865365   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 6819566   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 2759447   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 6824606   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 6535619   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 6559486   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 5191151   拉钩  网页产品设计师  https://www.lagou.com/jobs/list_网页产品设计师?labelW...
# 6701003   拉钩  网页产品设计师  https://www.lagou.com/jobs/list_网页产品设计师?labelW...
# 6701009   拉钩  网页产品设计师  https://www.lagou.com/jobs/list_网页产品设计师?labelW...
# ...

# %% [markdown]
# #### （c）组容量与组数

# %%
grouped_single.size()
# Out:
# 发展阶段
# A轮           349
# B轮           257
# C轮           179
# D轮及以上        181
# 上市公司         489
# 不需要融资        749
# 企业服务           1
# 企业服务,教育        1
# 企业服务,消费生活      1
# 医疗丨健康          1
# 天使轮          116
# 未融资          326
# 移动互联网,教育       1
# 移动互联网,游戏       1
# 金融             1
# dtype: int64

# %%
grouped_single.size().plot()

# %%
grouped_mul.size()
# Out:
# 发展阶段      领域
# A轮        人工智能         1
#           人工智能,企业服务    1
#           企业服务         3
#           企业服务 工具      1
#           企业服务,信息安全    1
#                       ..
# 未融资       金融,软件开发      2
#           金融、数据服务      1
# 移动互联网,教育  管理风格         1
# 移动互联网,游戏  管理风格         1
# 金融        管理风格         1
# Length: 523, dtype: int64

# %%
grouped_single.ngroups
# Out:
# 15

# %%
grouped_mul.ngroups
# Out:
# 523

# %% [markdown]
# #### （d）组的遍历

# %%
for name,group in grouped_single:
    print(name)
    # display(group.head())
# Out:
# A轮
# B轮
# C轮
# D轮及以上
# 上市公司
# 不需要融资
# 企业服务
# 企业服务,教育
# 企业服务,消费生活
# 医疗丨健康
# 天使轮
# 未融资
# 移动互联网,教育
# 移动互联网,游戏
# 金融

# %% [markdown]
# #### （e）level参数（用于多级索引）和axis参数

# %%
df.set_index(['发展阶段','领域']).groupby(level=1,axis=0).get_group('教育').head()
# Out:
#          网站名称 对应的搜索关键词                                               搜索条件  \
# 发展阶段  领域
# 未融资   教育   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 不需要融资 教育   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#       教育   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 未融资   教育   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 不需要融资 教育   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                              职位网址            公司名称 投资机构  \
# 发展阶段  领域
# 未融资   教育  https://www.lagou.com/jobs/6793134.html   未来大学教育咨询/格物大学  NaN
# 不需要融资 教育  https://www.lagou.com/jobs/6813992.html  北大附中基础教育投资有限公司  NaN
#       教育  https://www.lagou.com/jobs/5483057.html            水滴智慧  NaN
# 未融资   教育  https://www.lagou.com/jobs/5784993.html             育联网  NaN
# 不需要融资 教育  https://www.lagou.com/jobs/5631685.html            BT学院  NaN
#
#              公司规模                          公司网址  职位名称  \
# 发展阶段  领域
# ...

# %% [markdown]
# ### 2. groupby对象的特点

# %% [markdown]
# #### （a）查看所有可调用的方法

# %% [markdown]
# 由此可见，groupby对象可以使用相当多的函数，灵活程度很高

# %%
print([attr for attr in dir(grouped_single) if not attr.startswith('_')])
# Out:
# ['agg', 'aggregate', 'all', 'any', 'apply', 'backfill', 'bfill', 'boxplot', 'corr', 'corrwith', 'count', 'cov', 'cumcount', 'cummax', 'cummin', 'cumprod', 'cumsum', 'describe', 'diff', 'dtypes', 'expanding', 'ffill', 'fillna', 'filter', 'first', 'get_group', 'groups', 'head', 'hist', 'idxmax', 'idxmin', 'indices', 'last', 'mad', 'max', 'mean', 'median', 'min', 'ndim', 'ngroup', 'ngroups', 'nth', 'nunique', 'ohlc', 'pad', 'pct_change', 'pipe', 'plot', 'prod', 'quantile', 'rank', 'resample', 'rolling', 'sem', 'shift', 'size', 'skew', 'softskill要求', 'std', 'sum', 'tail', 'take', 'transform', 'tshift', 'var', '专业要求', '公司名称', '公司网址', '公司规模', '发展阶段', '发布日期', '学历要求', '对应的搜索关键词', '工作地点', '工作性质', '技能要求', '投资机构', '搜索条件', '标签列表', '经验要求', '网站名称', '职位关键词', '职位名称', '职位描述', '职位网址', '职位要求', '职位诱惑', '职位诱惑关键词', '职位诱惑统计词', '薪资范围', '证书要求', '需求匹配', '领域']

# %%
grouped_single.head(2)

# %% [markdown]
# #### （b）分组对象的head和first
#
# 对分组对象使用head函数，返回的是每个组的前几行，而不是数据集前几行
#
# first显示的是以分组为索引的每组的第一个分组信息

# %%
grouped_single.first()

# %% [markdown]
# #### （c）分组依据
#
# 对于groupby函数而言，分组的依据是非常自由的，只要是与数据框长度相同的列表即可，同时支持函数型分组
#
#
# #### （d）groupby的[]操作
#
# 可以用[]选出groupby对象的某个或者某几个列，上面的均分比较可以如下简洁地写出：

# %%
df.groupby(['发展阶段','领域'])['平均薪资/k'].mean()>=60

# %%
# 用列表可选出多个属性列：

df.groupby(['发展阶段','领域'])["最低薪资/k",'平均薪资/k'].mean()

# %% [markdown]
# #### （e）连续型变量分组
#
# 例如利用cut函数对数学成绩分组：

# %%
bins = [0,40,60,80,90,100]
cuts = pd.cut(df['平均薪资/k'],bins=bins) #可选label添加自定义标签
df.groupby(cuts)['平均薪资/k'].count()

# %% [markdown]
# ## 三、聚合、过滤和变换
#
# ### 1. 聚合（Aggregation）
#
# #### （a）常用聚合函数¶
#
# 所谓聚合就是把一堆数，变成一个标量，因此mean/sum/size/count/std/var/sem/describe/first/last/nth/min/max都是聚合函数
#
# 为了熟悉操作，不妨验证标准误sem函数，它的计算公式是：

# %%
group_m = grouped_single['平均薪资/k']
group_m.std().values/np.sqrt(group_m.count().values)== group_m.sem().values
# Out:
# array([ True,  True,  True,  True,  True,  True, False, False, False,
#        False,  True,  True, False, False, False])

# %% [markdown]
# #### （b）同时使用多个聚合函数

# %%
group_m.agg(['sum','mean','std'])
# Out:
#                sum       mean        std
# 发展阶段
# A轮          6559.5  18.795129  10.826426
# B轮          6139.0  23.887160  14.554213
# C轮          4177.0  23.335196  13.218537
# D轮及以上       5155.0  28.480663  14.499939
# 上市公司       11361.0  23.233129  13.234210
# 不需要融资      13648.5  18.222296  11.852070
# 企业服务           8.0   8.000000        NaN
# 企业服务,教育        3.5   3.500000        NaN
# 企业服务,消费生活     19.0  19.000000        NaN
# 医疗丨健康          7.5   7.500000        NaN
# 天使轮         1913.0  16.491379  12.180702
# 未融资         5653.5  17.342025  13.187478
# 移动互联网,教育      17.5  17.500000        NaN
# 移动互联网,游戏      22.5  22.500000        NaN
# 金融            20.0  20.000000        NaN

# %%
# 利用元组进行重命名
group_m.agg([('rename_sum','sum'),('rename_mean','mean')])
# Out:
#            rename_sum  rename_mean
# 发展阶段
# A轮             6559.5    18.795129
# B轮             6139.0    23.887160
# C轮             4177.0    23.335196
# D轮及以上          5155.0    28.480663
# 上市公司          11361.0    23.233129
# 不需要融资         13648.5    18.222296
# 企业服务              8.0     8.000000
# 企业服务,教育           3.5     3.500000
# 企业服务,消费生活        19.0    19.000000
# 医疗丨健康             7.5     7.500000
# 天使轮            1913.0    16.491379
# 未融资            5653.5    17.342025
# 移动互联网,教育         17.5    17.500000
# 移动互联网,游戏         22.5    22.500000
# 金融               20.0    20.000000

# %%
# 指定哪些函数作用哪些列

grouped_mul.agg({'平均薪资/k':['mean','max'],'最低薪资/k':'var'})
# Out:
#                    平均薪资/k       最低薪资/k
#                      mean   max    var
# 发展阶段     领域
# A轮       人工智能       11.50  11.5    NaN
#          人工智能,企业服务  40.00  40.0    NaN
#          企业服务       18.50  32.5  133.0
#          企业服务 工具    20.00  20.0    NaN
#          企业服务,信息安全  10.50  10.5    NaN
# ...                   ...   ...    ...
# 未融资      金融,软件开发    12.25  20.0   72.0
#          金融、数据服务    20.00  20.0    NaN
# 移动互联网,教育 管理风格       17.50  17.5    NaN
# 移动互联网,游戏 管理风格       22.50  22.5    NaN
# 金融       管理风格       20.00  20.0    NaN
#
# [523 rows x 3 columns]

# %% [markdown]
# #### （c）使用自定义函数

# %%
grouped_single['平均薪资/k'].agg(lambda x:print(x.head(),'间隔'))
#可以发现，agg函数的传入是分组逐列进行的，有了这个特性就可以做许多事情
# Out:
# 6362305    27.5
# 6868962    22.5
# 6719978    32.5
# 6799228    15.0
# 3930560    23.0
# Name: 平均薪资/k, dtype: float64 间隔
# 6831533    12.0
# 6770110    12.5
# 4328890    10.0
# 6195824    20.0
# 5623212    21.0
# Name: 平均薪资/k, dtype: float64 间隔
# 6863462    17.0
# 1483083    15.0
# 6851751    22.5
# 6578109    22.5
# 1996940    12.0
# Name: 平均薪资/k, dtype: float64 间隔
# 6825839    40.0
# 3894873    27.5
# 6801166    22.5
# 6648761    20.0
# 6870709    23.0
# Name: 平均薪资/k, dtype: float64 间隔
# 6210428    35.0
# 5627648    21.5
# 6800657    17.5
# 6763791    32.5
# 6869412    16.5
# Name: 平均薪资/k, dtype: float64 间隔
# 4878943    15.0
# 6856576    12.5
# 6863150    15.0
# 6866682    13.5
# 6863087    15.0
# Name: 平均薪资/k, dtype: float64 间隔
# 6835888    8.0
# Name: 平均薪资/k, dtype: float64 间隔
# 6791402    3.5
# Name: 平均薪资/k, dtype: float64 间隔
# 6853330    19.0
# Name: 平均薪资/k, dtype: float64 间隔
# 6833578    7.5
# Name: 平均薪资/k, dtype: float64 间隔
# 6097686    13.0
# 6860993    25.0
# ...

# %%
# 官方没有提供极差计算的函数，但通过agg可以容易地实现组内极差计算

grouped_single['平均薪资/k'].agg(lambda x:x.max()-x.min())
# Out:
# 发展阶段
# A轮            53.5
# B轮           102.5
# C轮            55.0
# D轮及以上         73.5
# 上市公司          73.5
# 不需要融资         83.5
# 企业服务           0.0
# 企业服务,教育        0.0
# 企业服务,消费生活      0.0
# 医疗丨健康          0.0
# 天使轮           88.5
# 未融资          113.5
# 移动互联网,教育       0.0
# 移动互联网,游戏       0.0
# 金融             0.0
# Name: 平均薪资/k, dtype: float64

# %% [markdown]
# #### （d）利用NamedAgg函数进行多个聚合
#
# 注意：不支持lambda函数，但是可以使用外置的def函数

# %%
def R1(x):
    return x.max()-x.min()

def R2(x):
    return x.max()-x.median()

grouped_single['平均薪资/k'].agg(
    min_score1=pd.NamedAgg(column='col1', aggfunc=R1),
    max_score1=pd.NamedAgg(column='col2', aggfunc='max'),
    range_score2=pd.NamedAgg(column='col3', aggfunc=R2)
).head()
# Out:
#        min_score1  max_score1  range_score2
# 发展阶段
# A轮           53.5        55.0          37.5
# B轮          102.5       105.0          83.5
# C轮           55.0        57.5          35.0
# D轮及以上        73.5        75.0          45.0
# 上市公司         73.5        75.0          52.5

# %% [markdown]
# #### （e）带参数的聚合函数

# %%
# 判断是否组内平均薪资/k至少有一个值在50-52之间：

def f(s,low,high):
    return s.between(low,high).max()

grouped_single['平均薪资/k'].agg(f,50,52)
# Out:
# 发展阶段
# A轮           False
# B轮            True
# C轮            True
# D轮及以上         True
# 上市公司          True
# 不需要融资         True
# 企业服务         False
# 企业服务,教育      False
# 企业服务,消费生活    False
# 医疗丨健康        False
# 天使轮          False
# 未融资          False
# 移动互联网,教育     False
# 移动互联网,游戏     False
# 金融           False
# Name: 平均薪资/k, dtype: bool

# %%
## 如果需要使用多个函数，并且其中至少有一个带参数，则使用wrap技巧：

def f_test(s,low,high):
    return s.between(low,high).max()

def agg_f(f_mul,name,*args,**kwargs):
    def wrapper(x):
        return f_mul(x,*args,**kwargs)
    wrapper.__name__ = name
    return wrapper

new_f = agg_f(f_test,'at_least_one_in_50_52',50,52)

grouped_single['平均薪资/k'].agg([new_f,'mean']).head()
# Out:
#        at_least_one_in_50_52       mean
# 发展阶段
# A轮                     False  18.795129
# B轮                      True  23.887160
# C轮                      True  23.335196
# D轮及以上                   True  28.480663
# 上市公司                    True  23.233129

# %% [markdown]
# ## 2. 过滤（Filteration）
#
# filter函数是用来筛选某些组的（务必记住结果是组的全体），因此传入的值应当是布尔标量

# %%
grouped_single[['平均薪资/k','最低薪资/k']].filter(lambda x:(x['平均薪资/k']>12).all()).head()

# %% [markdown]
# ## 3. 变换（Transformation）
#
# ### （a）传入对象
#
#
# transform函数中传入的对象是组内的列，并且返回值需要与列长完全一致

# %%
grouped_single[['平均薪资/k','最低薪资/k']].transform(lambda x:x-x.min()).head()
# Out:
#          平均薪资/k  最低薪资/k
# 职位 ID
# 6793134    21.0      14
# 6362305    26.0      19
# 6831533     9.5       6
# 4878943    13.5       9
# 6210428    33.5      24

# %% [markdown]
# 如果返回了标量值，那么组内的所有元素会被广播为这个值

# %%
grouped_single[['平均薪资/k','最低薪资/k']].transform(lambda x:x.mean()).head()
# Out:
#             平均薪资/k     最低薪资/k
# 职位 ID
# 6793134  17.342025  12.993865
# 6362305  18.795129  13.868195
# 6831533  23.887160  17.996109
# 4878943  18.222296  13.477971
# 6210428  23.233129  16.889571

# %% [markdown]
# ### （b）利用变换方法进行组内标准化

# %%
grouped_single[['平均薪资/k','最低薪资/k']].transform(lambda x:(x-x.mean())/x.std()).head()

# %% [markdown]
# ### （c）利用变换方法进行组内缺失值的均值填充

# %%
df[['平均薪资/k','最低薪资/k']]

# %%
df_nan = df[['平均薪资/k','最低薪资/k']].copy().reset_index()
df_nan.loc[np.random.randint(0,df.shape[0],25),['平均薪资/k']]=np.nan
df_nan.head()

# %% [markdown]
# ## 四、apply函数
#
# ### 1. apply函数的灵活性
#
# 可能在所有的分组函数中，apply是应用最为广泛的，这得益于它的灵活性：
#
# 对于传入值而言，从下面的打印内容可以看到是以分组的表传入apply中：

# %%
df.groupby('平均薪资/k').apply(lambda x:print(x.head(1)))

# %% [markdown]
# apply函数
#
# apply函数是`pandas`里面所有函数中自由度最高的函数。该函数如下：
#
# DataFrame.apply(func, axis=0, broadcast=False, raw=False, reduce=None, args=(), **kwds)
#
# 该函数最有用的是第一个参数，这个参数是函数，相当于C/C++的函数指针。
#
# 这个函数需要自己实现，函数的传入参数根据axis来定，比如axis = 1，就会把一行数据作为Series的数据
# 结构传入给自己实现的函数中，我们在函数中实现对Series不同属性之间的计算，返回一个结果，则apply函数
# 会自动遍历每一行DataFrame的数据，最后将所有结果组合成一个Series数据结构并返回。
#
#
#
# func : function
#
# 作用于每一列或行。
#
# axis : {0 或 ‘index’, 1 或 ‘columns’}, 默认 0
#
# 函数所应用的轴:
#
# 0 或 ‘index’: 对每一列应用函数。
#
# 1 或 ‘columns’: 对每一行应用函数。
#
# broadcast : bool, 可选
#
# 仅与聚合函数相关:
#
# False 或 None : 返回一个Series，该Series的长度是索引的长度或列的数量(基于axis参数)
#
# True : 结果将广播到框架的原始形状，原始索引和列将保留。
#
# 从0.23.0版本开始就不推荐使用:这个参数将在将来的版本中被删除，取而代之的是result_type= ' broadcast '。
#
# raw : bool, 默认 False
#
# False : 将每一行或每一列作为一个Series传递给函数。
#
# True : t传递的函数将接收ndarray对象。如果您只是应用一个NumPy约简函数，这将获得更好的性能。
#
# reduce : bool 或 None, 默认 None
#
# 试着使用减量程序。如果DataFrame为空，apply将使用reducto确定结果应该是一个Series还是一个DataFrame。如果reduce=None(缺省值)，apply的返回值将通过在空序列上调用func来猜测(注意:在猜测时，func引发的异常将被忽略)。如果reduce=True，则始终返回一个Series，如果reduce=False，则始终返回一个DataFrame。
#
# 从0.23.0版本开始就不推荐使用:这个参数将在将来的版本中被删除，取而代之的是result_type='reduce'。
#
# result_type : {‘expand’, ‘reduce’, ‘broadcast’, None}, 默认 None
#
# 这些只在axis=1(列)时起作用:
#
# ‘expand’ : 类似列表的结果将转换为列。
#
# ‘reduce’ : 如果可能，返回一个Series，而不是展开类似列表的结果。这是‘expand’的反义词。
#
# ‘broadcast’ : 结果将广播到DataFrame的原始形状，保留原始索引和列。
#
# 默认行为(None)取决于应用函数的返回值:类似列表的结果将作为这些结果的Series返回。但是，如果apply函数返回一个Series，这些列就会展开为列。
#
# New in version 0.23.0.
#
# args : tuple
#
# 除了array/series外，还要传递给func的位置参数。
#
# **kwds
#
# 要作为关键字参数传递给func的其他关键字参数。
#
#
#
#
# apply函数的灵活性很大程度来源于其返回值的多样性：
#
# ### ① 标量返回值

# %%
df[['工作地点','平均薪资/k','最低薪资/k']].groupby('工作地点').apply(lambda x:x.max())
# Out:
#       工作地点  平均薪资/k  最低薪资/k
# 工作地点
# 上海      上海   105.0      90
# 东莞      东莞    15.0      10
# 中山      中山     5.0       4
# 佛山      佛山    30.0      20
# 北京      北京    90.0      80
# 南京      南京    52.5      35
# 南宁      南宁    14.0      12
# 南昌      南昌    20.0      15
# 厦门      厦门    24.0      18
# 合肥      合肥    45.0      30
# 呼和浩特  呼和浩特     4.0       3
# 嘉兴      嘉兴    25.5      17
# 天津      天津    22.5      20
# 太原      太原     4.0       3
# 宁波      宁波    30.0      20
# 广州      广州    75.0      50
# 惠州      惠州     6.0       4
# 成都      成都    60.0      40
# 无锡      无锡   115.0      80
# 昆明      昆明    15.5      11
# 昭通      昭通    20.0      15
# 杭州      杭州    65.0      50
# 武汉      武汉    50.0      40
# 江门      江门     7.5       5
# 沈阳      沈阳    12.0       8
# 济南      济南     9.5       7
# 深圳      深圳    75.0      60
# 温州      温州     4.5       3
# 珠海      珠海    20.0      15
# 石家庄    石家庄    12.5      10
# 福州      福州    30.0      20
# 绵阳      绵阳    10.5       8
# 苏州      苏州    45.0      30
# ...

# %% [markdown]
# #### ② 列表返回值

# %%
df.head()

# %%
df[['工作地点','平均薪资/k','最低薪资/k']].groupby('工作地点').head()
# Out:
#         工作地点  平均薪资/k  最低薪资/k
# 职位 ID
# 6793134   深圳    22.5      15
# 6362305   北京    27.5      20
# 6831533   杭州    12.0       8
# 4878943   广州    15.0      10
# 6210428   北京    35.0      25
# ...      ...     ...     ...
# 6825466   无锡   115.0      80
# 6823946   嘉兴    25.5      17
# 6868160   黄石    30.0      20
# 6738944   南昌    20.0      15
# 6833779   福州    30.0      20
#
# [128 rows x 3 columns]

# %%
df[['工作地点','平均薪资/k','最低薪资/k']].groupby('工作地点').apply(lambda x:print(x) ).head()
# Out:
#         工作地点  平均薪资/k  最低薪资/k
# 职位 ID
# 6863462   上海    17.0      12
# 6866370   上海    15.5      13
# 6870012   上海    15.0      12
# 6867223   上海    20.0      15
# 3326114   上海    15.0      10
# ...      ...     ...     ...
# 6751635   上海    14.0      10
# 6065968   上海    30.0      25
# 6729603   上海    40.0      30
# 6194853   上海    40.0      30
# 6392017   上海    40.0      30
#
# [393 rows x 3 columns]
#         工作地点  平均薪资/k  最低薪资/k
# 职位 ID
# 6606203   东莞    15.0      10
# 6038854   东莞     6.0       5
# 6038850   东莞     8.5       6
# 6038847   东莞     8.5       6
#         工作地点  平均薪资/k  最低薪资/k
# 职位 ID
# 5643516   中山     5.0       4
#         工作地点  平均薪资/k  最低薪资/k
# 职位 ID
# 6077374   佛山     9.0       6
# 6832526   佛山    11.5      10
# 5912429   佛山     5.0       4
# 6210372   佛山     4.5       4
# 6775708   佛山    22.5      15
# 6265198   佛山    16.5      11
# 6786882   佛山    30.0      20
# 6777620   佛山    15.0      10
# 6786888   佛山    30.0      20
# 6788884   佛山    11.0       8
# ...

# %%
df[['工作地点','平均薪资/k','最低薪资/k']].groupby('工作地点').apply(lambda x:x['平均薪资/k'].max() - x['平均薪资/k'].min() ).head(20)
# Out:
# 工作地点
# 上海      103.5
# 东莞        9.0
# 中山        0.0
# 佛山       25.5
# 北京       88.5
# 南京       51.0
# 南宁       12.5
# 南昌        0.0
# 厦门       21.5
# 合肥       40.5
# 呼和浩特      0.0
# 嘉兴       22.5
# 天津       20.0
# 太原        0.0
# 宁波       22.0
# 广州       73.5
# 惠州        0.0
# 成都       58.5
# 无锡      110.0
# 昆明        0.0
# dtype: float64

# %%
df[['工作地点','平均薪资/k','最低薪资/k']].groupby('工作地点').apply(lambda x:x['平均薪资/k'].max() - x['平均薪资/k'].min() ).plot()

# %% [markdown]
# #### ③ 数据框返回值

# %%
df.groupby('工作地点').head()

# %%
df[['工作地点','最高薪资/k','平均薪资/k']].groupby('工作地点').apply(lambda x : print(x))
# Out:
#         工作地点  最高薪资/k  平均薪资/k
# 职位 ID
# 6863462   上海      22    17.0
# 6866370   上海      18    15.5
# 6870012   上海      18    15.0
# 6867223   上海      25    20.0
# 3326114   上海      20    15.0
# ...      ...     ...     ...
# 6751635   上海      18    14.0
# 6065968   上海      35    30.0
# 6729603   上海      50    40.0
# 6194853   上海      50    40.0
# 6392017   上海      50    40.0
#
# [393 rows x 3 columns]
#         工作地点  最高薪资/k  平均薪资/k
# 职位 ID
# 6606203   东莞      20    15.0
# 6038854   东莞       7     6.0
# 6038850   东莞      11     8.5
# 6038847   东莞      11     8.5
#         工作地点  最高薪资/k  平均薪资/k
# 职位 ID
# 5643516   中山       6     5.0
#         工作地点  最高薪资/k  平均薪资/k
# 职位 ID
# 6077374   佛山      12     9.0
# 6832526   佛山      13    11.5
# 5912429   佛山       6     5.0
# 6210372   佛山       5     4.5
# 6775708   佛山      30    22.5
# 6265198   佛山      22    16.5
# 6786882   佛山      40    30.0
# 6777620   佛山      20    15.0
# 6786888   佛山      40    30.0
# 6788884   佛山      14    11.0
# ...

# %%
df[['工作地点','最高薪资/k','平均薪资/k']].groupby('工作地点').apply(
    lambda x:x['最高薪资/k']-x['最高薪资/k'].max()
    ).head()
# Out:
# 工作地点  职位 ID
# 上海    6863462    -98
#       6866370   -102
#       6870012   -102
#       6867223    -95
#       3326114   -100
# Name: 最高薪资/k, dtype: int64

# %% [markdown]
# ### 2. 用apply同时统计多个指标
#
# 此处可以借助OrderedDict工具进行快捷的统计：

# %%
from collections import OrderedDict
def f(df):
    data = OrderedDict()
    data['平均薪资_sum'] = df['平均薪资/k'].sum()
    data['最高薪资_var'] = df['最高薪资/k'].var()
    data['最低薪资_mean'] = df['最低薪资/k'].mean()
    return pd.Series(data)
grouped_single.apply(f)
# Out:
#            平均薪资_sum    最高薪资_var  最低薪资_mean
# 发展阶段
# A轮           6559.5  189.678276  13.868195
# B轮           6139.0  319.063898  17.996109
# C轮           4177.0  269.533237  17.486034
# D轮及以上        5155.0  322.277655  20.972376
# 上市公司        11361.0  294.998718  16.889571
# 不需要融资       13648.5  226.869205  13.477971
# 企业服务            8.0         NaN   6.000000
# 企业服务,教育         3.5         NaN   3.000000
# 企业服务,消费生活      19.0         NaN  13.000000
# 医疗丨健康           7.5         NaN   5.000000
# 天使轮          1913.0  218.978936  12.422414
# 未融资          5653.5  283.260642  12.993865
# 移动互联网,教育       17.5         NaN  15.000000
# 移动互联网,游戏       22.5         NaN  15.000000
# 金融             20.0         NaN  15.000000

# %% [markdown]
# # 缺失数据

# %% [markdown]
# Pandas在步入1.0后，对数据类型也做出了新的尝试，尤其是Nullable类型和String类型，了解这些可能在未来成为主流的新特性是必要的

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('产品.xls')
df.head()
# Out:
#   网站名称 对应的搜索关键词                                               搜索条件    职位 ID  \
# 0   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6793134
# 1   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6362305
# 2   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6831533
# 3   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  4878943
# 4   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6210428
#
#                                       职位网址           公司名称          领域   发展阶段  \
# 0  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育    未融资
# 1  https://www.lagou.com/jobs/6362305.html            自如网        房产家居     A轮
# 2  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活     B轮
# 3  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务  不需要融资
# 4  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏   上市公司
#
#                       投资机构       公司规模  ...  \
# ...

# %% [markdown]
# ## 一、缺失观测及其类型
#
# #### 1. 了解缺失信息
#
# ##### （a）isna和notna方法
#
# 对Series使用会返回布尔列表

# %%
df[r'投资机构']
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2                                 隆领资本、华泽资本、华映资本、松柏资本(A轮)
# 3                                                     NaN
# 4                                                     NaN
#                               ...
# 2648    法拉龙资本、北极星资本、金沙江创投、元璟资本，以及天使阶段的真格基金和阿尔法公社。(B轮)，...
# 2649                                                  NaN
# 2650                                                  NaN
# 2651                                                  NaN
# 2652                                                  NaN
# Name: 投资机构, Length: 2653, dtype: object

# %%
df[r'投资机构'].isna().head()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: 投资机构, dtype: bool

# %%
df['投资机构'].notna().head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: 投资机构, dtype: bool

# %%
# 对DataFrame使用会返回布尔表
df.isna().head()
# Out:
#     网站名称  对应的搜索关键词   搜索条件  职位 ID   职位网址   公司名称     领域   发展阶段   投资机构   公司规模  \
# 0  False     False  False  False  False  False  False  False   True  False
# 1  False     False  False  False  False  False  False  False   True  False
# 2  False     False  False  False  False  False  False  False  False  False
# 3  False     False  False  False  False  False  False  False   True  False
# 4  False     False  False  False  False  False  False  False   True  False
#
#    ...  职位诱惑统计词  职位关键词   需求匹配  最低薪资/k  平均薪资/k  最高薪资/k   专业要求  证书要求  \
# 0  ...    False  False  False   False   False   False  False  True
# 1  ...    False  False  False   False   False   False  False  True
# 2  ...    False  False  False   False   False   False   True  True
# 3  ...    False  False  False   False   False   False  False  True
# 4  ...    False  False  False   False   False   False  False  True
#
#    softskill要求   技能要求
# 0        False  False
# 1        False  False
# 2        False  False
# ...

# %%
# 但对于DataFrame我们更关心到底每列有多少缺失值
df.isna().sum()
# Out:
# 网站名称              0
# 对应的搜索关键词          0
# 搜索条件              0
# 职位 ID             0
# 职位网址              0
# 公司名称              0
# 领域                0
# 发展阶段              0
# 投资机构           2081
# 公司规模              0
# 公司网址              0
# 职位名称              0
# 标签列表              0
# 职位描述              0
# 薪资范围              0
# 经验要求              0
# 学历要求              0
# 工作性质              0
# 工作地点              0
# 工作地址 1            0
#  工作地址 2        1135
#  工作地址 3           0
# 发布日期              0
# 职位诱惑              0
# 职位要求              0
# 职位诱惑关键词           0
# 职位诱惑统计词           0
# 职位关键词             0
# 需求匹配              0
# 最低薪资/k            0
# 平均薪资/k            0
# 最高薪资/k            0
# 专业要求           1273
# 证书要求           2613
# softskill要求     406
# 技能要求              0
# dtype: int64

# %%
# 此外，可以通过之前介绍的info函数查看缺失信息
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2653 entries, 0 to 2652
# Data columns (total 36 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   网站名称         2653 non-null   object
#  1   对应的搜索关键词     2653 non-null   object
#  2   搜索条件         2653 non-null   object
#  3   职位 ID        2653 non-null   int64
#  4   职位网址         2653 non-null   object
#  5   公司名称         2653 non-null   object
#  6   领域           2653 non-null   object
#  7   发展阶段         2653 non-null   object
#  8   投资机构         572 non-null    object
#  9   公司规模         2653 non-null   object
#  10  公司网址         2653 non-null   object
#  11  职位名称         2653 non-null   object
#  12  标签列表         2653 non-null   object
#  13  职位描述         2653 non-null   object
#  14  薪资范围         2653 non-null   object
#  15  经验要求         2653 non-null   object
#  16  学历要求         2653 non-null   object
#  17  工作性质         2653 non-null   object
# ...

# %% [markdown]
# ##### （b）查看缺失值的所以在行
#
#
# 以最后一列为例，挑出该列缺失值的行

# %%
df[df['投资机构'].isna()]
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 0      拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 1      拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 3      拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 4      拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 5      拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# ...   ...      ...                                                ...
# 2646   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2649   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2650   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2651   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2652   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#         职位 ID                                     职位网址           公司名称  \
# ...

# %% [markdown]
# ##### （c）挑选出所有非缺失值列
#
#
# 使用all就是全部非缺失值，如果是any就是至少有一个不是缺失值

# %%
df[df.notna().all(1)]
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 389    拉钩   网页产品经理  https://www.lagou.com/jobs/list_网页产品经理?labelWo...
# 1333   拉钩   电商产品经理  https://www.lagou.com/jobs/list_电商产品经理?labelWo...
# 1638   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 1686   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 2169   拉钩    产品部经理  https://www.lagou.com/jobs/list_产品部经理?labelWor...
#
#         职位 ID                                     职位网址      公司名称          领域  \
# 389   6820017  https://www.lagou.com/jobs/6820017.html      易言科技    移动互联网,教育
# 1333  6862198  https://www.lagou.com/jobs/6862198.html       妙健康       移动互联网
# 1638  6158313  https://www.lagou.com/jobs/6158313.html      大众问问    移动互联网,硬件
# 1686  6664335  https://www.lagou.com/jobs/6664335.html  PKFARE比客          旅游
# 2169  1119961  https://www.lagou.com/jobs/1119961.html        易路  移动互联网,企业服务
#
#        发展阶段                                               投资机构      公司规模  ...  \
# ...

# %% [markdown]
# #### 2. 三种缺失符号
#
# ##### （a）np.nan
#
# np.nan是一个麻烦的东西，首先它不等与任何东西，甚至不等于自己

# %%
np.nan == np.nan
# Out:
# False

# %%
np.nan == 0
# Out:
# False

# %%
np.nan == None
# Out:
# False

# %% [markdown]
# 在用equals函数比较时，自动略过两侧全是np.nan的单元格，因此结果不会影响

# %%
df.equals(df)
# Out:
# True

# %% [markdown]
# 其次，它在numpy中的类型为浮点，由此导致数据集读入时，即使原来是整数的列，只要有缺失值就会变为浮点型

# %%
type(np.nan)
# Out:
# float

# %%
pd.Series([1,2,3]).dtype
# Out:
# dtype('int64')

# %%
pd.Series([1,np.nan,3]).dtype
# Out:
# dtype('float64')

# %% [markdown]
# 此外，对于布尔类型的列表，如果是np.nan填充，那么它的值会自动变为True而不是False

# %%
pd.Series([1,np.nan,3],dtype='bool')
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %% [markdown]
# 但当修改一个布尔列表时，会改变列表类型，而不是赋值为True

# %%
s = pd.Series([True,False],dtype='bool')
s[1]=np.nan
s
# Out:
# 0    1.0
# 1    NaN
# dtype: float64

# %% [markdown]
# 在所有的表格读取后，无论列是存放什么类型的数据，默认的缺失值全为np.nan类型
# 因此整型列转为浮点；而字符由于无法转化为浮点，因此只能归并为object类型（'O'），原来是浮点型的则类型不变

# %% [markdown]
# ##### （b）None
#
# None比前者稍微好些，至少它会等于自身

# %%
None == None
# Out:
# True

# %%
# 它的布尔值为False

pd.Series([None],dtype='bool')
# Out:
# 0    False
# dtype: bool

# %%
# 修改布尔列表不会改变数据类型

s = pd.Series([True,False],dtype='bool')
s[0]=None
s
# Out:
# 0    False
# 1    False
# dtype: bool

# %%
s = pd.Series([1,0],dtype='bool')
s[0]=None
s
# Out:
# 0    False
# 1    False
# dtype: bool

# %%
# 在传入数值类型后，会自动变为np.nan
type(pd.Series([1,None])[1])
# Out:
# numpy.float64

# %%
# 只有当传入object类型是保持不动，几乎可以认为，除非人工命名None，它基本不会自动出现在Pandas中

type(pd.Series([1,None],dtype='O')[1])
# Out:
# NoneType

# %%
# 在使用equals函数时不会被略过，因此下面的情况下返回False

pd.Series([None]).equals(pd.Series([np.nan]))
# Out:
# False

# %% [markdown]
# ##### （c）NaT
#
# NaT是针对时间序列的缺失值，是Pandas的内置类型，可以完全看做时序版本的np.nan，与自己不等，且使用equals是也会被跳过

# %%
s_time = pd.Series([pd.Timestamp('20120101')]*5)
s_time
# Out:
# 0   2012-01-01
# 1   2012-01-01
# 2   2012-01-01
# 3   2012-01-01
# 4   2012-01-01
# dtype: datetime64[ns]

# %%
s_time[2] = None
s_time
# Out:
# 0   2012-01-01
# 1   2012-01-01
# 2          NaT
# 3   2012-01-01
# 4   2012-01-01
# dtype: datetime64[ns]

# %%
s_time[2] = pd.NaT
s_time
# Out:
# 0   2012-01-01
# 1   2012-01-01
# 2          NaT
# 3   2012-01-01
# 4   2012-01-01
# dtype: datetime64[ns]

# %%
type(s_time[2])
# Out:
# pandas._libs.tslibs.nattype.NaTType

# %%
s_time[2] == s_time[2]
# Out:
# False

# %%
s_time.equals(s_time)
# Out:
# True

# %%
s = pd.Series([True,False],dtype='bool')
s[1]=pd.NaT
s
# Out:
# 0    True
# 1    True
# dtype: bool

# %% [markdown]
# #### 3. Nullable类型与NA符号
#
# 这是Pandas在1.0新版本中引入的重大改变，其目的就是为了（在若干版本后）解决之前出现的混乱局面，统一缺失值处理方法
# "The goal of pd.NA is provide a “missing” indicator that can be used consistently across data types (instead of np.nan, None or pd.NaT depending on the data type)."——User Guide for Pandas v-1.0
# 官方鼓励用户使用新的数据类型和缺失类型pd.NA
#
# ##### （a）Nullable整形
#
# 对于该种类型而言，它与原来标记int上的符号区别在于首字母大写：'Int'

# %% [markdown]
# s_original = pd.Series([1, 2], dtype="int64")
# s_original

# %%
s_new = pd.Series([1, 2], dtype="Int64")
s_new
# Out:
# 0    1
# 1    2
# dtype: Int64

# %% [markdown]
# 它的好处就在于，其中前面提到的三种缺失值都会被替换为统一的NA符号，且不改变数据类型

# %%
s_original[1] = np.nan
s_original
# Out:
# 0    1.0
# 1    NaN
# dtype: float64

# %%
s_new[1] = np.nan
s_new
# Out:
# 0       1
# 1    <NA>
# dtype: Int64

# %%
s_new[1] = None
s_new
# Out:
# 0       1
# 1    <NA>
# dtype: Int64

# %%
s_new[1] = pd.NaT
s_new
# Out:
# 0       1
# 1    <NA>
# dtype: Int64

# %% [markdown]
# ##### （b）Nullable布尔
#
# 对于该种类型而言，作用与上面的类似，记号为boolean

# %%
s_original = pd.Series([1, 0], dtype="bool")
s_original
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
s_new = pd.Series([0, 1], dtype="boolean")
s_new
# Out:
# 0    False
# 1     True
# dtype: boolean

# %%
s_original[0] = np.nan
s_original
# Out:
# 0    NaN
# 1    0.0
# dtype: float64

# %%
s_original = pd.Series([1, 0], dtype="bool") #此处重新加一句是因为前面赋值改变了bool类型
s_original[0] = None
s_original
# Out:
# 0    False
# 1    False
# dtype: bool

# %%
s_new[0] = np.nan
s_new
# Out:
# 0    <NA>
# 1    True
# dtype: boolean

# %%
s_new[0] = None
s_new
# Out:
# 0    <NA>
# 1    True
# dtype: boolean

# %%
s_new[0] = pd.NaT
s_new
# Out:
# 0    <NA>
# 1    True
# dtype: boolean

# %% [markdown]
# 需要注意的是，含有pd.NA的布尔列表在1.0.2之前的版本作为索引时会报错，这是一个之前的bug，现已经修复

# %%
s = pd.Series(['dog','cat'])
s[s_new]
# Out:
# 1    cat
# dtype: object

# %% [markdown]
# ##### （c）string类型
#
# 该类型是1.0的一大创新，目的之一就是为了区分开原本含糊不清的object类型，这里将简要地提及string
#
# 它本质上也属于Nullable类型，因为并不会因为含有缺失而改变类型

# %%
s = pd.Series(['dog','cat'],dtype='string')
s
# Out:
# 0    dog
# 1    cat
# dtype: string

# %%
s[0] = np.nan
s
# Out:
# 0    <NA>
# 1     cat
# dtype: string

# %%
s[0] = None
s

# %%
s[0] = pd.NaT
s

# %% [markdown]
# 此外，和object类型的一点重要区别就在于，在调用字符方法后，string类型返回的是Nullable类型，object则会根据缺失类型和数据类型而改变

# %%
s = pd.Series(["a", None, "b"], dtype="string")
s.str.count('a')

# %%
s2 = pd.Series(["a", None, "b"], dtype="object")
s2.str.count("a")

# %%
s.str.isdigit()

# %%
s2.str.isdigit()

# %% [markdown]
# #### 4. NA的特性
#
# （a）逻辑运算
# 只需看该逻辑运算的结果是否依赖pd.NA的取值，如果依赖，则结果还是NA，如果不依赖，则直接计算结果

# %%
True | pd.NA

# %%
pd.NA | True

# %%
False | pd.NA

# %%
False & pd.NA

# %%
True & pd.NA

# %%
## 取值不明直接报错
#bool(pd.NA)

# %% [markdown]
# （b）算术运算和比较运算
# 这里只需记住除了下面两类情况，其他结果都是NA即可

# %%
pd.NA ** 0

# %%
1 ** pd.NA

# %% [markdown]
# 其他情况：

# %%
pd.NA + 1

# %%
"a" * pd.NA

# %%
pd.NA == pd.NA

# %%
pd.NA < 2.5

# %%
np.log(pd.NA)

# %%
np.add(pd.NA, 1)

# %% [markdown]
# #### 5. convert_dtypes方法
# 这个函数的功能往往就是在读取数据时，就把数据列转为Nullable类型，是1.0的新函数

# %%
pd.read_csv('data/table_missing.csv').dtypes

# %%
pd.read_csv('data/table_missing.csv').convert_dtypes().dtypes

# %% [markdown]
# ## 二、缺失数据的运算与分组
#
# ### 1. 加号与乘号规则
#
# 使用加法时，缺失值为0

# %%
s = pd.Series([2,3,np.nan,4])
s.sum()

# %%
# 使用乘法时，缺失值为1

s.prod()

# %%
# 使用累计函数时，缺失值自动略过

s.cumsum()

# %%
s.cumprod()

# %%
s.pct_change()

# %% [markdown]
# ### 2. groupby方法中的缺失值
# 自动忽略为缺失值的组

# %%
df_g = pd.DataFrame({'one':['A','B','C','D',np.nan],'two':np.random.randn(5)})
df_g

# %%
df_g.groupby('one').groups

# %% [markdown]
# ## 三、填充与剔除
#
# ### 1. fillna方法
#
# （a）值填充与前后向填充（分别与ffill方法和bfill方法等价）

# %%
df['投资机构'].fillna('missing').head()
# Out:
# 0                    missing
# 1                    missing
# 2    隆领资本、华泽资本、华映资本、松柏资本(A轮)
# 3                    missing
# 4                    missing
# Name: 投资机构, dtype: object

# %%
df['投资机构'].fillna(method='ffill').head()
# Out:
# 0                        NaN
# 1                        NaN
# 2    隆领资本、华泽资本、华映资本、松柏资本(A轮)
# 3    隆领资本、华泽资本、华映资本、松柏资本(A轮)
# 4    隆领资本、华泽资本、华映资本、松柏资本(A轮)
# Name: 投资机构, dtype: object

# %%
df['投资机构'].fillna(method='backfill').head()
# Out:
# 0      隆领资本、华泽资本、华映资本、松柏资本(A轮)
# 1      隆领资本、华泽资本、华映资本、松柏资本(A轮)
# 2      隆领资本、华泽资本、华映资本、松柏资本(A轮)
# 3    红杉；图灵；金沙江；魔量(A轮)，金沙江(天使轮)
# 4    红杉；图灵；金沙江；魔量(A轮)，金沙江(天使轮)
# Name: 投资机构, dtype: object

# %% [markdown]
# ##### （b）填充中的对齐特性

# %%
df_f = pd.DataFrame({'A':[1,3,np.nan],'B':[2,4,np.nan],'C':[3,5,np.nan]})
df_f.fillna(df_f.mean())
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  3.0  4.0  5.0
# 2  2.0  3.0  4.0

# %% [markdown]
# 返回的结果中没有C，根据对齐特点不会被填充

# %%
df_f.fillna(df_f.mean()[['A','B']])
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  3.0  4.0  5.0
# 2  2.0  3.0  NaN

# %% [markdown]
# ### 2. dropna方法
#
# ##### （a）axis参数

# %%
df_d = pd.DataFrame({'A':[np.nan,np.nan,np.nan],'B':[np.nan,3,2],'C':[3,2,1]})
df_d
# Out:
#     A    B  C
# 0 NaN  NaN  3
# 1 NaN  3.0  2
# 2 NaN  2.0  1

# %%
df_d.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
df_d.dropna(axis=1)
# Out:
#    C
# 0  3
# 1  2
# 2  1

# %% [markdown]
# ##### （b）how参数（可以选all或者any，表示全为缺失去除和存在缺失去除）

# %%
df_d.dropna(axis=1,how='all')
# Out:
#      B  C
# 0  NaN  3
# 1  3.0  2
# 2  2.0  1

# %% [markdown]
# ##### （c）subset参数（即在某一组列范围中搜索缺失值）

# %%
df_d.dropna(axis=0,subset=['B','C'])
# Out:
#     A    B  C
# 1 NaN  3.0  2
# 2 NaN  2.0  1

# %% [markdown]
# ## 四、插值（interpolation）
#
# ### 1. 线性插值
# #### （a）索引无关的线性插值
# 默认状态下，interpolate会对缺失的值进行线性插值

# %%
s = pd.Series([1,10,15,-5,-2,np.nan,np.nan,28])
s
# Out:
# 0     1.0
# 1    10.0
# 2    15.0
# 3    -5.0
# 4    -2.0
# 5     NaN
# 6     NaN
# 7    28.0
# dtype: float64

# %%
s.interpolate()
# Out:
# 0     1.0
# 1    10.0
# 2    15.0
# 3    -5.0
# 4    -2.0
# 5     8.0
# 6    18.0
# 7    28.0
# dtype: float64

# %%
s.interpolate().plot()

# %% [markdown]
# 此时的插值与索引无关

# %%
s.index = np.sort(np.random.randint(50,300,8))
s.interpolate()
#值不变
# Out:
# 69      1.0
# 85     10.0
# 137    15.0
# 174    -5.0
# 200    -2.0
# 219     8.0
# 238    18.0
# 255    28.0
# dtype: float64

# %%
s.interpolate().plot()
#后面三个点不是线性的（如果几乎为线性函数，请重新运行上面的一个代码块，这是随机性导致的）

# %% [markdown]
# #### （b）与索引有关的插值
#
# method中的index和time选项可以使插值线性地依赖索引，即插值为索引的线性函数

# %%
s.interpolate(method='index').plot()
#可以看到与上面的区别

# %% [markdown]
# 如果索引是时间，那么可以按照时间长短插值

# %%
s_t = pd.Series([0,np.nan,10]
        ,index=[pd.Timestamp('2012-05-01'),pd.Timestamp('2012-05-07'),pd.Timestamp('2012-06-03')])
s_t
# Out:
# 2012-05-01     0.0
# 2012-05-07     NaN
# 2012-06-03    10.0
# dtype: float64

# %%
s_t.interpolate().plot()

# %%
s_t.interpolate(method='time').plot()

# %% [markdown]
# ### 2. 高级插值方法
#
# 此处的高级指的是与线性插值相比较，例如样条插值、多项式插值、阿基玛插值等（需要安装Scipy），方法详情请看这里
#
# 关于这部分仅给出一个官方的例子，因为插值方法是数值分析的内容，而不是Pandas中的基本知识：

# %%
ser = pd.Series(np.arange(1, 10.1, .25) ** 2 + np.random.randn(37))
missing = np.array([4, 13, 14, 15, 16, 17, 18, 20, 29])
ser[missing] = np.nan
methods = ['linear', 'quadratic', 'cubic']
df = pd.DataFrame({m: ser.interpolate(method=m) for m in methods})
df.plot()

# %% [markdown]
# ### 3. interpolate中的限制参数
# （a）limit表示最多插入多少个

# %%
s = pd.Series([1,np.nan,np.nan,np.nan,5])
s.interpolate(limit=2)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %% [markdown]
# （b）limit_direction表示插值方向，可选forward,backward,both，默认前向

# %%
s = pd.Series([np.nan,np.nan,1,np.nan,np.nan,np.nan,5,np.nan,np.nan,])
s.interpolate(limit_direction='backward')
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    2.0
# 4    3.0
# 5    4.0
# 6    5.0
# 7    NaN
# 8    NaN
# dtype: float64

# %% [markdown]
# （c）limit_area表示插值区域，可选inside,outside，默认None

# %%
s = pd.Series([np.nan,np.nan,1,np.nan,np.nan,np.nan,5,np.nan,np.nan,])
s.interpolate(limit_area='inside')
# Out:
# 0    NaN
# 1    NaN
# 2    1.0
# 3    2.0
# 4    3.0
# 5    4.0
# 6    5.0
# 7    NaN
# 8    NaN
# dtype: float64

# %%
s = pd.Series([np.nan,np.nan,1,np.nan,np.nan,np.nan,5,np.nan,np.nan,])
s.interpolate(limit_area='outside')
# Out:
# 0    NaN
# 1    NaN
# 2    1.0
# 3    NaN
# 4    NaN
# 5    NaN
# 6    5.0
# 7    5.0
# 8    5.0
# dtype: float64

# %% [markdown]
# # 文本数据

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 一、string类型的性质
#
# ### 1. string与object的区别
#
# string类型和object不同之处有三：
#
# ① 字符存取方法（string accessor methods，如str.count）会返回相应数据的Nullable类型，而object会随缺失值的存在而改变返回类型
#
# ② 某些Series方法不能在string上使用，例如： Series.str.decode()，因为存储的是字符串而不是字节
#
# ③ string类型在缺失值存储或运算时，类型会广播为pd.NA，而不是浮点型np.nan
#
# 其余全部内容在当前版本下完全一致，但迎合Pandas的发展模式，我们仍然全部用string来操作字符串
#
# ### 2. string类型的转换
#
# 如果将一个其他类型的容器直接转换string类型可能会出错：
