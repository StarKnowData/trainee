# %%
import pandas as pd 
import numpy as np
pd.__version__
# Out:
# '0.22.0'

# %%
df = pd.read_excel('/home/tianchi/myspace/产品.xls')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2653 entries, 0 to 2652
# Data columns (total 36 columns):
# 网站名称           2653 non-null object
# 对应的搜索关键词       2653 non-null object
# 搜索条件           2653 non-null object
# 职位 ID          2653 non-null int64
# 职位网址           2653 non-null object
# 公司名称           2653 non-null object
# 领域             2653 non-null object
# 发展阶段           2653 non-null object
# 投资机构           572 non-null object
# 公司规模           2653 non-null object
# 公司网址           2653 non-null object
# 职位名称           2653 non-null object
# 标签列表           2653 non-null object
# 职位描述           2653 non-null object
# 薪资范围           2653 non-null object
# 经验要求           2653 non-null object
# 学历要求           2653 non-null object
# 工作性质           2653 non-null object
# 工作地点           2653 non-null object
# 工作地址 1         2653 non-null object
#  工作地址 2        1518 non-null object
#  工作地址 3        2653 non-null object
# 发布日期           2653 non-null object
# ...

# %%
df['公司规模'].value_counts()
# Out:
# 2000人以上                                         613
# 150-500人                                        612
# 50-150人                                         571
# 500-2000人                                       453
# 15-50人                                          362
# 少于15人                                            41
# 紫金科创(天使轮)，江苏舜天(天使轮)，金陵饭店(天使轮)，江苏高科技投资集团(天使轮)      1
# Name: 公司规模, dtype: int64

# %%
df['公司规模'].nunique()
# Out:
# 7

# %%
df['职位名称'].value_counts()
# Out:
# 产品经理                    439
# 产品总监                    154
# 数据产品经理                  135
# 产品助理                     91
# 项目助理                     69
# 产品实习生                    49
# 产品专员                     46
# 游戏策划                     43
# 电商产品经理                   38
# 数值策划                     32
# 高级产品经理                   31
# 大数据产品经理                  24
# ui设计师                    24
# 平面设计师                    20
# 产品运营实习生                  20
# UI设计师                    19
# 产品经理实习生                  19
# 交互设计师                    18
# 高级数据产品经理                 18
# 视觉设计师                    16
# 产品专家                     16
# 产品经理助理                   15
# 移动端产品经理                  12
# 游戏数值策划                   12
# 关卡策划                     11
# 游戏ui设计师                  10
# 产品运营专员                   10
# 战斗策划                      9
# 产品负责人                     9
# 移动产品经理                    9
#                        ...
# APP 产品总监                  1
# 中级产品经理                    1
# ...

# %%
df['职位名称'].nunique()
# Out:
# 1028

# %%
df = pd.read_excel('/home/tianchi/myspace/产品.xls',index_col='公司规模')

# %%
df[['职位名称','平均薪资/k']].head()
# Out:
#            职位名称  平均薪资/k
# 公司规模
# 15-50人     产品经理    22.5
# 2000人以上    产品经理    27.5
# 150-500人   产品经理    12.0
# 150-500人   产品经理    15.0
# 500-2000人  产品经理    35.0

# %%
grouped_mul = df.groupby(['公司规模','职位名称'])
res2=grouped_mul.get_group(('15-50人','产品经理'))
res2
# Out:
#        网站名称 对应的搜索关键词                                               搜索条件  \
# 公司规模
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# ...

# %%
grouped_mul = df.groupby(['公司规模','职位名称'])
res6=grouped_mul.get_group(('2000人以上','产品经理'))
res6
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 公司规模
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 2000人以上   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# ...

# %%
grouped_mul = df.groupby(['公司规模','职位名称'])
res4=grouped_mul.get_group(('150-500人','产品经理'))
res4
# Out:
#          网站名称 对应的搜索关键词                                               搜索条件  \
# 公司规模
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 150-500人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# ...

# %%
grouped_mul = df.groupby(['公司规模','职位名称'])
res3=grouped_mul.get_group(('50-150人','产品经理'))
res3
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 公司规模
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 50-150人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# ...

# %%
grouped_mul = df.groupby(['公司规模','职位名称'])
res5=grouped_mul.get_group(('500-2000人','产品经理'))
res5
# Out:
#           网站名称 对应的搜索关键词                                               搜索条件  \
# 公司规模
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 500-2000人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# ...

# %%
grouped_mul = df.groupby(['公司规模','职位名称'])
res1=grouped_mul.get_group(('少于15人','产品经理'))
res1
# Out:
#       网站名称 对应的搜索关键词                                               搜索条件  \
# 公司规模
# 少于15人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 少于15人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 少于15人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 少于15人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 少于15人   拉钩   网页产品经理  https://www.lagou.com/jobs/list_网页产品经理?labelWo...
# 少于15人   拉钩    产品部经理  https://www.lagou.com/jobs/list_产品部经理?labelWor...
# 少于15人   拉钩    产品部经理  https://www.lagou.com/jobs/list_产品部经理?labelWor...
# 少于15人   拉钩    产品部经理  https://www.lagou.com/jobs/list_产品部经理?labelWor...
# 少于15人   拉钩    产品部经理  https://www.lagou.com/jobs/list_产品部经理?labelWor...
#
#          职位 ID                                     职位网址        公司名称  \
# 公司规模
# 少于15人  6691526  https://www.lagou.com/jobs/6691526.html         益投后
# 少于15人  6833623  https://www.lagou.com/jobs/6833623.html        寰清能源
# ...

# %%
res1[['最低薪资/k','平均薪资/k','最高薪资/k']].head()
# Out:
#        最低薪资/k  平均薪资/k  最高薪资/k
# 公司规模
# 少于15人      25    37.5      50
# 少于15人      20    27.5      35
# 少于15人       8    11.5      15
# 少于15人      15    20.0      25
# 少于15人       5     7.5      10

# %%
res2[['最低薪资/k','平均薪资/k','最高薪资/k']].head()
# Out:
#         最低薪资/k  平均薪资/k  最高薪资/k
# 公司规模
# 15-50人      15    22.5      30
# 15-50人      15    22.5      30
# 15-50人      10    15.0      20
# 15-50人      12    17.0      22
# 15-50人       2     2.5       3

# %%
res3[['最低薪资/k','平均薪资/k','最高薪资/k']].head()
# Out:
#          最低薪资/k  平均薪资/k  最高薪资/k
# 公司规模
# 50-150人      10    15.0      20
# 50-150人      15    20.0      25
# 50-150人      10    15.0      20
# 50-150人      15    22.5      30
# 50-150人      15    20.0      25

# %%
res4[['最低薪资/k','平均薪资/k','最高薪资/k']].head()
# Out:
#           最低薪资/k  平均薪资/k  最高薪资/k
# 公司规模
# 150-500人       8    12.0      16
# 150-500人      10    15.0      20
# 150-500人      12    17.0      22
# 150-500人      10    12.5      15
# 150-500人      12    15.0      18

# %%
res5[['最低薪资/k','平均薪资/k','最高薪资/k']].head()
# Out:
#            最低薪资/k  平均薪资/k  最高薪资/k
# 公司规模
# 500-2000人      25    35.0      45
# 500-2000人      18    21.5      25
# 500-2000人      13    15.5      18
# 500-2000人      15    17.5      20
# 500-2000人       8    12.0      16

# %%
res6[['最低薪资/k','平均薪资/k','最高薪资/k']].head()
# Out:
#          最低薪资/k  平均薪资/k  最高薪资/k
# 公司规模
# 2000人以上      20    27.5      35
# 2000人以上      10    15.0      20
# 2000人以上      10    13.5      17
# 2000人以上      25    32.5      40
# 2000人以上      13    16.5      20

# %%
res1.groupby(['公司规模','职位名称'])["最低薪资/k",'平均薪资/k','最高薪资/k'].mean()
# Out:
#                 最低薪资/k    平均薪资/k     最高薪资/k
# 公司规模   职位名称
# 15-50人 产品经理  12.012195  16.27439  20.536585

# %%
res1.agg({'最低薪资/k':['mean','max','min','var'],'平均薪资/k':['mean','max','min','var'],'最高薪资/k':['mean','max','min','var']})
# Out:
#          最低薪资/k      平均薪资/k      最高薪资/k
# mean  12.555556   17.722222   22.888889
# max   25.000000   37.500000   50.000000
# min    3.000000    4.000000    5.000000
# var   49.777778  105.819444  184.361111

# %%
res2.agg({'最低薪资/k':['mean','max','min','var'],'平均薪资/k':['mean','max','min','var'],'最高薪资/k':['mean','max','min','var']})
# Out:
#          最低薪资/k     平均薪资/k     最高薪资/k
# mean  12.012195  16.274390  20.536585
# max   25.000000  32.500000  40.000000
# min    2.000000   2.500000   3.000000
# var   18.703553  33.575015  56.498645

# %%
res3.agg({'最低薪资/k':['mean','max','min','var'],'平均薪资/k':['mean','max','min','var'],'最高薪资/k':['mean','max','min','var']})
# Out:
#          最低薪资/k     平均薪资/k     最高薪资/k
# mean  12.259843  16.960630  21.661417
# max   30.000000  45.000000  60.000000
# min    4.000000   6.000000   7.000000
# var   21.574803  45.593676  81.257468

# %%
res4.agg({'最低薪资/k':['mean','max','min','var'],'平均薪资/k':['mean','max','min','var'],'最高薪资/k':['mean','max','min','var']})
# Out:
#          最低薪资/k     平均薪资/k     最高薪资/k
# mean  13.183673  17.892857  22.602041
# max   25.000000  37.500000  50.000000
# min    4.000000   6.000000   8.000000
# var   19.471071  36.521907  64.221439

# %%
res5.agg({'最低薪资/k':['mean','max','min','var'],'平均薪资/k':['mean','max','min','var'],'最高薪资/k':['mean','max','min','var']})
# Out:
#          最低薪资/k     平均薪资/k     最高薪资/k
# mean  13.083333  17.700000  22.316667
# max   25.000000  35.000000  45.000000
# min    7.000000   9.000000  10.000000
# var   14.552260  29.061017  51.948870

# %%
res6.agg({'最低薪资/k':['mean','max','min','var'],'平均薪资/k':['mean','max','min','var'],'最高薪资/k':['mean','max','min','var']})
# Out:
#          最低薪资/k     平均薪资/k     最高薪资/k
# mean  15.225806  20.870968  26.516129
# max   30.000000  40.000000  50.000000
# min    6.000000   7.000000   8.000000
# var   28.308831  56.925701  99.991539
