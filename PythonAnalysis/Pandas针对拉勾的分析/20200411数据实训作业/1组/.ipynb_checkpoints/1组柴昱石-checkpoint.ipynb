# %%
#检查环境
import pandas as pd 
import numpy as np
pd.__version__
# Out:
# '0.25.1'

# %%
from pandas import Series,DataFrame

# %%
#导入文件
dataFrameForProduct = pd.read_excel("../Taylor/产品.xls")

# %%
# info函数返回有哪些列、有多少非缺失值、每列的类型
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2653 entries, 0 to 2652
# Data columns (total 36 columns):
# 网站名称           2653 non-null object
# 对应的搜索关键词       2653 non-null object
# 搜索条件           2653 non-null object
# 职位 ID          2653 non-null int64
# 职位网址           2653 non-null object
# 公司名称           2653 non-null object
# 领域             2653 non-null object
# 发展阶段           2653 non-null object
# 投资机构           572 non-null object
# 公司规模           2653 non-null object
# 公司网址           2653 non-null object
# 职位名称           2653 non-null object
# 标签列表           2653 non-null object
# 职位描述           2653 non-null object
# 薪资范围           2653 non-null object
# 经验要求           2653 non-null object
# 学历要求           2653 non-null object
# 工作性质           2653 non-null object
# 工作地点           2653 non-null object
# 工作地址 1         2653 non-null object
#  工作地址 2        1518 non-null object
#  工作地址 3        2653 non-null object
# 发布日期           2653 non-null object
# ...

# %%
#描述信息
product_df.describe()
# Out:
#               职位 ID       最低薪资/k       平均薪资/k       最高薪资/k
# count  2.653000e+03  2653.000000  2653.000000  2653.000000
# mean   6.335620e+06    15.263475    20.619864    25.976253
# std    8.521579e+05     9.904004    13.145331    16.632093
# min    2.654930e+05     1.000000     1.500000     2.000000
# 25%    6.245654e+06     8.000000    11.500000    14.000000
# 50%    6.684678e+06    15.000000    19.000000    25.000000
# 75%    6.809075e+06    20.000000    27.500000    35.000000
# max    6.870833e+06    90.000000   115.000000   150.000000

# %%
product_df.head()
# Out:
#   网站名称 对应的搜索关键词                                               搜索条件    职位 ID  \
# 0   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6793134
# 1   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6362305
# 2   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6831533
# 3   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  4878943
# 4   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6210428
#
#                                       职位网址           公司名称          领域   发展阶段  \
# 0  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育    未融资
# 1  https://www.lagou.com/jobs/6362305.html            自如网        房产家居     A轮
# 2  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活     B轮
# 3  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务  不需要融资
# 4  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏   上市公司
#
#                       投资机构       公司规模  ...  \
# ...

# %%
#问题：探究薪资与公司规模间的关系？
#关键词：公司规模、平均薪资/k


#显示平均薪资/k最大值所在行
product_df['平均薪资/k'].idxmax()
# Out:
# 2221

# %%
product_df.loc[2221]
# Out:
# 网站名称                                                          拉钩
# 对应的搜索关键词                                                    产品总监
# 搜索条件           https://www.lagou.com/jobs/list_产品总监?labelWord...
# 职位 ID                                                    6825466
# 职位网址                     https://www.lagou.com/jobs/6825466.html
# 公司名称                                                        仁线科技
# 领域                                                       电商、消费生活
# 发展阶段                                                         未融资
# 投资机构                                                         NaN
# 公司规模                                                     2000人以上
# 公司网址                                https://www.lagou.com/gon...
# 职位名称                                                        产品总监
# 标签列表                           ['云计算', '工具软件', '业务流程管理', '部门管理']
# 职位描述           职位诱惑: 百亿美金，与你共创\n职位描述: 工作职责：1.负责产品全流程管理，包括制定产品...
# ...

# %%
#显示平均薪资/k最小值所在行
product_df['平均薪资/k'].idxmin()
# Out:
# 654

# %%
product_df.loc[654]
# Out:
# 网站名称                                                          拉钩
# 对应的搜索关键词                                                    产品助理
# 搜索条件           https://www.lagou.com/jobs/list_产品助理?labelWord...
# 职位 ID                                                    5644077
# 职位网址                     https://www.lagou.com/jobs/5644077.html
# 公司名称                                                          荔枝
# 领域                                                            社交
# 发展阶段                                                        上市公司
# 投资机构                   兰馨亚洲；EMC基金(D轮及以上)，小米科技；顺为资本；经纬中国；晨兴资本(C轮)
# 公司规模                                                   500-2000人
# 公司网址                                         http://www.lizhi.fm
# 职位名称                                          产品助理实习生 (MJ000205)
# 标签列表                            ['产品设计', '产品策划', '用户研究', '数据分析']
# 职位描述           职位诱惑: 大牛多 领导nice 薪酬福利好\n职位描述: 工作职责：1.产品功能体验与竞品...
# ...

# %%
#在此区间内的内容
product_df.loc[[654,2221]]
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 654    拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 2221   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#         职位 ID                                     职位网址  公司名称       领域  发展阶段  \
# 654   5644077  https://www.lagou.com/jobs/5644077.html    荔枝       社交  上市公司
# 2221  6825466  https://www.lagou.com/jobs/6825466.html  仁线科技  电商、消费生活   未融资
#
#                                            投资机构       公司规模  ...  \
# 654   兰馨亚洲；EMC基金(D轮及以上)，小米科技；顺为资本；经纬中国；晨兴资本(C轮)  500-2000人  ...
# 2221                                        NaN    2000人以上  ...
#
#                                职位诱惑统计词  \
# 654   ['大牛', '领导', 'nice', '薪酬', '福利']
# 2221                     ['亿美金', '共创']
#
#                                          职位关键词                      需求匹配  \
# 654                   ['竞品分析', '逻辑思维', '数据驱动']                  ['逻辑思维']
# ...

# %%
# 值排序
product_df.sort_values(by='平均薪资/k').head()
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 1631   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 1690   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 864    拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 654    拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 1693   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
#
#         职位 ID                                     职位网址   公司名称        领域  \
# 1631  5415572  https://www.lagou.com/jobs/5415572.html   平安人寿        金融
# 1690  6604956  https://www.lagou.com/jobs/6604956.html    云宝宝     移动互联网
# 864   6510841  https://www.lagou.com/jobs/6510841.html  大易云计算   企业服务,其他
# 654   5644077  https://www.lagou.com/jobs/5644077.html     荔枝        社交
# 1693  6745753  https://www.lagou.com/jobs/6745753.html   星链科技  信息安全,区块链
#
#        发展阶段                                       投资机构       公司规模  ...  \
# ...

# %%
#结论：平均薪资高的公司规模也相对较大

# %%
#问题：探究公司规模与发展阶段是否有关系？
#关键词：公司规模、发展阶段（上市公司）
product_df.set_index('公司规模').sort_index().head()
# Out:
#        网站名称 对应的搜索关键词                                               搜索条件  \
# 公司规模
# 15-50人   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 15-50人   拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 15-50人   拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 15-50人   拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 15-50人   拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
#
#           职位 ID                                     职位网址           公司名称  \
# 公司规模
# 15-50人  6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学
# 15-50人  6744750  https://www.lagou.com/jobs/6744750.html  广州市启科信息科技有限公司
# 15-50人  3016764  https://www.lagou.com/jobs/3016764.html           八斗科技
# 15-50人  6827159  https://www.lagou.com/jobs/6827159.html            爱养牛
# 15-50人  6531570  https://www.lagou.com/jobs/6531570.html           DUMA
#
#                 领域   发展阶段 投资机构                          公司网址  ...  \
# ...

# %%
product_df['发展阶段'].describe()
# Out:
# count      2653
# unique       15
# top       不需要融资
# freq        749
# Name: 发展阶段, dtype: object

# %%
product_df['发展阶段'].head()
# Out:
# 0      未融资
# 1       A轮
# 2       B轮
# 3    不需要融资
# 4     上市公司
# Name: 发展阶段, dtype: object

# %%
product_df.loc[:,['公司规模','发展阶段']].head()
# Out:
#         公司规模   发展阶段
# 0     15-50人    未融资
# 1    2000人以上     A轮
# 2   150-500人     B轮
# 3   150-500人  不需要融资
# 4  500-2000人   上市公司

# %%
#发展阶段越好，公司规模越大

# %%
#单行提取发展阶段
product_df.iloc[:,7]
# Out:
# 0         未融资
# 1          A轮
# 2          B轮
# 3       不需要融资
# 4        上市公司
#         ...
# 2648       B轮
# 2649      天使轮
# 2650     上市公司
# 2651      未融资
# 2652      天使轮
# Name: 发展阶段, Length: 2653, dtype: object

# %%
#单行提取公司规模
product_df.iloc[:,8]
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2                                 隆领资本、华泽资本、华映资本、松柏资本(A轮)
# 3                                                     NaN
# 4                                                     NaN
#                               ...
# 2648    法拉龙资本、北极星资本、金沙江创投、元璟资本，以及天使阶段的真格基金和阿尔法公社。(B轮)，...
# 2649                                                  NaN
# 2650                                                  NaN
# 2651                                                  NaN
# 2652                                                  NaN
# Name: 投资机构, Length: 2653, dtype: object

# %%
product_df.iloc[:,7::2]
# Out:
#        发展阶段       公司规模                  职位名称  \
# 0       未融资     15-50人                  产品经理
# 1        A轮    2000人以上                  产品经理
# 2        B轮   150-500人                  产品经理
# 3     不需要融资   150-500人                  产品经理
# 4      上市公司  500-2000人                  产品经理
# ...     ...        ...                   ...
# 2648     B轮  500-2000人  产品总监（CPO） (MJ000138)
# 2649    天使轮   150-500人         产品总监（支付、聚合支付）
# 2650   上市公司    2000人以上          03713-算法产品总监
# 2651    未融资    2000人以上               商品库产品总监
# 2652    天使轮     15-50人                高级产品总监
#
#                                                    职位描述      经验要求 工作性质 工作地址 1  \
# 0     职位诱惑: 只奖励奉献者和贡献者，欢迎有识者加入！\n职位描述: 所谓大学者，非谓有大楼之谓...  经验5-10年    全职    南山区
# 1     职位诱惑: 年底双薪 绩效奖金\n职位描述: 岗位主要职责：1、基于公司集中式公寓战略方向，...  经验5-10年    全职    朝阳区
# 2     职位诱惑: 高速发展行业 福利齐全 年终奖\n职位描述: 产品经理（后台）工作职责：1）负责...   经验1-3年    全职    西湖区
# 3     职位诱惑: 福利优厚 美味三餐 成长快 团队氛围好\n职位描述: 岗位职责：1、对市场现状进...   经验3-5年    全职    海珠区
# ...

# %%
product_df.iloc[3::4,7::-2]
# Out:
#        发展阶段           公司名称    职位 ID 对应的搜索关键词
# 3     不需要融资           大圣科技  4878943     产品经理
# 7        C轮           理工数字  6863462     产品经理
# 11    不需要融资        YIDATEC  6866682     产品经理
# 15    不需要融资          大胖球网络  6865348     产品经理
# 19       A轮           秀蛋科技  6799228     产品经理
# ...     ...            ...      ...      ...
# 2635   上市公司           亿程信息  6672192     产品总监
# 2639   企业服务         柯凡工业设计  6835888     产品总监
# 2643   上市公司           亿程信息  6686638     产品总监
# 2647     C轮  Makeblock童心制物  6824183     产品总监
# 2651    未融资            千喜鹤  6843241     产品总监
#
# [663 rows x 4 columns]

# %%
product_df.iloc[(product_df['发展阶段']=='上市公司').values].head()
# Out:
#    网站名称 对应的搜索关键词                                               搜索条件    职位 ID  \
# 4    拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6210428
# 6    拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  5627648
# 22   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6800657
# 25   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6763791
# 26   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6869412
#
#                                        职位网址     公司名称         领域  发展阶段  \
# 4   https://www.lagou.com/jobs/6210428.html     虎牙信息      社交,游戏  上市公司
# 6   https://www.lagou.com/jobs/5627648.html     安恒信息  信息安全,数据服务  上市公司
# 22  https://www.lagou.com/jobs/6800657.html       兑吧      移动互联网  上市公司
# 25  https://www.lagou.com/jobs/6763791.html  爱学习教育集团   教育,移动互联网  上市公司
# 26  https://www.lagou.com/jobs/6869412.html      360       信息安全  上市公司
#
#                                                  投资机构       公司规模  ...  \
# ...

# %%
#公司规模与发展阶段有密切的关系。随着发展阶段的进步，公司规模也会相对进行扩张

# %%
#问题：发展规模影响产品经理的工作地点变更吗？
#关键词：发展规模、工作地点（北京）
product_df.iloc[:,18]
# Out:
# 0       深圳
# 1       北京
# 2       杭州
# 3       广州
# 4       北京
#         ..
# 2648    北京
# 2649    深圳
# 2650    北京
# 2651    北京
# 2652    北京
# Name: 工作地点, Length: 2653, dtype: object

# %%
product_df[['发展阶段','工作地点']]
# Out:
#        发展阶段 工作地点
# 0       未融资   深圳
# 1        A轮   北京
# 2        B轮   杭州
# 3     不需要融资   广州
# 4      上市公司   北京
# ...     ...  ...
# 2648     B轮   北京
# 2649    天使轮   深圳
# 2650   上市公司   北京
# 2651    未融资   北京
# 2652    天使轮   北京
#
# [2653 rows x 2 columns]

# %%
#工作地点多集中在较发达城市，且北京地区的上市公司居多

# %%
product_df[(product_df['发展阶段']=='上市公司')&(product_df['平均薪资/k']>=22.5)]
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 4      拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 25     拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 51     拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 103    拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 160    拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# ...   ...      ...                                                ...
# 2632   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2637   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2638   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2646   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2650   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#         职位 ID                                     职位网址            公司名称  \
# ...

# %%
#符合以上两个条件的占比不是很高，说明即使是上市公司，平均薪资也不一定都是很高
258/2653
# Out:
# 0.09724839803995476
