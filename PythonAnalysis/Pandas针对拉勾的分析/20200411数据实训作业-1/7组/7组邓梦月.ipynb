# %%
import pandas as pd 
import numpy as np
pd.__version__
# Out:
# '0.25.1'

# %%
dataFrameForProduct = pd.read_excel("产品.xls")

# %%
dataFrameForProduct.head()
# Out:
#   网站名称 对应的搜索关键词                                               搜索条件    职位 ID  \
# 0   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6793134
# 1   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6362305
# 2   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6831533
# 3   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  4878943
# 4   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6210428
#
#                                       职位网址           公司名称          领域   发展阶段  \
# 0  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育    未融资
# 1  https://www.lagou.com/jobs/6362305.html            自如网        房产家居     A轮
# 2  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活     B轮
# 3  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务  不需要融资
# 4  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏   上市公司
#
#                       投资机构       公司规模  ...  \
# ...

# %%
dataFrameForProduct.tail()
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 2648   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2649   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2650   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2651   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2652   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#         职位 ID                                     职位网址          公司名称     领域  \
# 2648  6645804  https://www.lagou.com/jobs/6645804.html  北京领创智信科技有限公司  移动互联网
# 2649  6743841  https://www.lagou.com/jobs/6743841.html           博纳德  移动互联网
# 2650  6068624  https://www.lagou.com/jobs/6068624.html          龙湖集团     其他
# 2651  6843241  https://www.lagou.com/jobs/6843241.html           千喜鹤   消费生活
# 2652  6723168  https://www.lagou.com/jobs/6723168.html         慧泊金科技  移动互联网
#
#       发展阶段                                               投资机构       公司规模  ...  \
# ...

# %%
dataFrameForProduct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2653 entries, 0 to 2652
# Data columns (total 36 columns):
# 网站名称           2653 non-null object
# 对应的搜索关键词       2653 non-null object
# 搜索条件           2653 non-null object
# 职位 ID          2653 non-null int64
# 职位网址           2653 non-null object
# 公司名称           2653 non-null object
# 领域             2653 non-null object
# 发展阶段           2653 non-null object
# 投资机构           572 non-null object
# 公司规模           2653 non-null object
# 公司网址           2653 non-null object
# 职位名称           2653 non-null object
# 标签列表           2653 non-null object
# 职位描述           2653 non-null object
# 薪资范围           2653 non-null object
# 经验要求           2653 non-null object
# 学历要求           2653 non-null object
# 工作性质           2653 non-null object
# 工作地点           2653 non-null object
# 工作地址 1         2653 non-null object
#  工作地址 2        1518 non-null object
#  工作地址 3        2653 non-null object
# 发布日期           2653 non-null object
# ...

# %%
dataFrameForProduct.describe()
# Out:
#               职位 ID       最低薪资/k       平均薪资/k       最高薪资/k
# count  2.653000e+03  2653.000000  2653.000000  2653.000000
# mean   6.335620e+06    15.263475    20.619864    25.976253
# std    8.521579e+05     9.904004    13.145331    16.632093
# min    2.654930e+05     1.000000     1.500000     2.000000
# 25%    6.245654e+06     8.000000    11.500000    14.000000
# 50%    6.684678e+06    15.000000    19.000000    25.000000
# 75%    6.809075e+06    20.000000    27.500000    35.000000
# max    6.870833e+06    90.000000   115.000000   150.000000

# %% [markdown]
# # 搜索关键词

# %%
import numpy as np
import pandas as pd
df = pd.read_excel('产品.xls',index_col='职位 ID')
df.loc[6210428]
# Out:
# 网站名称                                                          拉钩
# 对应的搜索关键词                                                    产品经理
# 搜索条件           https://www.lagou.com/jobs/list_产品经理?labelWord...
# 职位网址                     https://www.lagou.com/jobs/6210428.html
# 公司名称                                                        虎牙信息
# 领域                                                         社交,游戏
# 发展阶段                                                        上市公司
# 投资机构                                                         NaN
# 公司规模                                                   500-2000人
# 公司网址                                         http://hr.huya.com/
# 职位名称                                                        产品经理
# 标签列表                                    ['产品策划', '产品设计', '用户研究']
# 职位描述           职位诱惑: 大平台、大牛多、发展空间、薪资福利好\n职位描述: 工作职责： 1、对社区类产品...
# 薪资范围                                                    25k-45k
# ...

# %% [markdown]
# # 职位网址

# %%
df.iloc[:,3]
# Out:
# 职位 ID
# 6793134    https://www.lagou.com/jobs/6793134.html
# 6362305    https://www.lagou.com/jobs/6362305.html
# 6831533    https://www.lagou.com/jobs/6831533.html
# 4878943    https://www.lagou.com/jobs/4878943.html
# 6210428    https://www.lagou.com/jobs/6210428.html
#                             ...
# 6645804    https://www.lagou.com/jobs/6645804.html
# 6743841    https://www.lagou.com/jobs/6743841.html
# 6068624    https://www.lagou.com/jobs/6068624.html
# 6843241    https://www.lagou.com/jobs/6843241.html
# 6723168    https://www.lagou.com/jobs/6723168.html
# Name: 职位网址, Length: 2653, dtype: object

# %% [markdown]
# # 职位ID

# %%
dataFrameForProduct['职位 ID'].idxmax()
# Out:
# 1387

# %%
dataFrameForProduct['职位 ID'].count()
# Out:
# 2653

# %%
dataFrameForProduct['职位 ID']
# Out:
# 0       6793134
# 1       6362305
# 2       6831533
# 3       4878943
# 4       6210428
#          ...
# 2648    6645804
# 2649    6743841
# 2650    6068624
# 2651    6843241
# 2652    6723168
# Name: 职位 ID, Length: 2653, dtype: int64

# %%
dataFrameForProduct['职位 ID'].value_counts()
# Out:
# 6826069    2
# 6499275    2
# 5397000    2
# 5483057    2
# 6685447    2
#           ..
# 6484695    1
# 6819199    1
# 6849237    1
# 6413012    1
# 6805897    1
# Name: 职位 ID, Length: 2620, dtype: int64

# %%
dataFrameForProduct['职位 ID'].unique()
# Out:
# array([6793134, 6362305, 6831533, ..., 6068624, 6843241, 6723168],
#       dtype=int64)

# %%
dataFrameForProduct['职位 ID'].nunique()
# Out:
# 2620

# %%
dataFrameForProduct.set_index('职位 ID').head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6362305  https://www.lagou.com/jobs/6362305.html            自如网        房产家居
# 6831533  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活
# 4878943  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务
# 6210428  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏
#
#           发展阶段                     投资机构       公司规模  \
# ...

# %%
dataFrameForProduct.set_index('职位 ID').sort_index().head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 265493    拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 854127    拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 1119961   拉钩    产品部经理  https://www.lagou.com/jobs/list_产品部经理?labelWor...
# 1206287   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 1248752   拉钩  网页产品设计师  https://www.lagou.com/jobs/list_网页产品设计师?labelW...
#
#                                             职位网址      公司名称          领域  发展阶段  \
# 职位 ID
# 265493    https://www.lagou.com/jobs/265493.html       凯奇谷    移动互联网,游戏  上市公司
# 854127    https://www.lagou.com/jobs/854127.html  花儿绽放网络科技  移动互联网,广告营销  上市公司
# 1119961  https://www.lagou.com/jobs/1119961.html        易路  移动互联网,企业服务    C轮
# 1206287  https://www.lagou.com/jobs/1206287.html  Marketin   企业服务,数据服务    A轮
# 1248752  https://www.lagou.com/jobs/1248752.html      进门财经    移动互联网,金融    A轮
#
# ...

# %% [markdown]
# # 职位要求

# %%
df.iloc[:,16::18]
# Out:
#         工作性质                                        技能要求
# 职位 ID
# 6793134   全职               产品设计，项目管理，需求分析，逻辑思维，创新思维，工作经验
# 6362305   全职          竞品分析，产品设计，项目管理，逻辑思维，工作经验，需求调研，沟通能力
# 6831533   全职                                        逻辑思维
# 4878943   全职                                   产品设计，工作经验
# 6210428   全职  用户调研，产品设计，竞品分析，功能策划，逻辑思维，需求分析，工作经验，本科及以上学历
# ...      ...                                         ...
# 6645804   全职                       产品设计，团队管理，逻辑思维，本科以上学历
# 6743841   全职                              项目管理，工作经验，沟通能力
# 6068624   全职                           逻辑思维，工作经验，本科及以上学历
# 6843241   全职                              团队管理，工作经验，沟通能力
# 6723168   全职                         团队管理，团队合作，需求分析，沟通能力
#
# [2653 rows x 2 columns]

# %% [markdown]
# # 公司

# %%
dataFrameForProduct['公司规模'].describe()
# Out:
# count        2653
# unique          7
# top       2000人以上
# freq          613
# Name: 公司规模, dtype: object

# %%
df[['工作地点','平均薪资/k','最低薪资/k']].groupby('工作地点').apply(lambda x:x.max())
# Out:
#       工作地点  平均薪资/k  最低薪资/k
# 工作地点
# 上海      上海   105.0      90
# 东莞      东莞    15.0      10
# 中山      中山     5.0       4
# 佛山      佛山    30.0      20
# 北京      北京    90.0      80
# 南京      南京    52.5      35
# 南宁      南宁    14.0      12
# 南昌      南昌    20.0      15
# 厦门      厦门    24.0      18
# 合肥      合肥    45.0      30
# 呼和浩特  呼和浩特     4.0       3
# 嘉兴      嘉兴    25.5      17
# 天津      天津    22.5      20
# 太原      太原     4.0       3
# 宁波      宁波    30.0      20
# 广州      广州    75.0      50
# 惠州      惠州     6.0       4
# 成都      成都    60.0      40
# 无锡      无锡   115.0      80
# 昆明      昆明    15.5      11
# 昭通      昭通    20.0      15
# 杭州      杭州    65.0      50
# 武汉      武汉    50.0      40
# 江门      江门     7.5       5
# 沈阳      沈阳    12.0       8
# 济南      济南     9.5       7
# 深圳      深圳    75.0      60
# 温州      温州     4.5       3
# 珠海      珠海    20.0      15
# 石家庄    石家庄    12.5      10
# 福州      福州    30.0      20
# 绵阳      绵阳    10.5       8
# 苏州      苏州    45.0      30
# ...

# %%
df[['工作地点','平均薪资/k','最低薪资/k']].groupby('工作地点').apply(lambda x:print(x) )
# Out:
#         工作地点  平均薪资/k  最低薪资/k
# 职位 ID
# 6863462   上海    17.0      12
# 6866370   上海    15.5      13
# 6870012   上海    15.0      12
# 6867223   上海    20.0      15
# 3326114   上海    15.0      10
# ...      ...     ...     ...
# 6751635   上海    14.0      10
# 6065968   上海    30.0      25
# 6729603   上海    40.0      30
# 6194853   上海    40.0      30
# 6392017   上海    40.0      30
#
# [393 rows x 3 columns]
#         工作地点  平均薪资/k  最低薪资/k
# 职位 ID
# 6606203   东莞    15.0      10
# 6038854   东莞     6.0       5
# 6038850   东莞     8.5       6
# 6038847   东莞     8.5       6
#         工作地点  平均薪资/k  最低薪资/k
# 职位 ID
# 5643516   中山     5.0       4
#         工作地点  平均薪资/k  最低薪资/k
# 职位 ID
# 6077374   佛山     9.0       6
# 6832526   佛山    11.5      10
# 5912429   佛山     5.0       4
# 6210372   佛山     4.5       4
# 6775708   佛山    22.5      15
# 6265198   佛山    16.5      11
# 6786882   佛山    30.0      20
# 6777620   佛山    15.0      10
# 6786888   佛山    30.0      20
# 6788884   佛山    11.0       8
# ...

# %% [markdown]
# # 职位领域

# %%
df.loc[:,'领域']
# Out:
# 职位 ID
# 6793134            教育
# 6362305          房产家居
# 6831533    移动互联网,消费生活
# 4878943     软件开发,数据服务
# 6210428         社交,游戏
#               ...
# 6645804         移动互联网
# 6743841         移动互联网
# 6068624            其他
# 6843241          消费生活
# 6723168         移动互联网
# Name: 领域, Length: 2653, dtype: object

# %%
df.set_index(['发展阶段','领域']).groupby(level=1,axis=0).get_group('教育')
# Out:
#          网站名称 对应的搜索关键词                                               搜索条件  \
# 发展阶段  领域
# 未融资   教育   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 不需要融资 教育   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#       教育   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 未融资   教育   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 不需要融资 教育   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# ...       ...      ...                                                ...
# D轮及以上 教育   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# C轮    教育   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 上市公司  教育   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# B轮    教育   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# C轮    教育   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#                                              职位网址            公司名称  \
# ...

# %% [markdown]
# # 发展阶段

# %%
dataFrameForProduct['发展阶段'].head()
# Out:
# 0      未融资
# 1       A轮
# 2       B轮
# 3    不需要融资
# 4     上市公司
# Name: 发展阶段, dtype: object

# %%
df.loc[:,'公司名称':'发展阶段']
# Out:
#                   公司名称          领域   发展阶段
# 职位 ID
# 6793134  未来大学教育咨询/格物大学          教育    未融资
# 6362305            自如网        房产家居     A轮
# 6831533            车点点  移动互联网,消费生活     B轮
# 4878943           大圣科技   软件开发,数据服务  不需要融资
# 6210428           虎牙信息       社交,游戏   上市公司
# ...                ...         ...    ...
# 6645804   北京领创智信科技有限公司       移动互联网     B轮
# 6743841            博纳德       移动互联网    天使轮
# 6068624           龙湖集团          其他   上市公司
# 6843241            千喜鹤        消费生活    未融资
# 6723168          慧泊金科技       移动互联网    天使轮
#
# [2653 rows x 3 columns]

# %%
df.loc[lambda x:x['发展阶段']=='未融资'].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6870561   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6544519   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6829687   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6801113   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6870561  https://www.lagou.com/jobs/6870561.html          年轻的战场       移动互联网
# 6544519  https://www.lagou.com/jobs/6544519.html        北京乐途原动力  移动互联网,广告营销
# 6829687  https://www.lagou.com/jobs/6829687.html           东来科技        房产家居
# 6801113  https://www.lagou.com/jobs/6801113.html           米娱科技    文娱丨内容,社交
#
# ...

# %%
df.loc[df['发展阶段'].isin(['A轮','B轮'])]
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868962   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6719978   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6770110   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# ...      ...      ...                                                ...
# 6835686   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 6833511   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 6065968   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 6729603   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 6645804   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#                                             职位网址          公司名称          领域  \
# ...

# %%
grouped_single = df.groupby('发展阶段')
grouped_single.get_group('A轮').head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868962   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6719978   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6799228   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 3930560   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址          公司名称          领域  \
# 职位 ID
# 6362305  https://www.lagou.com/jobs/6362305.html           自如网        房产家居
# 6868962  https://www.lagou.com/jobs/6868962.html  北京极睿科技有限责任公司  移动互联网,数据服务
# 6719978  https://www.lagou.com/jobs/6719978.html           微拍堂       移动互联网
# 6799228  https://www.lagou.com/jobs/6799228.html          秀蛋科技    移动互联网,社交
# 3930560  https://www.lagou.com/jobs/3930560.html            领主    移动互联网,社交
#
#         发展阶段                       投资机构      公司规模  \
# ...

# %%
grouped_mul = df.groupby(['发展阶段','领域'])
grouped_mul.get_group(('A轮','游戏'))
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6485768   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6720395   拉钩   网页产品经理  https://www.lagou.com/jobs/list_网页产品经理?labelWo...
# 6127506   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 6865365   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 6819566   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 2759447   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 6824606   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 6535619   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 6559486   拉钩     游戏策划  https://www.lagou.com/jobs/list_游戏策划?labelWord...
# 5191151   拉钩  网页产品设计师  https://www.lagou.com/jobs/list_网页产品设计师?labelW...
# 6701003   拉钩  网页产品设计师  https://www.lagou.com/jobs/list_网页产品设计师?labelW...
# 6701009   拉钩  网页产品设计师  https://www.lagou.com/jobs/list_网页产品设计师?labelW...
# ...

# %%
df[df['发展阶段'].isin(['A轮','B轮'])].head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868962   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6719978   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6770110   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址          公司名称          领域  \
# 职位 ID
# 6362305  https://www.lagou.com/jobs/6362305.html           自如网        房产家居
# 6831533  https://www.lagou.com/jobs/6831533.html           车点点  移动互联网,消费生活
# 6868962  https://www.lagou.com/jobs/6868962.html  北京极睿科技有限责任公司  移动互联网,数据服务
# 6719978  https://www.lagou.com/jobs/6719978.html           微拍堂       移动互联网
# 6770110  https://www.lagou.com/jobs/6770110.html           壹心理       移动互联网
#
# ...

# %% [markdown]
# # 薪资

# %%
dataFrameForProduct.select_dtypes(include=['number']).head()
# Out:
#      职位 ID  最低薪资/k  平均薪资/k  最高薪资/k
# 0  6793134      15    22.5      30
# 1  6362305      20    27.5      35
# 2  6831533       8    12.0      16
# 3  4878943      10    15.0      20
# 4  6210428      25    35.0      45

# %%
dataFrameForProduct.sort_values(by='平均薪资/k').head()
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 1631   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 1690   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
# 864    拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 654    拉钩     产品助理  https://www.lagou.com/jobs/list_产品助理?labelWord...
# 1693   拉钩    产品实习生  https://www.lagou.com/jobs/list_产品实习生?labelWor...
#
#         职位 ID                                     职位网址   公司名称        领域  \
# 1631  5415572  https://www.lagou.com/jobs/5415572.html   平安人寿        金融
# 1690  6604956  https://www.lagou.com/jobs/6604956.html    云宝宝     移动互联网
# 864   6510841  https://www.lagou.com/jobs/6510841.html  大易云计算   企业服务,其他
# 654   5644077  https://www.lagou.com/jobs/5644077.html     荔枝        社交
# 1693  6745753  https://www.lagou.com/jobs/6745753.html   星链科技  信息安全,区块链
#
#        发展阶段                                       投资机构       公司规模  ...  \
# ...

# %%
dataFrameForProduct.sort_values(by='平均薪资/k',ascending=False).head()
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 2221   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2417   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2652   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 987    拉钩   数据产品经理  https://www.lagou.com/jobs/list_数据产品经理?labelWo...
# 2275   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#         职位 ID                                     职位网址   公司名称       领域   发展阶段  \
# 2221  6825466  https://www.lagou.com/jobs/6825466.html   仁线科技  电商、消费生活    未融资
# 2417  6690075  https://www.lagou.com/jobs/6690075.html    爱库存       电商     B轮
# 2652  6723168  https://www.lagou.com/jobs/6723168.html  慧泊金科技    移动互联网    天使轮
# 987   6870249  https://www.lagou.com/jobs/6870249.html     百度       工具  不需要融资
# 2275  6453934  https://www.lagou.com/jobs/6453934.html   酷划在线    移动互联网  不需要融资
#
#                                                    投资机构       公司规模  ...  \
# ...

# %%
df[['发展阶段','平均薪资/k']]
# Out:
#           发展阶段  平均薪资/k
# 职位 ID
# 6793134    未融资    22.5
# 6362305     A轮    27.5
# 6831533     B轮    12.0
# 4878943  不需要融资    15.0
# 6210428   上市公司    35.0
# ...        ...     ...
# 6645804     B轮    45.0
# 6743841    天使轮    25.0
# 6068624   上市公司    37.5
# 6843241    未融资    32.5
# 6723168    天使轮    90.0
#
# [2653 rows x 2 columns]

# %%
df[(df['发展阶段']=='A轮')&(df['平均薪资/k']>=22.5)]
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6868962   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6719978   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 3930560   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6606290   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# ...      ...      ...                                                ...
# 5512688   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 6782077   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 6833511   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 6065968   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 6729603   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#                                             职位网址          公司名称          领域  \
# ...

# %%
math_interval = pd.cut(df['平均薪资/k'],bins=[0,40,60,80,100])
math_interval
# Out:
# 职位 ID
# 6793134      (0, 40]
# 6362305      (0, 40]
# 6831533      (0, 40]
# 4878943      (0, 40]
# 6210428      (0, 40]
#              ...
# 6645804     (40, 60]
# 6743841      (0, 40]
# 6068624      (0, 40]
# 6843241      (0, 40]
# 6723168    (80, 100]
# Name: 平均薪资/k, Length: 2653, dtype: category
# Categories (4, interval[int64]): [(0, 40] < (40, 60] < (60, 80] < (80, 100]]

# %%
df_i = df.join(math_interval,rsuffix='_interval')[['平均薪资/k','平均薪资/k_interval']].reset_index().set_index('平均薪资/k_interval')
df_i.head()
# Out:
#                    职位 ID  平均薪资/k
# 平均薪资/k_interval
# (0, 40]           265493    12.5
# (0, 40]           854127     8.5
# (0, 40]          1119961    30.0
# (0, 40]          1206287     5.0
# (0, 40]          1248752     6.5

# %%
df_i.loc[65]
# Out:
#                    职位 ID  平均薪资/k
# 平均薪资/k_interval
# (60, 80]         4687751    65.0
# (60, 80]         5459009    65.0
# (60, 80]         5505690    65.0
# (60, 80]         5693927    65.0
# (60, 80]         5803917    65.0
# (60, 80]         6054031    75.0
# (60, 80]         6453934    80.0
# (60, 80]         6609876    65.0
# (60, 80]         6651717    65.0
# (60, 80]         6670033    75.0
# (60, 80]         6670439    65.0
# (60, 80]         6751156    65.0
# (60, 80]         6756127    75.0
# (60, 80]         6759559    67.5
# (60, 80]         6788156    65.0
# (60, 80]         6808927    75.0
# (60, 80]         6819765    70.0
# (60, 80]         6825809    65.0
# (60, 80]         6857145    65.0
# (60, 80]         6858636    75.0
# (60, 80]         6865674    65.0

# %%
df_i.loc[[65,90]]
# Out:
#                    职位 ID  平均薪资/k
# 平均薪资/k_interval
# (60, 80]         4687751    65.0
# (60, 80]         5459009    65.0
# (60, 80]         5505690    65.0
# (60, 80]         5693927    65.0
# (60, 80]         5803917    65.0
# (60, 80]         6054031    75.0
# (60, 80]         6453934    80.0
# (60, 80]         6609876    65.0
# (60, 80]         6651717    65.0
# (60, 80]         6670033    75.0
# (60, 80]         6670439    65.0
# (60, 80]         6751156    65.0
# (60, 80]         6756127    75.0
# (60, 80]         6759559    67.5
# (60, 80]         6788156    65.0
# (60, 80]         6808927    75.0
# (60, 80]         6819765    70.0
# (60, 80]         6825809    65.0
# (60, 80]         6857145    65.0
# (60, 80]         6858636    75.0
# (60, 80]         6865674    65.0
# (80, 100]        6723168    90.0
# (80, 100]        6870249    85.0

# %%
def f_test(s,low,high):
    return s.between(low,high).max()

def agg_f(f_mul,name,*args,**kwargs):
    def wrapper(x):
        return f_mul(x,*args,**kwargs)
    wrapper.__name__ = name
    return wrapper

new_f = agg_f(f_test,'at_least_one_in_50_52',50,52)

grouped_single['平均薪资/k'].agg([new_f,'mean'])
# Out:
#            at_least_one_in_50_52       mean
# 发展阶段
# A轮                         False  18.795129
# B轮                          True  23.887160
# C轮                          True  23.335196
# D轮及以上                       True  28.480663
# 上市公司                        True  23.233129
# 不需要融资                       True  18.222296
# 企业服务                       False   8.000000
# 企业服务,教育                    False   3.500000
# 企业服务,消费生活                  False  19.000000
# 医疗丨健康                      False   7.500000
# 天使轮                        False  16.491379
# 未融资                        False  17.342025
# 移动互联网,教育                   False  17.500000
# 移动互联网,游戏                   False  22.500000
# 金融                         False  20.000000

# %%
grouped_single[['平均薪资/k','最低薪资/k']].filter(lambda x:(x['平均薪资/k']>12).all())
# Out:
#          平均薪资/k  最低薪资/k
# 职位 ID
# 6626544    20.0      15
# 6830391    22.5      15
# 6686800    17.5      15
# 6853330    19.0      13

# %%
from collections import OrderedDict
def f(df):
    data = OrderedDict()
    data['平均薪资_sum'] = df['平均薪资/k'].sum()
    data['最高薪资_var'] = df['最高薪资/k'].var()
    data['最低薪资_mean'] = df['最低薪资/k'].mean()
    return pd.Series(data)
grouped_single.apply(f)
# Out:
#            平均薪资_sum    最高薪资_var  最低薪资_mean
# 发展阶段
# A轮           6559.5  189.678276  13.868195
# B轮           6139.0  319.063898  17.996109
# C轮           4177.0  269.533237  17.486034
# D轮及以上        5155.0  322.277655  20.972376
# 上市公司        11361.0  294.998718  16.889571
# 不需要融资       13648.5  226.869205  13.477971
# 企业服务            8.0         NaN   6.000000
# 企业服务,教育         3.5         NaN   3.000000
# 企业服务,消费生活      19.0         NaN  13.000000
# 医疗丨健康           7.5         NaN   5.000000
# 天使轮          1913.0  218.978936  12.422414
# 未融资          5653.5  283.260642  12.993865
# 移动互联网,教育       17.5         NaN  15.000000
# 移动互联网,游戏       22.5         NaN  15.000000
# 金融             20.0         NaN  15.000000
