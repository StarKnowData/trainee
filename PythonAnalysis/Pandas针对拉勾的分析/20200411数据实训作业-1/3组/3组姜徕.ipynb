# %%
import pandas as pd 
import numpy as np
pd.__version__
# Out:
# '0.25.1'

# %%
dataFrameForProduct = pd.read_excel("技术.xls")

# %%
dataFrameForProduct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15700 entries, 0 to 15699
# Data columns (total 36 columns):
# Unnamed: 0     15700 non-null int64
# 网站名称           15700 non-null object
# 对应的搜索关键词       15700 non-null object
# 搜索条件           15700 non-null object
# 职位 ID          15700 non-null int64
# 职位网址           15700 non-null object
# 公司名称           15699 non-null object
# 领域             15700 non-null object
# 发展阶段           15700 non-null object
# 投资机构           2647 non-null object
# 公司规模           15700 non-null object
# 公司网址           15700 non-null object
# 职位名称           15700 non-null object
# 标签列表           15700 non-null object
# 职位描述           15700 non-null object
# 薪资范围           15700 non-null object
# 经验要求           15700 non-null object
# 学历要求           15700 non-null object
# 工作性质           15700 non-null object
# 工作地点           15700 non-null object
# 工作地址 1         15700 non-null object
#  工作地址 2        8878 non-null object
# ...

# %%
dataFrameForProduct['职位 ID']
# Out:
# 0        1422976
# 1        6807272
# 2        6869132
# 3        1958487
# 4        6680164
#           ...
# 15695    6064055
# 15696    6195723
# 15697    6689683
# 15698    5715958
# 15699    6558874
# Name: 职位 ID, Length: 15700, dtype: int64

# %%
dataFrameForProduct['职位 ID'].nunique()
# Out:
# 12049

# %%
dataFrameForProduct['职位 ID'].value_counts()

# 发现有大量的职位ID重合 大概有3000+
# Out:
# 6236572    8
# 2516657    8
# 6252407    8
# 6592758    8
# 5206884    6
#           ..
# 6309868    1
# 6815723    1
# 6813674    1
# 6041577    1
# 5834753    1
# Name: 职位 ID, Length: 12049, dtype: int64

# %%
dataFrameForProduct.set_index('职位 ID').sort_index().head() # #可以设置ascending参数，默认为升序，True
# Out:
#         Unnamed: 0 网站名称 对应的搜索关键词  \
# 职位 ID
# 97805         2084   拉钩   Python
# 116706         487   拉钩      PHP
# 116719         549   拉钩      PHP
# 183975        5066   拉钩      U3D
# 199812        4215   拉钩    web前端
#
#                                                      搜索条件  \
# 职位 ID
# 97805   https://www.lagou.com/jobs/list_Python?labelWo...
# 116706  https://www.lagou.com/jobs/list_PHP?labelWords...
# 116719  https://www.lagou.com/jobs/list_PHP?labelWords...
# 183975  https://www.lagou.com/jobs/list_U3D?labelWords...
# 199812  https://www.lagou.com/jobs/list_web前端?labelWor...
#
#                                           职位网址  公司名称        领域   发展阶段  \
# 职位 ID
# 97805    https://www.lagou.com/jobs/97805.html   她理财        金融     A轮
# 116706  https://www.lagou.com/jobs/116706.html    乐鱼        游戏    未融资
# 116719  https://www.lagou.com/jobs/116719.html    乐鱼        游戏    未融资
# 183975  https://www.lagou.com/jobs/183975.html   凯奇谷  移动互联网,游戏   上市公司
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_excel('技术.xls',index_col='职位 ID')
df.head()
# Out:
#          Unnamed: 0 网站名称 对应的搜索关键词  \
# 职位 ID
# 1422976           0   拉钩     Java
# 6807272           1   拉钩     Java
# 6869132           2   拉钩     Java
# 1958487           3   拉钩     Java
# 6680164           4   拉钩     Java
#
#                                                       搜索条件  \
# 职位 ID
# 1422976  https://www.lagou.com/jobs/list_Java?labelWord...
# 6807272  https://www.lagou.com/jobs/list_Java?labelWord...
# 6869132  https://www.lagou.com/jobs/list_Java?labelWord...
# 1958487  https://www.lagou.com/jobs/list_Java?labelWord...
# 6680164  https://www.lagou.com/jobs/list_Java?labelWord...
#
#                                             职位网址            公司名称         领域  \
# 职位 ID
# 1422976  https://www.lagou.com/jobs/1422976.html            大圣科技  软件开发,数据服务
# 6807272  https://www.lagou.com/jobs/6807272.html            伊澳科技   移动互联网,电商
# 6869132  https://www.lagou.com/jobs/6869132.html  北京天谱在线网络科技有限公司         教育
# ...

# %%
df.loc[6236572]
# Out:
#          Unnamed: 0 网站名称 对应的搜索关键词  \
# 职位 ID
# 6236572        3250   拉钩   后端开发其它
# 6236572        6335   拉钩    测试工程师
# 6236572        6497   拉钩    自动化测试
# 6236572        6900   拉钩     功能测试
# 6236572        7126   拉钩     测试开发
# 6236572        7461   拉钩     白盒测试
# 6236572        8060   拉钩     测试其它
# 6236572       10286   拉钩  MongoDB
#
#                                                       搜索条件  \
# 职位 ID
# 6236572  https://www.lagou.com/jobs/list_后端开发其它?labelWo...
# 6236572  https://www.lagou.com/jobs/list_测试工程师?labelWor...
# 6236572  https://www.lagou.com/jobs/list_自动化测试?labelWor...
# 6236572  https://www.lagou.com/jobs/list_功能测试?labelWord...
# 6236572  https://www.lagou.com/jobs/list_测试开发?labelWord...
# 6236572  https://www.lagou.com/jobs/list_白盒测试?labelWord...
# 6236572  https://www.lagou.com/jobs/list_测试其它?labelWord...
# 6236572  https://www.lagou.com/jobs/list_MongoDB?labelW...
#
#                                             职位网址 公司名称    领域   发展阶段 投资机构  \
# 职位 ID
# ...

# %%
data_1 = dataFrameForProduct.drop_duplicates(["职位 ID"])

# %%
data_1['职位 ID'].value_counts()  #删除了重复的数据
# Out:
# 4722686    1
# 6130599    1
# 6755736    1
# 6090135    1
# 5481878    1
#           ..
# 5885698    1
# 3134677    1
# 6828755    1
# 5574188    1
# 5834753    1
# Name: 职位 ID, Length: 12049, dtype: int64

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12049 entries, 0 to 15698
# Data columns (total 36 columns):
# Unnamed: 0     12049 non-null int64
# 网站名称           12049 non-null object
# 对应的搜索关键词       12049 non-null object
# 搜索条件           12049 non-null object
# 职位 ID          12049 non-null int64
# 职位网址           12049 non-null object
# 公司名称           12048 non-null object
# 领域             12049 non-null object
# 发展阶段           12049 non-null object
# 投资机构           1992 non-null object
# 公司规模           12049 non-null object
# 公司网址           12049 non-null object
# 职位名称           12049 non-null object
# 标签列表           12049 non-null object
# 职位描述           12049 non-null object
# 薪资范围           12049 non-null object
# 经验要求           12049 non-null object
# 学历要求           12049 non-null object
# 工作性质           12049 non-null object
# 工作地点           12049 non-null object
# 工作地址 1         12049 non-null object
#  工作地址 2        6817 non-null object
# ...

# %% [markdown]
# # 1.要有什么样的证书可以进入技术岗位
#
# # 2.技术的待遇怎么样，平均薪资表示，或者用区间个数来表示
#
# # 3.技术的待遇差距（地区），如果我从事技术专业，选择哪个地方最合适
#
# # 4.技术对专业的要求，有哪些专业适合进入技术

# %%
data_1['证书要求']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 15693    NaN
# 15694    NaN
# 15696    NaN
# 15697    NaN
# 15698    NaN
# Name: 证书要求, Length: 12049, dtype: object

# %%
data_1['证书要求'].count()
# Out:
# 308

# %%
data_1['证书要求'].value_counts()
# Out:
# 计算机二级                                                                 129
# 英语四级，英语专业四级，英语六级                                                       50
# 英语六级，英语专业四级，英语四级                                                       35
# 英语六级，英语四级                                                              21
# 英语六级，英语四级，英语专业四级                                                       18
# CET4，CET6                                                              18
# 英语四级，英语六级                                                              13
# 英语六级，英语专业四级，英语四级，计算机二级                                                  4
# 基金从业资格证，期货从业资格证，证券从业资格证，银行从业资格证，审计师统计从业资格证，会计从业资格证                      4
# 英语六级，英语四级，计算机二级                                                         3
# 法律职业资格证                                                                 3
# 律师执业证                                                                   1
# ACA，AICPA，ACCA                                                          1
# ...

# %%
data_1['证书要求'].nunique()
# Out:
# 21

# %%
data_1['证书要求'].unique()
# Out:
# array([nan, '英语四级，英语专业四级，英语六级', '计算机二级', 'CET4，CET6', '英语六级，英语专业四级，英语四级',
#        '英语六级，英语四级，英语专业四级', '英语四级，英语六级', '英语六级，英语四级',
#        '基金从业资格证，期货从业资格证，证券从业资格证，银行从业资格证，会计从业资格证', '法律职业资格证', '华为认证',
#        '基金从业资格证，期货从业资格证，证券从业资格证，银行从业资格证，审计师统计从业资格证，会计从业资格证',
#        'ACA，AICPA，ACCA', '英语六级，英语专业四级，英语四级，计算机二级',
#        '高等学校教师资格证，初级中学教师资格证，小学教师资格证，高级中学教师资格证，幼儿园教师资格证，中等职业学校教师资格证，高校教师资格证',
#        '英语专业八级，英语专业四级，英语四级', '英语专业八级，英语六级，英语四级，英语专业四级', '英语专业八级，英语专业四级',
#        '英语六级，英语四级，计算机二级', '阿里云认证', 'GMAT', '律师执业证'], dtype=object)

# %% [markdown]
# ## 1.技术方向的岗位，在证书上一共有21种，在已有的数据中，，英语四级和英语六级159/308，是要求最多的证书，其次是计算机二级129/398，然后还有专业四级证书77/308

# %%
data_1['专业要求']
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 15693                                   装甲车辆工程，智能车辆工程，车辆工程
# 15694    医学信息工程，通信工程，地理空间信息工程，电子信息工程，智能电网信息工程，信息工程，光电信息...
# 15696                                                  NaN
# 15697                                                  NaN
# 15698                                                 产品设计
# Name: 专业要求, Length: 12049, dtype: object

# %%
data_1['专业要求'].count()
# Out:
# 3997

# %%
data_1['专业要求'].nunique()
# Out:
# 378

# %%
data_1['专业要求'].value_counts()
# Out:
# 软件工程                                                                                                                                                                  669
# 人工智能，工业智能                                                                                                                                                             603
# 产品设计                                                                                                                                                                  590
# 信息安全                                                                                                                                                                  391
# 市场营销教育，市场营销                                                                                                                                                           121
# ...

# %% [markdown]
# # 专业上依据5229条有效数据,软件工程(669)、产品设计(590)和人工智能，工业智能专业(603)是部分技术岗最需要的专业

# %%
data_1.head()
# Out:
#    Unnamed: 0 网站名称 对应的搜索关键词  \
# 0           0   拉钩     Java
# 1           1   拉钩     Java
# 2           2   拉钩     Java
# 3           3   拉钩     Java
# 4           4   拉钩     Java
#
#                                                 搜索条件    职位 ID  \
# 0  https://www.lagou.com/jobs/list_Java?labelWord...  1422976
# 1  https://www.lagou.com/jobs/list_Java?labelWord...  6807272
# 2  https://www.lagou.com/jobs/list_Java?labelWord...  6869132
# 3  https://www.lagou.com/jobs/list_Java?labelWord...  1958487
# 4  https://www.lagou.com/jobs/list_Java?labelWord...  6680164
#
#                                       职位网址            公司名称         领域   发展阶段  \
# 0  https://www.lagou.com/jobs/1422976.html            大圣科技  软件开发,数据服务  不需要融资
# 1  https://www.lagou.com/jobs/6807272.html            伊澳科技   移动互联网,电商   上市公司
# 2  https://www.lagou.com/jobs/6869132.html  北京天谱在线网络科技有限公司         教育  不需要融资
# 3  https://www.lagou.com/jobs/1958487.html             万熹翼   移动互联网,电商     A轮
# ...

# %%
data_1['最高薪资/k']
# Out:
# 0        22
# 1        35
# 2        13
# 3        12
# 4        11
#          ..
# 15693    25
# 15694    35
# 15696     6
# 15697    32
# 15698    25
# Name: 最高薪资/k, Length: 12049, dtype: int64

# %%
# 构造平均薪资
moneyMid = (data_1['最高薪资/k']+data_1['最低薪资/k'])/2

# %%
moneyMid
# Out:
# 0    17.0
# 1    30.0
# 2    11.5
# 3     9.0
# 4    10.0
# dtype: float64

# %%
data_1.loc[ : ,"平均薪资/k"] = (data_1['最高薪资/k']+data_1['最低薪资/k'])/2

# %%
data_1.head()
# Out:
#    Unnamed: 0 网站名称 对应的搜索关键词  \
# 0           0   拉钩     Java
# 1           1   拉钩     Java
# 2           2   拉钩     Java
# 3           3   拉钩     Java
# 4           4   拉钩     Java
#
#                                                 搜索条件    职位 ID  \
# 0  https://www.lagou.com/jobs/list_Java?labelWord...  1422976
# 1  https://www.lagou.com/jobs/list_Java?labelWord...  6807272
# 2  https://www.lagou.com/jobs/list_Java?labelWord...  6869132
# 3  https://www.lagou.com/jobs/list_Java?labelWord...  1958487
# 4  https://www.lagou.com/jobs/list_Java?labelWord...  6680164
#
#                                       职位网址            公司名称         领域   发展阶段  \
# 0  https://www.lagou.com/jobs/1422976.html            大圣科技  软件开发,数据服务  不需要融资
# 1  https://www.lagou.com/jobs/6807272.html            伊澳科技   移动互联网,电商   上市公司
# 2  https://www.lagou.com/jobs/6869132.html  北京天谱在线网络科技有限公司         教育  不需要融资
# 3  https://www.lagou.com/jobs/1958487.html             万熹翼   移动互联网,电商     A轮
# ...

# %%
data_1['平均薪资/k'].nlargest(10)
# Out:
# 6648     300.0
# 11143    150.0
# 11193    150.0
# 11228    150.0
# 1010     115.0
# 971      112.5
# 11487    100.0
# 5819      95.0
# 11340     92.5
# 3583      90.0
# Name: 平均薪资/k, dtype: float64

# %%
math_interval = pd.cut(data_1['平均薪资/k'],bins=[0,10,20,40,60,80,100,150,300])

# %%
math_interval
# Out:
# 0        (10, 20]
# 1        (20, 40]
# 2        (10, 20]
# 3         (0, 10]
# 4         (0, 10]
#            ...
# 15693    (10, 20]
# 15694    (20, 40]
# 15696     (0, 10]
# 15697    (20, 40]
# 15698    (10, 20]
# Name: 平均薪资/k, Length: 12049, dtype: category
# Categories (8, interval[int64]): [(0, 10] < (10, 20] < (20, 40] < (40, 60] < (60, 80] < (80, 100] < (100, 150] < (150, 300]]

# %%
data_1.join(math_interval,rsuffix='_interval')
# Out:
#        Unnamed: 0 网站名称 对应的搜索关键词  \
# 0               0   拉钩     Java
# 1               1   拉钩     Java
# 2               2   拉钩     Java
# 3               3   拉钩     Java
# 4               4   拉钩     Java
# ...           ...  ...      ...
# 15693       15693   拉钩   企业软件其它
# 15694       15694   拉钩   企业软件其它
# 15696       15696   拉钩   企业软件其它
# 15697       15697   拉钩   企业软件其它
# 15698       15698   拉钩   企业软件其它
#
#                                                     搜索条件    职位 ID  \
# 0      https://www.lagou.com/jobs/list_Java?labelWord...  1422976
# 1      https://www.lagou.com/jobs/list_Java?labelWord...  6807272
# 2      https://www.lagou.com/jobs/list_Java?labelWord...  6869132
# 3      https://www.lagou.com/jobs/list_Java?labelWord...  1958487
# 4      https://www.lagou.com/jobs/list_Java?labelWord...  6680164
# ...                                                  ...      ...
# 15693  https://www.lagou.com/jobs/list_企业软件其它?labelWo...  6077324
# ...

# %%
data_1.loc[ : ,"薪资区间"] = math_interval

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12049 entries, 0 to 15698
# Data columns (total 38 columns):
# Unnamed: 0     12049 non-null int64
# 网站名称           12049 non-null object
# 对应的搜索关键词       12049 non-null object
# 搜索条件           12049 non-null object
# 职位 ID          12049 non-null int64
# 职位网址           12049 non-null object
# 公司名称           12048 non-null object
# 领域             12049 non-null object
# 发展阶段           12049 non-null object
# 投资机构           1992 non-null object
# 公司规模           12049 non-null object
# 公司网址           12049 non-null object
# 职位名称           12049 non-null object
# 标签列表           12049 non-null object
# 职位描述           12049 non-null object
# 薪资范围           12049 non-null object
# 经验要求           12049 non-null object
# 学历要求           12049 non-null object
# 工作性质           12049 non-null object
# 工作地点           12049 non-null object
# 工作地址 1         12049 non-null object
#  工作地址 2        6817 non-null object
# ...

# %%
data_1.describe()
# Out:
#          Unnamed: 0         职位 ID        最低薪资/k        最高薪资/k        平均薪资/k
# count  12049.000000  1.204900e+04  12049.000000  12049.000000  12049.000000
# mean    7487.886630  6.238710e+06     14.865632     25.530998     20.198315
# std     4696.356885  9.507776e+05      8.882213     15.567029     12.104630
# min        0.000000  9.780500e+04      1.000000      2.000000      1.500000
# 25%     3260.000000  6.098292e+06      8.000000     15.000000     11.500000
# 50%     7219.000000  6.626123e+06     15.000000     22.000000     18.000000
# 75%    11768.000000  6.795011e+06     20.000000     35.000000     26.500000
# max    15698.000000  6.871297e+06    200.000000    400.000000    300.000000

# %%
import matplotlib.pyplot as plt
import pandas as pd
import sys
import seaborn as sns

# %%
sns.factorplot('薪资区间',data=data_1,kind='count')

# %% [markdown]
# ## 根据上图所示，我们可以发现，技术岗的薪资（10:20]占第一位，（20:40]占第二位，其次是（0:10]。平均薪资为20K，可以知道技术岗的薪资还是很可观的，一般能拿到10K以上。

# %%
# 看技术岗的地区

data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12049 entries, 0 to 15698
# Data columns (total 38 columns):
# Unnamed: 0     12049 non-null int64
# 网站名称           12049 non-null object
# 对应的搜索关键词       12049 non-null object
# 搜索条件           12049 non-null object
# 职位 ID          12049 non-null int64
# 职位网址           12049 non-null object
# 公司名称           12048 non-null object
# 领域             12049 non-null object
# 发展阶段           12049 non-null object
# 投资机构           1992 non-null object
# 公司规模           12049 non-null object
# 公司网址           12049 non-null object
# 职位名称           12049 non-null object
# 标签列表           12049 non-null object
# 职位描述           12049 non-null object
# 薪资范围           12049 non-null object
# 经验要求           12049 non-null object
# 学历要求           12049 non-null object
# 工作性质           12049 non-null object
# 工作地点           12049 non-null object
# 工作地址 1         12049 non-null object
#  工作地址 2        6817 non-null object
# ...

# %%
dataPlace = data_1[['工作地点','平均薪资/k','最低薪资/k','最高薪资/k']].groupby('工作地点').apply(lambda x:x.max())

# %%
dataPlace.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, 三亚 to 黔南
# Data columns (total 4 columns):
# 工作地点      87 non-null object
# 平均薪资/k    87 non-null float64
# 最低薪资/k    87 non-null int64
# 最高薪资/k    87 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.4+ KB

# %%
dataPlace.head()
# Out:
#      工作地点  平均薪资/k  最低薪资/k  最高薪资/k
# 工作地点
# 三亚     三亚     8.0       6      10
# 上海     上海   150.0     120     180
# 东莞     东莞    65.0      50      80
# 中山     中山     9.0       6      12
# 临沂     临沂     8.0       6      10

# %%
dataPlace.describe()
# Out:
#            平均薪资/k      最低薪资/k      最高薪资/k
# count   87.000000   87.000000   87.000000
# mean    28.183908   20.655172   35.885057
# std     42.395365   29.453482   55.740976
# min      3.000000    2.000000    4.000000
# 25%      8.000000    6.000000   10.000000
# 50%     15.000000   11.000000   19.000000
# 75%     27.250000   20.000000   32.500000
# max    300.000000  200.000000  400.000000

# %%
dataPlace['平均薪资/k'].nlargest(10)
# Out:
# 工作地点
# 杭州    300.0
# 上海    150.0
# 北京    150.0
# 深圳    150.0
# 成都     90.0
# 厦门     80.0
# 广州     80.0
# 武汉     75.0
# 南京     67.5
# 东莞     65.0
# Name: 平均薪资/k, dtype: float64

# %% [markdown]
# ## 在数据可靠的情况下，技术岗薪资最多的地区是（排序）：杭州、上海和北京和深圳、成都、厦门、广州、武汉、南京、东莞等。北上广深仍然是值得去的地方，还可以考虑杭州、成都、厦门等城市

# %%
moneyDifference = dataPlace['最高薪资/k'] - dataPlace['最低薪资/k']

# %%
moneyDifference
# Out:
# 工作地点
# 三亚          4
# 上海         60
# 东莞         30
# 中山          6
# 临沂          4
#            ..
# 青岛         15
# 韶关          3
# 香港特别行政区     2
# 马鞍山        15
# 黔南          2
# Length: 87, dtype: int64

# %%
dataPlace.loc[ : ,"薪资差距"] = moneyDifference

# %%
dataPlace.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, 三亚 to 黔南
# Data columns (total 5 columns):
# 工作地点      87 non-null object
# 平均薪资/k    87 non-null float64
# 最低薪资/k    87 non-null int64
# 最高薪资/k    87 non-null int64
# 薪资差距      87 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 6.6+ KB

# %%
dataPlace["薪资差距"]
# Out:
# 工作地点
# 三亚          4
# 上海         60
# 东莞         30
# 中山          6
# 临沂          4
#            ..
# 青岛         15
# 韶关          3
# 香港特别行政区     2
# 马鞍山        15
# 黔南          2
# Name: 薪资差距, Length: 87, dtype: int64

# %%
dataPlace['薪资差距'].nlargest(10)
# Out:
# 工作地点
# 杭州    200
# 北京    100
# 深圳    100
# 上海     60
# 成都     60
# 武汉     50
# 厦门     40
# 南京     35
# 广州     35
# 东莞     30
# Name: 薪资差距, dtype: int64

# %%
dataPlace[dataPlace['薪资差距']<2]
# Out:
#      工作地点  平均薪资/k  最低薪资/k  最高薪资/k  薪资差距
# 工作地点
# 梅州     梅州     6.5       6       7     1
# 榆林     榆林     3.5       3       4     1
# 洛阳     洛阳     3.5       3       4     1
# 衡水     衡水     5.5       5       6     1
# 赣州     赣州     3.5       3       4     1

# %%
dataPlace[(dataPlace['薪资差距'] <=5)&(dataPlace['平均薪资/k']>= 20)]
# Out:
#      工作地点  平均薪资/k  最低薪资/k  最高薪资/k  薪资差距
# 工作地点
# 佛山     佛山    32.5      30      35     5
# 廊坊     廊坊    27.5      25      30     5

# %%
df[(df['发展阶段']=='A轮')&(df['平均薪资/k']>=22.5)].head()

# %% [markdown]
# ## 由数据可以知道，如果数据可靠的话，杭州的技术的薪资差距最大，足足有200K，其次是北京和深圳有100K，然后是上海和成都。薪资差距最小的5个城市是梅州、榆林、洛阳、衡水和赣州
#
# ## 佛山和廊坊的薪资在20K以上，薪资差距为5K

# %% [markdown]
# # 综上（技术岗）
#
# ## 1.要有什么样的证书可以进入技术岗位
#
# ###  CET4 和CET6,二级证书是基础，有条件可以由专业四级证书
# #### 在证书上一共有21种，在已有的数据中,英语四级和英语六级159/308，是要求最多的证书，其次是计算机二级129/398，然后还有专业四级证书77/308
#
# ## 2.技术的待遇怎么样，平均薪资表示，或者用区间个数来表示
#
# ### 薪资大部分在[10:40],平均薪资在20K，薪资很可观
#
# #### 技术岗的薪资（10:20]占第一位，（20:40]占第二位，其次是（0:10]，平均薪资为20K。
#
# ## 3.技术的待遇差距（地区），如果我从事技术专业，选择哪个地方最合适
#
# ### 杭州的待遇差距最大，有200K，其次是上海北京有150K。待遇差距不大的地方有梅州、榆林、洛阳、衡水和赣州,不过这些城市薪资平均在5K。说明有风险才有高收入，低风险的收入并不可观。
# ### 另外 佛山和廊坊的平均薪资都在20K以上，而且薪资差距为5K，是一个高收入风险较低的地方，值得去
#
# ####  在数据可靠的情况下，技术岗薪资最多的地区是（排序）：杭州、上海和北京和深圳、成都、厦门、广州、武汉、南京、东莞等。北上广深仍然是值得去的地方，还可以考虑杭州、成都、厦门等城市
#
# ## 4.技术对专业的要求，有哪些专业适合进入技术
#
# ### 软件工程、产品设计和人工智能，工业智能等专业适合进入技术
#
# #### 专业上依据5229条有效数据,软件工程(669)、产品设计(590)和人工智能，工业智能专业(603)是部分技术岗最需要的专业
