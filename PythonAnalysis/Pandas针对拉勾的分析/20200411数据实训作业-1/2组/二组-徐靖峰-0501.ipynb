# %%
import pandas as pd 
import numpy as np
pd.__version__
# Out:
# '0.22.0'

# %%
dataFrameForProduct = pd.read_excel("datalab/62617/产品.xls")

# %%
dataFrameForProduct.set_index('职位 ID').head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6362305  https://www.lagou.com/jobs/6362305.html            自如网        房产家居
# 6831533  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活
# 4878943  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务
# 6210428  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏
#
#           发展阶段                     投资机构       公司规模  \
# ...

# %%
dataFrameForProduct.set_index('职位 ID').head()
# Out:
#         网站名称 对应的搜索关键词                                               搜索条件  \
# 职位 ID
# 6793134   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6362305   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6831533   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 4878943   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
# 6210428   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...
#
#                                             职位网址           公司名称          领域  \
# 职位 ID
# 6793134  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育
# 6362305  https://www.lagou.com/jobs/6362305.html            自如网        房产家居
# 6831533  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活
# 4878943  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务
# 6210428  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏
#
#           发展阶段                     投资机构       公司规模  \
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_excel("datalab/62617/产品.xls")
df.head()
# Out:
#   网站名称 对应的搜索关键词                                               搜索条件    职位 ID  \
# 0   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6793134
# 1   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6362305
# 2   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6831533
# 3   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  4878943
# 4   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6210428
#
#                                       职位网址           公司名称          领域   发展阶段  \
# 0  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育    未融资
# 1  https://www.lagou.com/jobs/6362305.html            自如网        房产家居     A轮
# 2  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活     B轮
# 3  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务  不需要融资
# 4  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏   上市公司
#
#                       投资机构       公司规模  \
# ...

# %%
df.loc[6210428::-1].head()
# Out:
#      网站名称 对应的搜索关键词                                               搜索条件  \
# 2652   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2651   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2650   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2649   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
# 2648   拉钩     产品总监  https://www.lagou.com/jobs/list_产品总监?labelWord...
#
#         职位 ID                                     职位网址          公司名称     领域  \
# 2652  6723168  https://www.lagou.com/jobs/6723168.html         慧泊金科技  移动互联网
# 2651  6843241  https://www.lagou.com/jobs/6843241.html           千喜鹤   消费生活
# 2650  6068624  https://www.lagou.com/jobs/6068624.html          龙湖集团     其他
# 2649  6743841  https://www.lagou.com/jobs/6743841.html           博纳德  移动互联网
# 2648  6645804  https://www.lagou.com/jobs/6645804.html  北京领创智信科技有限公司  移动互联网
#
#       发展阶段                                               投资机构       公司规模  \
# ...

# %%
import pandas as pd
import numpy as np
df =  pd.read_excel("datalab/62617/产品.xls")
df.head()
# Out:
#   网站名称 对应的搜索关键词                                               搜索条件    职位 ID  \
# 0   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6793134
# 1   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6362305
# 2   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6831533
# 3   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  4878943
# 4   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6210428
#
#                                       职位网址           公司名称          领域   发展阶段  \
# 0  https://www.lagou.com/jobs/6793134.html  未来大学教育咨询/格物大学          教育    未融资
# 1  https://www.lagou.com/jobs/6362305.html            自如网        房产家居     A轮
# 2  https://www.lagou.com/jobs/6831533.html            车点点  移动互联网,消费生活     B轮
# 3  https://www.lagou.com/jobs/4878943.html           大圣科技   软件开发,数据服务  不需要融资
# 4  https://www.lagou.com/jobs/6210428.html           虎牙信息       社交,游戏   上市公司
#
#                       投资机构       公司规模  \
# ...

# %%
df.isna().sum()
# Out:
# 网站名称              0
# 对应的搜索关键词          0
# 搜索条件              0
# 职位 ID             0
# 职位网址              0
# 公司名称              0
# 领域                0
# 发展阶段              0
# 投资机构           2081
# 公司规模              0
# 公司网址              0
# 职位名称              0
# 标签列表              0
# 职位描述              0
# 薪资范围              0
# 经验要求              0
# 学历要求              0
# 工作性质              0
# 工作地点              0
# 工作地址 1            0
#  工作地址 2        1135
#  工作地址 3           0
# 发布日期              0
# 职位诱惑              0
# 职位要求              0
# 职位诱惑关键词           0
# 职位诱惑统计词           0
# 职位关键词             0
# 需求匹配              0
# 最低薪资/k            0
# 平均薪资/k            0
# 最高薪资/k            0
# 专业要求           1273
# 证书要求           2613
# softskill要求     406
# 技能要求              0
# dtype: int64

# %%
#单行提取公司规模
df.iloc[:,8]
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2                                 隆领资本、华泽资本、华映资本、松柏资本(A轮)
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                               红杉；图灵；金沙江；魔量(A轮)，金沙江(天使轮)
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# ...

# %%
df[df['发展阶段']=='A轮'].head()
# Out:
#    网站名称 对应的搜索关键词                                               搜索条件    职位 ID  \
# 1    拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6362305
# 8    拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6868962
# 10   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6719978
# 19   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6799228
# 33   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  3930560
#
#                                        职位网址          公司名称          领域 发展阶段  \
# 1   https://www.lagou.com/jobs/6362305.html           自如网        房产家居   A轮
# 8   https://www.lagou.com/jobs/6868962.html  北京极睿科技有限责任公司  移动互联网,数据服务   A轮
# 10  https://www.lagou.com/jobs/6719978.html           微拍堂       移动互联网   A轮
# 19  https://www.lagou.com/jobs/6799228.html          秀蛋科技    移动互联网,社交   A轮
# 33  https://www.lagou.com/jobs/3930560.html            领主    移动互联网,社交   A轮
#
# ...

# %%
#问题：产品岗位招聘公司发展阶段对薪资的影响

df[(df['发展阶段']=='上市公司')&(df['平均薪资/k']>=22.5)].head()
# Out:
#     网站名称 对应的搜索关键词                                               搜索条件    职位 ID  \
# 4     拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6210428
# 25    拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6763791
# 51    拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  5552216
# 103   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6802904
# 160   拉钩     产品经理  https://www.lagou.com/jobs/list_产品经理?labelWord...  6823101
#
#                                         职位网址            公司名称        领域  发展阶段  \
# 4    https://www.lagou.com/jobs/6210428.html            虎牙信息     社交,游戏  上市公司
# 25   https://www.lagou.com/jobs/6763791.html         爱学习教育集团  教育,移动互联网  上市公司
# 51   https://www.lagou.com/jobs/5552216.html            平安产险        金融  上市公司
# 103  https://www.lagou.com/jobs/6802904.html              网易        电商  上市公司
# 160  https://www.lagou.com/jobs/6823101.html  上海银科创展投资集团有限公司  移动互联网,金融  上市公司
#
# ...

# %%
# 问题: 招聘产品岗位的地区

work_adress = dict(df['工作地点'])

df[['工作地点','平均薪资/k']].head()
# Out:
#   工作地点  平均薪资/k
# 0   深圳    22.5
# 1   北京    27.5
# 2   杭州    12.0
# 3   广州    15.0
# 4   北京    35.0

# %%
df.select_dtypes(include=['number']).head()
# Out:
#      职位 ID  最低薪资/k  平均薪资/k  最高薪资/k
# 0  6793134      15    22.5      30
# 1  6362305      20    27.5      35
# 2  6831533       8    12.0      16
# 3  4878943      10    15.0      20
# 4  6210428      25    35.0      45

# %%
#问题：发展规模受工作地点的影响
#关键词：发展规模、工作地点
df.iloc[:,18].head()
# Out:
# 0    深圳
# 1    北京
# 2    杭州
# 3    广州
# 4    北京
# Name: 工作地点, dtype: object

# %%
#问题：学历对薪资的影响
#关键词：学历要求，平均薪资/k

df[['学历要求','平均薪资/k']].head()
# Out:
#      学历要求  平均薪资/k
# 0  本科及以上     22.5
# 1   学历不限     27.5
# 2  本科及以上     12.0
# 3  本科及以上     15.0
# 4  本科及以上     35.0
