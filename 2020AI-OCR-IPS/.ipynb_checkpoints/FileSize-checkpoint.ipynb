# %%
# -*-coding:utf-8-*-
import os

filePath = '/Users/lw/WorkSpace/BuEr/trainee/'

fileMap = {}
size = 0

# 遍历filePath下的文件、文件夹（包括子目录）
for parent, dirnames, filenames in os.walk(filePath):
    #for dirname in dirnames:
        #print('parent is %s, dirname is %s' % (parent, dirname))

    for filename in filenames:
        # print('parent is %s, filename is %s' % (parent, filename))
        # print('the full name of the file is %s' % os.path.join(parent, filename))
        
        size = os.path.getsize(os.path.join(parent, filename))
        fileMap.setdefault(os.path.join(parent, filename), size)

filelist = sorted(fileMap.items(), key=lambda d: d[1], reverse=False)
for filename, size in filelist:
    if size >=100000000:
        print("filename is %s , and size is %d" % (filename, size))
# Out:
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Untitled Folder
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Python-Fly-Game
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is joyful-pandas
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is jandan
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is PyEcharts
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is PythonMath
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Python-Spider
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is HelloWorld
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Python2-HTML
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is OneinStack
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Machine-Learning-With-Python
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Python-Basic
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is 推荐算法
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is pydata-book
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Python3
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is 算法
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is PythonAnalysis
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Python2
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is 量化交易
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is 虚拟机
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is HTML2Markdown
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is handson-ml
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Untitled Folder 2
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is 2020WinterIPS-Tech
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Java
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is __pycache__
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is 2020AI-OCR-IPS
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is lcan
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Titanic_Train
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is 数据挖掘
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Computing-Intelligence
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is MySQL
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Titanic
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is wechat_mini
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Carmelo
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is ImageDownloaderAndPythonWechat
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Python-Advanced
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is Numpy-Pandas-Matplotlib
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is .git
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is PythonDataAnalysisForBeginner
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is 公式预测
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is ml-100k
# parent is /Users/lw/WorkSpace/BuEr/trainee/, dirname is MachineLearningMathBasic
# parent is /Users/lw/WorkSpace/BuEr/trainee/Untitled Folder, dirname is __pycache__
# parent is /Users/lw/WorkSpace/BuEr/trainee/Untitled Folder, dirname is 未命名文件夹
# parent is /Users/lw/WorkSpace/BuEr/trainee/Untitled Folder, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Fly-Game, dirname is images
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Fly-Game, dirname is __pycache__
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Fly-Game, dirname is font
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Fly-Game, dirname is sound
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas, dirname is picture
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas, dirname is .git
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas, dirname is data
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git, dirname is objects
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git, dirname is logs
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git, dirname is hooks
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git/objects, dirname is pack
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git/objects, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git/logs, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git/logs/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git/logs/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git/logs/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git/refs, dirname is tags
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/joyful-pandas/.git/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/PyEcharts, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath, dirname is punkt
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath, dirname is 数据结构与算法
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/punkt, dirname is PY3
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法, dirname is 中文版的数据结构
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法, dirname is DavidEppsteinPADS
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法, dirname is tryalgo
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构, dirname is python-data-structure-cn
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn, dirname is 7.图和图的算法
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn, dirname is 3.基本数据结构
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn, dirname is 4.递归
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn, dirname is 2.算法分析
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn, dirname is 6.树和树的算法
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn, dirname is .git
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn, dirname is 5.排序和搜索
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn, dirname is 1.介绍
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.3.图抽象数据类型
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.22.Prim生成树算法
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.18.强连通分量
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.6.实现
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.7.字梯的问题
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.9.实现广度优先搜索
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.16.深度优先搜索分析
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.20.Dijkstra算法
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.19.最短路径问题
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.12.构建骑士之旅图
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.23.总结
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.14.骑士之旅分析
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.15.通用深度优先搜索
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.4.邻接矩阵
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.2.词汇和定义
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.8.构建字梯图
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.1.目标
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.10.广度优先搜索分析
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.17.拓扑排序
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.21.Dijkstra算法分析
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.13.实现骑士之旅
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.11.骑士之旅
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法, dirname is 7.5.邻接表
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.22.Prim生成树算法, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.18.强连通分量, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.9.实现广度优先搜索, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.20.Dijkstra算法, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.19.最短路径问题, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.12.构建骑士之旅图, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.14.骑士之旅分析, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.15.通用深度优先搜索, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.4.邻接矩阵, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.2.词汇和定义, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.8.构建字梯图, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.1.目标, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.1.目标, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.1.目标/assets, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.10.广度优先搜索分析, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.17.拓扑排序, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.13.实现骑士之旅, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/7.图和图的算法/7.5.邻接表, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.6.简单括号匹配
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.1.目标
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.20.无序列表抽象数据类型
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.10.什么是队列
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.4.栈的抽象数据类型
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.23.实现有序列表
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.7.符号匹配
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.12.Python实现队列
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.17.Python实现Deque
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.5.Python实现栈
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.21.实现无序列表：链表
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.15.什么是Deque
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.11.队列抽象数据类型
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.9.中缀前缀和后缀表达式
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.24.总结
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.14.模拟：打印机
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.19.列表
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.3.什么是栈
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.22.有序列表抽象数据结构
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.13.模拟：烫手山芋
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.8.十进制转换成二进制
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.16.Deque抽象数据类型
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.2.什么是线性数据结构
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构, dirname is 3.18.回文检查
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.6.简单括号匹配, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.10.什么是队列, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.4.栈的抽象数据类型, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.23.实现有序列表, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.21.实现无序列表：链表, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.15.什么是Deque, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.11.队列抽象数据类型, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.9.中缀前缀和后缀表达式, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.14.模拟：打印机, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.19.列表, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.3.什么是栈, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.13.模拟：烫手山芋, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.8.十进制转换成二进制, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.16.Deque抽象数据类型, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/3.基本数据结构/3.18.回文检查, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.2.什么是递归
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.3.计算整数列表和
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.8.谢尔宾斯基三角形
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.9.复杂递归问题
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.4.递归的三定律
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.13.总结
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.1.目标
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.6.栈帧：实现递归
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.7.介绍：可视化递归
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.5.整数转换为任意进制字符串
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.11.探索迷宫
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.10.汉诺塔游戏
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归, dirname is 4.12.动态规划
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归/4.3.计算整数列表和, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归/4.8.谢尔宾斯基三角形, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归/4.6.栈帧：实现递归, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归/4.7.介绍：可视化递归, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归/4.5.整数转换为任意进制字符串, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归/4.11.探索迷宫, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归/4.10.汉诺塔游戏, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/4.递归/4.12.动态规划, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析, dirname is 2.3.大O符号
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析, dirname is 2.1.目标
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析, dirname is 2.7.字典
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析, dirname is 2.4.一个乱序字符串检查的例子
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析, dirname is 2.8.总结
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析, dirname is 2.5.Python数据结构的性能
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析, dirname is 2.2.什么是算法分析
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析, dirname is 2.6.列表
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析/2.3.大O符号, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析/2.7.字典, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/2.算法分析/2.6.列表, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.13.查找树实现
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.16.AVL平衡二叉搜索树
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.12.查找树操作
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.18.Map抽象数据结构总结
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.8.基于二叉堆的优先队列
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.10.二叉堆实现
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.4.列表表示
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.7.树的遍历
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.19.总结
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.1.目标
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.2.树的例子
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.6.分析树
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.15.平衡二叉搜索树
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.14.查找树分析
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.17.AVL平衡二叉搜索树实现
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.11.二叉查找树
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.9.二叉堆操作
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.3.词汇和定义
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法, dirname is 6.5.节点表示
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.13.查找树实现, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.16.AVL平衡二叉搜索树, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.18.Map抽象数据结构总结, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.10.二叉堆实现, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.4.列表表示, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.7.树的遍历, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.2.树的例子, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.6.分析树, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.15.平衡二叉搜索树, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.14.查找树分析, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.17.AVL平衡二叉搜索树实现, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.3.词汇和定义, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/6.树和树的算法/6.5.节点表示, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git, dirname is objects
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git, dirname is logs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git, dirname is hooks
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git/objects, dirname is pack
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git/objects, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git/logs, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git/logs/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git/logs/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git/logs/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git/refs, dirname is tags
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/.git/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.9.插入排序
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.11.归并排序
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.5.Hash查找
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.2.搜索
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.4.二分查找
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.7.冒泡排序
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.8.选择排序
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.13.总结
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.1.目标
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.3.顺序查找
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.12.快速排序
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.10.希尔排序
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索, dirname is 5.6.排序
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.9.插入排序, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.11.归并排序, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.5.Hash查找, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.2.搜索, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.4.二分查找, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.7.冒泡排序, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.8.选择排序, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.3.顺序查找, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.12.快速排序, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.10.希尔排序, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/5.排序和搜索/5.10.希尔排序, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.7.回顾Python基础
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.8.数据入门
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.10.控制结构
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.13.面向对象编程-定义类
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.6.为什么要学习算法
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.9.输入和输出
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.11.处理异常
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.14.总结
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.5.为什么要学习数据结构和抽象数据类型
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.12.定义函数
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.2.快速开始
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.3.什么是计算机科学
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.4.什么是编程
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍, dirname is 1.1.目标
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍/1.8.数据入门, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍/1.13.面向对象编程-定义类, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍/1.9.输入和输出, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍/1.5.为什么要学习数据结构和抽象数据类型, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/中文版的数据结构/python-data-structure-cn/1.介绍/1.3.什么是计算机科学, dirname is assets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS, dirname is pads
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads, dirname is .git
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git, dirname is objects
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git, dirname is logs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git, dirname is hooks
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git/objects, dirname is pack
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git/objects, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git/logs, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git/logs/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git/logs/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git/logs/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git/refs, dirname is tags
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/DavidEppsteinPADS/pads/.git/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo, dirname is tests
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo, dirname is docs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo, dirname is examples
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo, dirname is .git
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo, dirname is tryalgo
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/docs, dirname is _static
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/docs, dirname is tryalgo
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/examples, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git, dirname is objects
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git, dirname is logs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git, dirname is hooks
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git/objects, dirname is pack
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git/objects, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git/logs, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git/logs/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git/logs/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git/logs/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git/refs, dirname is tags
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/.git/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonMath/数据结构与算法/tryalgo/tryalgo, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider, dirname is Pypeteer
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider, dirname is IPS2020SpiderPracticalTraining
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider, dirname is XICIDAILI
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider, dirname is TouTiaoFav
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider, dirname is fonts
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider/Pypeteer, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider/IPS2020SpiderPracticalTraining, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider/XICIDAILI, dirname is .idea
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider/XICIDAILI/.idea, dirname is inspectionProfiles
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider/TouTiaoFav, dirname is __pycache__
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider/TouTiaoFav, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider/TouTiaoFav, dirname is .idea
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Spider/TouTiaoFav/.idea, dirname is inspectionProfiles
# parent is /Users/lw/WorkSpace/BuEr/trainee/HelloWorld, dirname is out
# parent is /Users/lw/WorkSpace/BuEr/trainee/HelloWorld, dirname is .idea
# parent is /Users/lw/WorkSpace/BuEr/trainee/HelloWorld, dirname is src
# parent is /Users/lw/WorkSpace/BuEr/trainee/HelloWorld/out, dirname is production
# parent is /Users/lw/WorkSpace/BuEr/trainee/HelloWorld/out/production, dirname is HelloWorld
# parent is /Users/lw/WorkSpace/BuEr/trainee/Machine-Learning-With-Python, dirname is Recommend
# parent is /Users/lw/WorkSpace/BuEr/trainee/Machine-Learning-With-Python, dirname is Artificial-master
# parent is /Users/lw/WorkSpace/BuEr/trainee/Machine-Learning-With-Python, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/Machine-Learning-With-Python/Recommend, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/Machine-Learning-With-Python/Artificial-master, dirname is images
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Basic, dirname is __pycache__
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python-Basic, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/推荐算法, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book, dirname is datasets
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book, dirname is examples
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book, dirname is .git
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/datasets, dirname is haiti
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/datasets, dirname is fec
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/datasets, dirname is babynames
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/datasets, dirname is mta_perf
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/datasets, dirname is bitly_usagov
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/datasets, dirname is titanic
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/datasets, dirname is usda_food
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/datasets, dirname is movielens
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/datasets/haiti, dirname is PortAuPrince_Roads
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git, dirname is objects
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git, dirname is logs
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git, dirname is hooks
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git, dirname is branches
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git/objects, dirname is pack
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git/objects, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git/logs, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git/logs/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git/logs/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git/logs/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git/refs, dirname is tags
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/.git/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/Python3, dirname is Anaconda-Jupyter
# parent is /Users/lw/WorkSpace/BuEr/trainee/算法, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis, dirname is pydata-book
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis, dirname is 科比
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis, dirname is 信用卡欺诈
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis, dirname is Pandas针对拉勾的分析
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis, dirname is 预测科比生涯数据
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis, dirname is 泰坦尼克号成员获救情况预测
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book, dirname is datasets
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book, dirname is examples
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book, dirname is .git
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/datasets, dirname is haiti
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/datasets, dirname is fec
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/datasets, dirname is babynames
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/datasets, dirname is mta_perf
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/datasets, dirname is bitly_usagov
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/datasets, dirname is titanic
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/datasets, dirname is usda_food
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/datasets, dirname is movielens
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/datasets/haiti, dirname is PortAuPrince_Roads
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git, dirname is objects
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git, dirname is logs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git, dirname is hooks
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git/objects, dirname is pack
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git/objects, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git/logs, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git/logs/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git/logs/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git/logs/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git/refs, dirname is tags
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/.git/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/科比, dirname is NBAdata
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/科比, dirname is Kaggle-NBAData
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/科比, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/科比/Kaggle-NBAData, dirname is NBA
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/科比/Kaggle-NBAData, dirname is NBA 2
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/科比/Kaggle-NBAData/NBA, dirname is NBA
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/科比/Kaggle-NBAData/NBA 2, dirname is NBA 2
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/科比/Kaggle-NBAData/NBA 2/NBA 2, dirname is test
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/信用卡欺诈, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析, dirname is 20200411数据实训作业
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析, dirname is 20200411数据实训作业-1
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析, dirname is pyecharts-gallery
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析, dirname is data
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析/20200411数据实训作业, dirname is 5组
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析/20200411数据实训作业, dirname is 1组
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析/20200411数据实训作业, dirname is 2组
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析/20200411数据实训作业, dirname is 3组
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析/20200411数据实训作业, dirname is 4组
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析/20200411数据实训作业, dirname is 7组
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/Pandas针对拉勾的分析/20200411数据实训作业/5组, dirname is .ipynb_checkpoints
# ...
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is b4
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is a2
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is a5
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is bd
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is d1
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is d6
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is bc
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ae
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is d8
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ab
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is e5
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is e2
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is f4
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is f3
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is eb
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is c7
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is c0
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ee
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is c9
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is fc
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is fd
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is f2
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is f5
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is e3
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is cf
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ca
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is e4
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is fe
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is c8
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is fb
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ed
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is c1
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is c6
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ec
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 4e
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 20
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 18
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 27
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 4b
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is pack
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 11
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 7d
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 29
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 7c
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 16
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 42
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 89
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 45
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 1f
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 73
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 87
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 80
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 74
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 1a
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 28
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 17
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 7b
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 8f
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 8a
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 7e
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 10
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 19
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 4c
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 26
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 21
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 4d
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 75
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 81
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 86
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 72
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 44
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 2a
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 2f
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 43
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 88
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 9f
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 6b
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 07
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 38
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 00
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 6e
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 9a
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 36
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 5c
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 09
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 5d
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 31
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is info
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 91
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 65
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 62
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 96
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 3a
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 54
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 98
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 53
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 3f
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 30
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 5e
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 5b
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 37
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 08
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 6d
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 01
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 06
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 6c
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 39
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 99
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 52
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 55
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 97
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 63
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 0f
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 0a
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 64
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 90
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is bf
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is d3
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is d4
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ba
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is a0
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is a7
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is b8
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is b1
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is dd
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is dc
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is b6
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is a9
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is d5
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is d2
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is aa
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is af
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is b7
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is db
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is a8
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is de
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is b0
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is a6
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is b9
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is a1
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ef
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is c3
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is c4
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ea
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is e1
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is cd
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is cc
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is e6
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is f9
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is f0
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is f7
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is e8
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is fa
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ff
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is c5
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is c2
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is f6
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is e9
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is f1
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is e7
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is cb
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is f8
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is ce
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is e0
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 46
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 2c
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 79
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 2d
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 41
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 83
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 1b
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 77
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 48
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 70
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 1e
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 84
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 4a
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 24
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 23
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 4f
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 8d
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 15
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 12
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 8c
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 85
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 1d
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 71
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 76
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 1c
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 82
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 49
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 40
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 2e
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 2b
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 47
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 78
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 8b
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 13
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 7f
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 7a
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 14
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 8e
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 22
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/objects, dirname is 25
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/logs, dirname is refs
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/logs/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/logs/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/logs/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/refs, dirname is heads
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/refs, dirname is tags
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/refs, dirname is remotes
# parent is /Users/lw/WorkSpace/BuEr/trainee/.git/refs/remotes, dirname is origin
# parent is /Users/lw/WorkSpace/BuEr/trainee/PythonDataAnalysisForBeginner, dirname is .ipynb_checkpoints
# parent is /Users/lw/WorkSpace/BuEr/trainee/公式预测, dirname is datascut
# parent is /Users/lw/WorkSpace/BuEr/trainee/公式预测, dirname is datascut300
# filename is /Users/lw/WorkSpace/BuEr/trainee/.git/objects/pack/pack-1e3162b0ca4ac973172210987a3c7800d6265355.pack , and size is 149494829
# filename is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/信用卡欺诈/creditcard.csv , and size is 150828752
# filename is /Users/lw/WorkSpace/BuEr/trainee/pydata-book/datasets/fec/P00000001-ALL.csv , and size is 157871393
# filename is /Users/lw/WorkSpace/BuEr/trainee/PythonAnalysis/pydata-book/datasets/fec/P00000001-ALL.csv , and size is 157871393
# filename is /Users/lw/WorkSpace/BuEr/trainee/Computing-Intelligence/jupyters_and_slides/.git/objects/pack/pack-808d67bff05be83effa68c10715af12000f9cba6.pack , and size is 310986035
